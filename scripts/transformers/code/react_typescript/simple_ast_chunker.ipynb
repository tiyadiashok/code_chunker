# %% [markdown]
# Core AST Chunking Test Program
# This program implements just the essential AST-based chunking functionality for .tsx files. It will:
#
# Parse .tsx files using Tree-sitter TypeScript parser
# Identify semantic boundaries (functions, classes, components, etc.)
# Create base chunks from AST nodes
# Apply sub-chunking when chunks exceed token limits
# Print results showing the chunking hierarchy
#
# What's included:
#
# Core Tree-sitter parsing for TypeScript/TSX
# Basic AST boundary detection
# Token counting for size management
# Recursive sub-chunking logic
# Simple output display
#
# What's excluded:
#
# Import management
# Fallback chunking
# Package.json analysis
# Error handling
# Performance optimization
# File validation
# Output generation

# %%
#!/usr/bin/env python3

import os
from pathlib import Path
from typing import List, Dict, Any
import tiktoken

# Tree-sitter setup for TSX
try:
    from tree_sitter_language_pack import get_language, get_parser
    tsx_language = get_language('tsx')
    parser = get_parser('tsx')
    print("✅ Using TSX parser for React TypeScript files")
except ImportError:
    print("Please install: pip install tree-sitter-languages")
    exit(1)

# Configuration
MAX_CHUNK_TOKENS = 1000
MAX_RECURSION_DEPTH = 3

# Initialize token encoder
encoder = tiktoken.get_encoding("cl100k_base")

def count_tokens(text: str) -> int:
    """Count tokens in text"""
    return len(encoder.encode(text))

class Chunk:
    def __init__(self, start_byte: int, end_byte: int, content: str, node_type: str, name: str, depth: int = 0):
        self.start_byte = start_byte
        self.end_byte = end_byte
        self.content = content
        self.node_type = node_type
        self.name = name
        self.depth = depth
        self.token_count = count_tokens(content)
        self.sub_chunks = []

def extract_node_name(node, source_code: str) -> str:
    """Extract meaningful name from AST node"""
    node_text = source_code[node.start_byte:node.end_byte]
    lines = node_text.split('\n')
    
    import re
    
    # Try different patterns based on node type
    if node.type == 'function_declaration':
        match = re.search(r'function\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
        if match:
            return match.group(1)
    
    elif node.type == 'variable_declaration':
        # Look for const/let ComponentName = forwardRef or const hook = 
        match = re.search(r'(?:const|let|var)\s+([a-zA-Z_$][a-zA-Z0-9_$]*)\s*=', node_text)
        if match:
            return match.group(1)
    
    elif node.type == 'interface_declaration':
        match = re.search(r'interface\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
        if match:
            return match.group(1)
    
    elif node.type == 'type_alias_declaration':
        match = re.search(r'type\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
        if match:
            return match.group(1)
    
    elif node.type == 'class_declaration':
        match = re.search(r'class\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
        if match:
            return match.group(1)
    
    elif node.type == 'export_statement':
        # Handle various export patterns
        if 'export interface' in node_text:
            match = re.search(r'export\s+interface\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
            if match:
                return f"interface_{match.group(1)}"
        elif 'export const' in node_text:
            match = re.search(r'export\s+const\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
            if match:
                return f"const_{match.group(1)}"
        elif 'export function' in node_text:
            match = re.search(r'export\s+function\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
            if match:
                return f"function_{match.group(1)}"
        elif 'export default' in node_text:
            return "default_export"
        else:
            return "export_statement"
    
    # Fallback
    first_line = lines[0][:50].strip()
    simple_match = re.search(r'\b([a-zA-Z_$][a-zA-Z0-9_$]*)', first_line)
    if simple_match:
        return simple_match.group(1)
    
    return f"{node.type}_{node.start_byte}"

def is_top_level_semantic_node(node, parent_types: List[str]) -> bool:
    """Check if this node represents a top-level semantic unit"""
    
    # Top-level declarations
    if node.type in ['function_declaration', 'class_declaration', 'interface_declaration', 'type_alias_declaration']:
        # Make sure it's actually top-level (not nested inside a function)
        return 'function_declaration' not in parent_types and 'method_definition' not in parent_types
    
    # Variable declarations that are likely components or important constants
    if node.type == 'variable_declaration':
        # Check if it's at top level
        if 'function_declaration' not in parent_types and 'method_definition' not in parent_types:
            # Look for patterns like: const Component = forwardRef, const useHook = 
            node_text = get_node_text_preview(node)
            if any(pattern in node_text for pattern in ['forwardRef', 'useState', 'useEffect', 'createContext']):
                return True
    
    # Export statements at top level
    if node.type == 'export_statement':
        return 'function_declaration' not in parent_types and 'method_definition' not in parent_types
    
    return False

def get_node_text_preview(node) -> str:
    """Get a preview of node text for pattern matching"""
    # This would need the source code, but for checking we can use a simpler approach
    return ""

def find_semantic_chunks(tree, source_code: str) -> List[Dict[str, Any]]:
    """Find semantic chunks - complete, meaningful code blocks"""
    semantic_nodes = []
    
    def traverse(node, parent_types=None):
        if parent_types is None:
            parent_types = []
        
        current_parent_types = parent_types + [node.type]
        
        # Check if this is a top-level semantic unit
        node_text = source_code[node.start_byte:node.end_byte]
        
        # Top-level function declarations
        if node.type == 'function_declaration' and len(parent_types) <= 1:
            name = extract_node_name(node, source_code)
            semantic_nodes.append({
                'node': node,
                'name': name,
                'start_byte': node.start_byte,
                'end_byte': node.end_byte,
                'type': node.type,
                'content': node_text
            })
            return  # Don't traverse children - we want the whole function
        
        # Top-level interfaces and types
        elif node.type in ['interface_declaration', 'type_alias_declaration'] and len(parent_types) <= 1:
            name = extract_node_name(node, source_code)
            semantic_nodes.append({
                'node': node,
                'name': name,
                'start_byte': node.start_byte,
                'end_byte': node.end_byte,
                'type': node.type,
                'content': node_text
            })
            return
        
        # Top-level variable declarations (components, hooks, constants)
        elif node.type == 'variable_declaration' and len(parent_types) <= 1:
            # Check if it looks like a component or important declaration
            if any(pattern in node_text for pattern in ['forwardRef', '= (' , 'useState', 'useEffect', 'createContext', 'makePrefixer']):
                name = extract_node_name(node, source_code)
                semantic_nodes.append({
                    'node': node,
                    'name': name,
                    'start_byte': node.start_byte,
                    'end_byte': node.end_byte,
                    'type': 'component_or_hook',
                    'content': node_text
                })
                return
        
        # Top-level export statements (but check what they're exporting)
        elif node.type == 'export_statement' and len(parent_types) <= 1:
            name = extract_node_name(node, source_code)
            # Only include if it's a substantial export (not just a re-export)
            if len(node_text.strip()) > 50:  # Substantial content
                semantic_nodes.append({
                    'node': node,
                    'name': name,
                    'start_byte': node.start_byte,
                    'end_byte': node.end_byte,
                    'type': node.type,
                    'content': node_text
                })
                return
        
        # Continue traversing children for other nodes
        for child in node.children:
            traverse(child, current_parent_types)
    
    traverse(tree.root_node)
    
    # Sort by start position and remove overlaps
    semantic_nodes.sort(key=lambda x: x['start_byte'])
    
    # Remove nested/overlapping nodes
    filtered_nodes = []
    for node in semantic_nodes:
        # Check if this node is contained within any existing node
        is_contained = False
        for existing in filtered_nodes:
            if (existing['start_byte'] <= node['start_byte'] and 
                existing['end_byte'] >= node['end_byte']):
                is_contained = True
                break
        
        if not is_contained:
            # Also check if this node contains any existing nodes
            to_remove = []
            for i, existing in enumerate(filtered_nodes):
                if (node['start_byte'] <= existing['start_byte'] and 
                    node['end_byte'] >= existing['end_byte']):
                    to_remove.append(i)
            
            # Remove contained nodes
            for i in reversed(to_remove):
                filtered_nodes.pop(i)
            
            filtered_nodes.append(node)
    
    return filtered_nodes

def create_semantic_chunks(semantic_nodes: List[Dict[str, Any]]) -> List[Chunk]:
    """Create chunks from semantic nodes"""
    chunks = []
    
    for node_info in semantic_nodes:
        chunk = Chunk(
            start_byte=node_info['start_byte'],
            end_byte=node_info['end_byte'],
            content=node_info['content'],
            node_type=node_info['type'],
            name=node_info['name'],
            depth=0
        )
        chunks.append(chunk)
    
    return chunks

def sub_chunk_by_statements(chunk: Chunk, tree, source_code: str, depth: int = 0) -> List[Chunk]:
    """Sub-chunk by breaking down into logical statements/blocks"""
    if depth >= MAX_RECURSION_DEPTH or chunk.token_count <= MAX_CHUNK_TOKENS:
        return [chunk]
    
    print(f"    Breaking down {chunk.name} ({chunk.token_count} tokens) into smaller pieces...")
    
    # Simple line-based splitting for now
    lines = chunk.content.split('\n')
    sub_chunks = []
    current_lines = []
    current_size = 0
    
    for line in lines:
        line_tokens = count_tokens(line)
        
        if current_size + line_tokens > MAX_CHUNK_TOKENS and current_lines:
            # Create sub-chunk
            sub_content = '\n'.join(current_lines)
            if sub_content.strip():
                sub_chunk = Chunk(
                    start_byte=chunk.start_byte,  # Approximate
                    end_byte=chunk.start_byte + len(sub_content),
                    content=sub_content,
                    node_type=f"{chunk.node_type}_part",
                    name=f"{chunk.name}_part_{len(sub_chunks)+1}",
                    depth=depth + 1
                )
                sub_chunks.append(sub_chunk)
            
            current_lines = [line]
            current_size = line_tokens
        else:
            current_lines.append(line)
            current_size += line_tokens
    
    # Add remaining lines
    if current_lines:
        sub_content = '\n'.join(current_lines)
        if sub_content.strip():
            sub_chunk = Chunk(
                start_byte=chunk.start_byte,
                end_byte=chunk.end_byte,
                content=sub_content,
                node_type=f"{chunk.node_type}_part",
                name=f"{chunk.name}_part_{len(sub_chunks)+1}",
                depth=depth + 1
            )
            sub_chunks.append(sub_chunk)
    
    chunk.sub_chunks = sub_chunks
    return sub_chunks if len(sub_chunks) > 1 else [chunk]

def process_tsx_file(file_path: Path) -> List[Chunk]:
    """Process a single .tsx file and return semantic chunks"""
    print(f"\n=== Processing: {file_path.name} ===")
    
    # Read file
    with open(file_path, 'r', encoding='utf-8') as f:
        source_code = f.read()
    
    print(f"File size: {len(source_code)} characters")
    
    # Parse with Tree-sitter TSX parser
    tree = parser.parse(source_code.encode('utf-8'))
    
    if tree.root_node.has_error:
        print("⚠️ Parse errors detected")
    
    # Find semantic chunks
    semantic_nodes = find_semantic_chunks(tree, source_code)
    print(f"Found {len(semantic_nodes)} semantic units")
    
    # Show what we found
    for node in semantic_nodes:
        preview = node['content'][:100].replace('\n', ' ').strip()
        print(f"  - {node['type']}: {node['name']} ({count_tokens(node['content'])} tokens)")
        print(f"    Preview: {preview}...")
    
    # Create chunks
    base_chunks = create_semantic_chunks(semantic_nodes)
    print(f"Created {len(base_chunks)} semantic chunks")
    
    # Apply sub-chunking for oversized chunks
    final_chunks = []
    oversized_count = 0
    
    for chunk in base_chunks:
        if chunk.token_count > MAX_CHUNK_TOKENS:
            print(f"  Sub-chunking {chunk.name} ({chunk.token_count} tokens)")
            sub_chunks = sub_chunk_by_statements(chunk, tree, source_code)
            final_chunks.extend(sub_chunks)
            oversized_count += 1
        else:
            final_chunks.append(chunk)
    
    if oversized_count > 0:
        print(f"Sub-chunked {oversized_count} oversized chunks")
    print(f"Final result: {len(final_chunks)} total chunks")
    
    return final_chunks

def print_chunk_summary(chunks: List[Chunk], file_name: str):
    """Print detailed summary of chunks"""
    print(f"\n--- Semantic Chunk Summary for {file_name} ---")
    
    for i, chunk in enumerate(chunks, 1):
        indent = "  " * chunk.depth
        content_lines = len(chunk.content.split('\n'))
        
        print(f"{indent}{i}. {chunk.name}")
        print(f"{indent}   Type: {chunk.node_type}")
        print(f"{indent}   Size: {chunk.token_count} tokens, {content_lines} lines")
        print(f"{indent}   Content preview:")
        
        # Show first few lines of actual content
        content_lines_list = chunk.content.split('\n')
        for j, line in enumerate(content_lines_list[:3]):
            print(f"{indent}     {line.strip()}")
        if len(content_lines_list) > 3:
            print(f"{indent}     ... ({len(content_lines_list) - 3} more lines)")
        print()

def main():
    """Main function to test semantic chunking"""
    print("🚀 Semantic TSX Chunking Test")
    print(f"Max chunk tokens: {MAX_CHUNK_TOKENS}")
    print(f"Max recursion depth: {MAX_RECURSION_DEPTH}")
    
    # Get directory from user or use current directory
    directory = input("\nEnter directory path (or press Enter for current directory): ").strip()
    if not directory:
        directory = "."
    
    target_dir = Path(directory)
    if not target_dir.exists():
        print(f"❌ Directory not found: {directory}")
        return
    
    # Find all .tsx files
    tsx_files = list(target_dir.rglob("*.tsx"))
    
    if not tsx_files:
        print(f"❌ No .tsx files found in {directory}")
        return
    
    print(f"📁 Found {len(tsx_files)} .tsx files")
    
    # Process each file
    all_chunks = []
    for file_path in tsx_files:
        try:
            chunks = process_tsx_file(file_path)
            all_chunks.extend(chunks)
            print_chunk_summary(chunks, file_path.name)
        except Exception as e:
            print(f"❌ Error processing {file_path}: {e}")
    
    # Overall summary
    print(f"\n🎉 OVERALL SUMMARY")
    print(f"Files processed: {len(tsx_files)}")
    print(f"Total chunks created: {len(all_chunks)}")
    
    if all_chunks:
        avg_tokens = sum(c.token_count for c in all_chunks) / len(all_chunks)
        max_tokens = max(c.token_count for c in all_chunks)
        min_tokens = min(c.token_count for c in all_chunks)
        
        print(f"Average chunk size: {avg_tokens:.0f} tokens")
        print(f"Largest chunk: {max_tokens} tokens")
        print(f"Smallest chunk: {min_tokens} tokens")
        
        # Count by node type
        type_counts = {}
        for chunk in all_chunks:
            type_counts[chunk.node_type] = type_counts.get(chunk.node_type, 0) + 1
        
        print(f"\nChunk types:")
        for node_type, count in sorted(type_counts.items()):
            print(f"  {node_type}: {count}")
        
        print("\nChunk Data:")
        for chunk in all_chunks:
            print(f"\nChunk Name: {chunk.name}")
            print(f"\nChunk Content: {chunk.content}")
            print("\n============================")


if __name__ == "__main__":
    main()
# Out:
# ✅ Using TSX parser for React TypeScript files
# 🚀 Semantic TSX Chunking Test
# Max chunk tokens: 1000
# Max recursion depth: 3
# 📁 Found 2 .tsx files
#
# === Processing: Accordion.tsx ===
# File size: 2780 characters
# Found 2 semantic units
#   - export_statement: interface_AccordionProps (182 tokens)
#     Preview: export interface AccordionProps   extends Omit<ComponentPropsWithoutRef<"div">, "onToggle"> {   /**...
#   - export_statement: const_Accordion (353 tokens)
#     Preview: export const Accordion = forwardRef<HTMLDivElement, AccordionProps>(   function Accordion(props, ref...
# Created 2 semantic chunks
# Final result: 2 total chunks
#
# --- Semantic Chunk Summary for Accordion.tsx ---
# 1. interface_AccordionProps
#    Type: export_statement
#    Size: 182 tokens, 31 lines
#    Content preview:
#      export interface AccordionProps
#      extends Omit<ComponentPropsWithoutRef<"div">, "onToggle"> {
#      /**
#      ... (28 more lines)
#
# 2. const_Accordion
#    Type: export_statement
#    Size: 353 tokens, 69 lines
#    Content preview:
#      export const Accordion = forwardRef<HTMLDivElement, AccordionProps>(
#      function Accordion(props, ref) {
#      const {
#      ... (66 more lines)
#
#
# === Processing: ComboBox.tsx ===
# File size: 13268 characters
# Found 2 semantic units
#   - export_statement: export_statement (79 tokens)
#     Preview: export type ComboBoxProps<Item = string> = {   /**    * The options to display in the combo box....
#   - export_statement: const_ComboBox (2718 tokens)
#     Preview: export const ComboBox = forwardRef(function ComboBox<Item>(   props: ComboBoxProps<Item>,   ref: For...
# Created 2 semantic chunks
#   Sub-chunking const_ComboBox (2718 tokens)
#     Breaking down const_ComboBox (2718 tokens) into smaller pieces...
# Sub-chunked 1 oversized chunks
# Final result: 4 total chunks
#
# --- Semantic Chunk Summary for ComboBox.tsx ---
# 1. export_statement
#    Type: export_statement
#    Size: 79 tokens, 11 lines
#    Content preview:
#      export type ComboBoxProps<Item = string> = {
#      /**
#      * The options to display in the combo box.
#      ... (8 more lines)
#
#   2. const_ComboBox_part_1
#      Type: export_statement_part
#      Size: 1001 tokens, 176 lines
#      Content preview:
#        export const ComboBox = forwardRef(function ComboBox<Item>(
#        props: ComboBoxProps<Item>,
#        ref: ForwardedRef<HTMLDivElement>,
#        ... (173 more lines)
#
#   3. const_ComboBox_part_2
#      Type: export_statement_part
#      Size: 999 tokens, 172 lines
#      Content preview:
#        }
#
#        let newActive:
#        ... (169 more lines)
#
#   4. const_ComboBox_part_3
#      Type: export_statement_part
#      Size: 717 tokens, 99 lines
#      Content preview:
#        aria-labelledby={clsx(buttonId, formFieldLabelledBy)}
#        aria-label="Show options"
#        aria-expanded={openState}
#        ... (96 more lines)
#
#
# 🎉 OVERALL SUMMARY
# Files processed: 2
# Total chunks created: 6
# Average chunk size: 555 tokens
# Largest chunk: 1001 tokens
# Smallest chunk: 79 tokens
#
# Chunk types:
#   export_statement: 3
#   export_statement_part: 3
#
# Chunk Data:
#
# Chunk Name: interface_AccordionProps
#
# Chunk Content: export interface AccordionProps
#   extends Omit<ComponentPropsWithoutRef<"div">, "onToggle"> {
#   /**
#    * AccordionGroup value.
#    */
#   value: string;
#   /**
#    * Whether the accordion is expanded.
#    */
#   expanded?: boolean;
#   /**
#    * Whether the accordion is expanded by default.
#    */
#   defaultExpanded?: boolean;
#   /**
#    * Side to align the Accordion's indicator. Defaults to `left`.
#    */
#   indicatorSide?: "left" | "right";
#   /**
#    * Callback fired when the accordion is toggled.
#    */
#   onToggle?: (event: SyntheticEvent<HTMLButtonElement>) => void;
#   /**
#    * Whether the accordion is disabled.
#    */
#   disabled?: boolean;
#   /**
#    * The status of the accordion.
#    */
#   status?: "error" | "warning" | "success";
# }
#
# ============================
#
# Chunk Name: const_Accordion
#
# Chunk Content: export const Accordion = forwardRef<HTMLDivElement, AccordionProps>(
#   function Accordion(props, ref) {
#     const {
#       className,
#       defaultExpanded,
#       expanded: expandedProp,
#       disabled,
#       indicatorSide = "left",
#       id: idProp,
#       onToggle,
#       status,
#       value,
#       ...rest
#     } = props;
#
#     const id = useId(idProp);
#     const [headerId, setHeaderId] = useState(`${id}-header`);
#     const [panelId, setPanelId] = useState(`${id}-panel`);
#
#     const targetWindow = useWindow();
#     useComponentCssInjection({
#       testId: "salt-accordion",
#       css: accordionCss,
#       window: targetWindow,
#     });
#
#     const [expanded, setExpanded] = useControlled({
#       controlled: expandedProp,
#       default: Boolean(defaultExpanded),
#       name: "Accordion",
#       state: "expanded",
#     });
#
#     const toggle = (event: SyntheticEvent<HTMLButtonElement>) => {
#       setExpanded((prev) => !prev);
#       onToggle?.(event);
#     };
#
#     return (
#       <AccordionContext.Provider
#         value={{
#           value,
#           toggle,
#           expanded,
#           indicatorSide,
#           disabled: Boolean(disabled),
#           headerId,
#           setHeaderId,
#           panelId,
#           setPanelId,
#           status,
#         }}
#       >
#         <div
#           ref={ref}
#           className={clsx(
#             withBaseName(),
#             {
#               [withBaseName(status ?? "")]: status,
#               [withBaseName("disabled")]: disabled,
#             },
#             className,
#           )}
#           {...rest}
#         />
#       </AccordionContext.Provider>
#     );
#   },
# );
#
# ============================
#
# Chunk Name: export_statement
#
# Chunk Content: export type ComboBoxProps<Item = string> = {
#   /**
#    * The options to display in the combo box.
#    */
#   children?: ReactNode;
#   /**
#    * If true, options will be selected on tab key press.
#    */
#   selectOnTab?: boolean;
# } & UseComboBoxProps<Item> &
#   Omit<PillInputProps, "onPillRemove">;
#
# ============================
#
# Chunk Name: const_ComboBox_part_1
#
# Chunk Content: export const ComboBox = forwardRef(function ComboBox<Item>(
#   props: ComboBoxProps<Item>,
#   ref: ForwardedRef<HTMLDivElement>,
# ) {
#   const {
#     children,
#     className,
#     disabled: disabledProp,
#     endAdornment: endAdornmentProp,
#     readOnly: readOnlyProp,
#     multiselect,
#     selectOnTab = !multiselect,
#     onSelectionChange,
#     selected,
#     defaultSelected,
#     defaultOpen,
#     onOpenChange,
#     onChange,
#     open,
#     inputRef: inputRefProp,
#     inputProps: inputPropsProp,
#     variant = "primary",
#     onKeyDown,
#     onFocus,
#     onBlur,
#     value,
#     defaultValue,
#     valueToString = defaultValueToString,
#     truncate,
#     bordered = false,
#     ...rest
#   } = props;
#
#   const targetWindow = useWindow();
#   useComponentCssInjection({
#     testId: "salt-combo-box",
#     css: comboBoxCss,
#     window: targetWindow,
#   });
#   const { CollapseIcon, ExpandIcon } = useIcon();
#   const {
#     a11yProps: { "aria-labelledby": formFieldLabelledBy } = {},
#     disabled: formFieldDisabled,
#     readOnly: formFieldReadOnly,
#   } = useFormFieldProps();
#
#   const disabled = Boolean(disabledProp) || formFieldDisabled;
#   const readOnly = Boolean(readOnlyProp) || formFieldReadOnly;
#   const inputRef = useRef<HTMLInputElement>(null);
#   const handleInputRef = useForkRef(inputRef, inputRefProp);
#
#   const listControl = useComboBox<Item>({
#     open,
#     defaultOpen,
#     onOpenChange,
#     multiselect,
#     defaultSelected,
#     selected,
#     onSelectionChange,
#     value,
#     defaultValue,
#     disabled,
#     readOnly,
#     valueToString,
#   });
#
#   const {
#     activeState,
#     setActive,
#     openState,
#     setOpen,
#     openKey,
#     getIndexOfOption,
#     getOptionsMatching,
#     getFirstOption,
#     getLastOption,
#     getOptionAfter,
#     getOptionBefore,
#     getOptionPageAbove,
#     getOptionPageBelow,
#     selectedState,
#     select,
#     clear,
#     focusVisibleState,
#     setFocusVisibleState,
#     focusedState,
#     setFocusedState,
#     listRef,
#     valueState,
#     setValueState,
#     removePill,
#   } = listControl;
#
#   const handleOpenChange: UseFloatingUIProps["onOpenChange"] = (
#     newOpen,
#     _event,
#     reason,
#   ) => {
#     const focusNotBlur = reason === "focus" && newOpen;
#     if (reason === "focus") {
#       setFocusedState(newOpen);
#     }
#
#     if (reason === "focus" && !newOpen) {
#       setFocusVisibleState(false);
#     }
#
#     if (readOnly || focusNotBlur) return;
#     setOpen(newOpen);
#
#     if (newOpen) {
#       inputRef.current?.focus();
#     }
#   };
#
#   const hasValidChildren =
#     Children.toArray(children).filter(Boolean).length > 0;
#
#   const { x, y, strategy, elements, floating, reference, context } =
#     useFloatingUI({
#       open: openState && !readOnly && hasValidChildren,
#       onOpenChange: handleOpenChange,
#       placement: "bottom-start",
#       strategy: "fixed",
#       middleware: [
#         offset(1),
#         size({
#           apply({ rects, elements, availableHeight }) {
#             Object.assign(elements.floating.style, {
#               minWidth: `${rects.reference.width}px`,
#               maxHeight: `max(calc(${availableHeight}px - var(--salt-spacing-100)), calc((var(--salt-size-base) + var(--salt-spacing-100)) * 5))`,
#             });
#           },
#         }),
#         flip({ fallbackStrategy: "initialPlacement" }),
#       ],
#     });
#
#   const { getReferenceProps, getFloatingProps } = useInteractions([
#     useDismiss(context),
#     useFocus(context),
#     useClick(context, { keyboardHandlers: false, toggle: false }),
#   ]);
#
#   const handleRef = useForkRef<HTMLDivElement>(reference, ref);
#
#   const handleButtonClick = (event: MouseEvent<HTMLButtonElement>) => {
#     if (!readOnly) {
#       event.stopPropagation();
#       setFocusVisibleState(false);
#       setOpen(!openState, "manual");
#     }
#   };
#
#   const handleButtonFocus = () => {
#     inputRef.current?.focus();
#   };
#
#   const handleKeyDown = (event: KeyboardEvent<HTMLInputElement>) => {
#     onKeyDown?.(event);
#
#     if (readOnly) {
#       return;
#     }
#
#     if (!openState) {
#       if (event.key === "ArrowDown" || event.key === "ArrowUp") {
#         setOpen(true, undefined, event.key);
#         return;
#       }
#     }
#
#     const activeOption = activeState ?? getFirstOption()?.data;
#
#     if (activeOption === undefined) {
#       return;
#
# ============================
#
# Chunk Name: const_ComboBox_part_2
#
# Chunk Content:     }
#
#     let newActive:
#       | { data: OptionValue<Item>; element: HTMLElement }
#       | undefined;
#     switch (event.key) {
#       case "ArrowDown":
#         newActive = getOptionAfter(activeOption) ?? getLastOption();
#         break;
#       case "ArrowUp":
#         newActive = getOptionBefore(activeOption) ?? getFirstOption();
#         break;
#       case "Home":
#         newActive = getFirstOption();
#         break;
#       case "End":
#         newActive = getLastOption();
#         break;
#       case "PageUp":
#         newActive = getOptionPageAbove(activeOption);
#         break;
#       case "PageDown":
#         newActive = getOptionPageBelow(activeOption);
#         break;
#       case "Enter":
#         if (openState && activeState?.disabled) {
#           event.preventDefault();
#           return;
#         }
#
#         if (!openState || !activeState) {
#           return;
#         }
#
#         select(event, activeState);
#
#         if (!multiselect) {
#           event.preventDefault();
#         }
#
#         break;
#       case "Tab":
#         if (
#           openState &&
#           selectOnTab &&
#           activeState &&
#           !activeState?.disabled &&
#           !selectedState.includes(activeState?.value)
#         ) {
#           select(event, activeState);
#         }
#         break;
#     }
#
#     if (newActive) {
#       setFocusVisibleState(true);
#     }
#
#     if (newActive && newActive.data.id !== activeState?.id) {
#       event.preventDefault();
#       setActive(newActive.data);
#     }
#   };
#
#   const handleFocus = (event: FocusEvent<HTMLInputElement>) => {
#     setFocusedState(true);
#     onFocus?.(event);
#   };
#
#   const handleBlur = (event: FocusEvent<HTMLInputElement>) => {
#     event.persist();
#     if (!listRef.current || !listRef.current.contains(event.relatedTarget)) {
#       onBlur?.(event);
#     }
#   };
#
#   const handleChange = (event: ChangeEvent<HTMLInputElement>) => {
#     const value = event.target.value;
#
#     if (!openState) {
#       setOpen(true, "input");
#     }
#
#     if (value === "" && !multiselect) {
#       clear(event);
#     }
#
#     setValueState(value);
#
#     // Wait for the filter to happen
#     queueMicrotask(() => {
#       if (value !== "") {
#         const newOption = getFirstOption();
#         if (newOption) {
#           setActive(newOption.data);
#         }
#       } else {
#         setActive(undefined);
#       }
#     });
#
#     onChange?.(event);
#   };
#
#   const handlePillRemove = (event: SyntheticEvent, index: number) => {
#     event.stopPropagation();
#     const removed = selectedState[index];
#     removePill(event, removed);
#   };
#
#   const handleListMouseOver = () => {
#     setFocusVisibleState(false);
#   };
#
#   const handleListMouseLeave = () => {
#     setActive(undefined);
#   };
#
#   const handleFocusInput = () => {
#     inputRef.current?.focus();
#   };
#
#   // biome-ignore lint/correctness/useExhaustiveDependencies: We only want this to run when the list's openState or the displayed options change.
#   useEffect(() => {
#     // If the list is closed we should clear the active item
#     if (!openState) {
#       setActive(undefined);
#       return;
#     }
#
#     // We check the active index because the active item may have been removed
#     const activeIndex = activeState ? getIndexOfOption(activeState) : -1;
#     let newActive: ReturnType<typeof getFirstOption>;
#
#     // If the active item is still in the list, we don't need to do anything
#     if (activeIndex > -1) {
#       return;
#     }
#
#     // If we have selected an item, we should make that the active item
#     if (selectedState.length > 0) {
#       newActive = getOptionsMatching(
#         (option) => option.value === selectedState[0],
#       ).pop();
#     }
#
#     // If we still don't have an active item, we should check if the list has been opened with the keyboard
#     if (!newActive) {
#       if (openKey.current === "ArrowDown") {
#         newActive = getFirstOption();
#         setFocusVisibleState(true);
#       } else if (openKey.current === "ArrowUp") {
#         newActive = getLastOption();
#         setFocusVisibleState(true);
#       }
#     }
#
#     // If we still don't have an active item, we should just select the first item
#     if (!newActive) {
#       newActive = getFirstOption();
#     }
#
#     setActive(newActive?.data);
#   }, [openState, children]);
#
#   const buttonId = useId();
#   const listId = useId();
#
#   const handleListRef = useForkRef<HTMLDivElement>(listRef, floating);
#
#   const showOptionsButton = (
#     <Button
#
# ============================
#
# Chunk Name: const_ComboBox_part_3
#
# Chunk Content:       aria-labelledby={clsx(buttonId, formFieldLabelledBy)}
#       aria-label="Show options"
#       aria-expanded={openState}
#       aria-controls={openState ? listId : undefined}
#       aria-haspopup="listbox"
#       disabled={disabled}
#       appearance="transparent"
#       onClick={handleButtonClick}
#       onFocus={handleButtonFocus}
#       tabIndex={-1}
#     >
#       {openState ? <CollapseIcon aria-hidden /> : <ExpandIcon aria-hidden />}
#     </Button>
#   );
#
#   // avoid render empty fragment, or empty div appear in PillInput
#   const endAdornment =
#     !readOnly && hasValidChildren ? (
#       <>
#         {endAdornmentProp}
#         {showOptionsButton}
#       </>
#     ) : (
#       endAdornmentProp
#     );
#
#   return (
#     <ListControlContext.Provider value={listControl}>
#       <PillInput
#         // Ensures that the field is focused when you don't directly click on the input.
#         tabIndex={!disabled ? -1 : undefined}
#         className={clsx(
#           withBaseName(),
#           {
#             [withBaseName("focused")]: focusedState,
#             [withBaseName("focusVisible")]: focusVisibleState,
#           },
#           className,
#         )}
#         endAdornment={endAdornment}
#         onChange={handleChange}
#         // Workaround to have readonly conveyed by screen readers (https://github.com/jpmorganchase/salt-ds/issues/4586)
#         role={readOnly ? "textbox" : "combobox"}
#         disabled={disabled}
#         readOnly={readOnly}
#         inputProps={{
#           "aria-readonly": readOnly ? "true" : undefined,
#           "aria-expanded": !readOnly ? openState : undefined,
#           "aria-controls": openState && !readOnly ? listId : undefined,
#           onKeyDown: handleKeyDown,
#           ...inputPropsProp,
#         }}
#         aria-activedescendant={activeState?.id}
#         variant={variant}
#         inputRef={handleInputRef}
#         value={valueState}
#         ref={handleRef}
#         bordered={bordered}
#         {...getReferenceProps({
#           onBlur: handleBlur,
#           onFocus: handleFocus,
#           ...rest,
#         })}
#         pills={
#           multiselect ? selectedState.map((item) => valueToString(item)) : []
#         }
#         truncate={truncate && !focusedState && !openState}
#         onPillRemove={handlePillRemove}
#         hidePillClose={!focusedState || readOnly}
#         emptyReadOnlyMarker={
#           readOnly && selectedState.length > 0 ? "" : undefined
#         }
#       />
#       <OptionList
#         aria-multiselectable={multiselect}
#         open={(openState || focusedState) && !readOnly && hasValidChildren}
#         collapsed={!openState}
#         ref={handleListRef}
#         id={listId}
#         tabIndex={-1}
#         {...getFloatingProps({
#           onMouseOver: handleListMouseOver,
#           onFocus: handleFocusInput,
#           onClick: handleFocusInput,
#           onMouseLeave: handleListMouseLeave,
#         })}
#         left={x ?? 0}
#         top={y ?? 0}
#         position={strategy}
#         width={elements.floating?.offsetWidth}
#         height={elements.floating?.offsetHeight}
#       >
#         {children}
#       </OptionList>
#     </ListControlContext.Provider>
#   );
# }) as <Item = string>(
#   props: ComboBoxProps<Item> & { ref?: Ref<HTMLDivElement> },
# ) => JSX.Element;
#
# ============================

# %% [markdown]
# The minimal changes I made:
#
# Added SUPPORTED_EXTENSIONS list with all 4 file types
# Added get_syntax_highlighting_language() function to map extensions to proper syntax highlighting
# Renamed function from process_tsx_file to process_js_ts_file
# Updated file discovery to search for all supported extensions using rglob()
# Added file type display in processing output
# Updated console messages to reflect multi-language support
#
# The TSX parser handles all these file types correctly:
#
# .tsx - Full TypeScript + JSX support
# .ts - TypeScript (just ignores JSX parts)
# .js - JavaScript (ignores TypeScript-specific syntax)
# .jsx - JavaScript + JSX
#
# No other changes needed - the semantic chunking logic works the same across all these file types!

# %%
#!/usr/bin/env python3

import os
from pathlib import Path
from typing import List, Dict, Any
import tiktoken

# Tree-sitter setup for TypeScript/JavaScript files
try:
    from tree_sitter_language_pack import get_language, get_parser
    tsx_language = get_language('tsx')
    parser = get_parser('tsx')
    print("✅ Using TSX parser for TypeScript/JavaScript files")
except ImportError:
    print("Please install: pip install tree-sitter-languages")
    exit(1)

# Configuration
MAX_CHUNK_TOKENS = 1000
MAX_RECURSION_DEPTH = 3

# Supported file extensions
SUPPORTED_EXTENSIONS = ['.tsx', '.ts', '.js', '.jsx']

# Initialize token encoder
encoder = tiktoken.get_encoding("cl100k_base")

def count_tokens(text: str) -> int:
    """Count tokens in text"""
    return len(encoder.encode(text))

def get_syntax_highlighting_language(file_extension: str) -> str:
    """Get appropriate syntax highlighting language for markdown output"""
    language_map = {
        '.tsx': 'tsx',
        '.ts': 'typescript', 
        '.js': 'javascript',
        '.jsx': 'jsx'
    }
    return language_map.get(file_extension, 'javascript')

class Chunk:
    def __init__(self, start_byte: int, end_byte: int, content: str, node_type: str, name: str, depth: int = 0):
        self.start_byte = start_byte
        self.end_byte = end_byte
        self.content = content
        self.node_type = node_type
        self.name = name
        self.depth = depth
        self.token_count = count_tokens(content)
        self.sub_chunks = []

def extract_node_name(node, source_code: str) -> str:
    """Extract meaningful name from AST node"""
    node_text = source_code[node.start_byte:node.end_byte]
    lines = node_text.split('\n')
    
    import re
    
    # Try different patterns based on node type
    if node.type == 'function_declaration':
        match = re.search(r'function\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
        if match:
            return match.group(1)
    
    elif node.type == 'variable_declaration':
        # Look for const/let ComponentName = forwardRef or const hook = 
        match = re.search(r'(?:const|let|var)\s+([a-zA-Z_$][a-zA-Z0-9_$]*)\s*=', node_text)
        if match:
            return match.group(1)
    
    elif node.type == 'interface_declaration':
        match = re.search(r'interface\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
        if match:
            return match.group(1)
    
    elif node.type == 'type_alias_declaration':
        match = re.search(r'type\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
        if match:
            return match.group(1)
    
    elif node.type == 'class_declaration':
        match = re.search(r'class\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
        if match:
            return match.group(1)
    
    elif node.type == 'export_statement':
        # Handle various export patterns
        if 'export interface' in node_text:
            match = re.search(r'export\s+interface\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
            if match:
                return f"interface_{match.group(1)}"
        elif 'export const' in node_text:
            match = re.search(r'export\s+const\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
            if match:
                return f"const_{match.group(1)}"
        elif 'export function' in node_text:
            match = re.search(r'export\s+function\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
            if match:
                return f"function_{match.group(1)}"
        elif 'export default' in node_text:
            return "default_export"
        else:
            return "export_statement"
    
    # Fallback
    first_line = lines[0][:50].strip()
    simple_match = re.search(r'\b([a-zA-Z_$][a-zA-Z0-9_$]*)', first_line)
    if simple_match:
        return simple_match.group(1)
    
    return f"{node.type}_{node.start_byte}"

def find_semantic_chunks(tree, source_code: str) -> List[Dict[str, Any]]:
    """Find semantic chunks - complete, meaningful code blocks"""
    semantic_nodes = []
    
    def traverse(node, parent_types=None):
        if parent_types is None:
            parent_types = []
        
        current_parent_types = parent_types + [node.type]
        
        # Check if this is a top-level semantic unit
        node_text = source_code[node.start_byte:node.end_byte]
        
        # Top-level function declarations
        if node.type == 'function_declaration' and len(parent_types) <= 1:
            name = extract_node_name(node, source_code)
            semantic_nodes.append({
                'node': node,
                'name': name,
                'start_byte': node.start_byte,
                'end_byte': node.end_byte,
                'type': node.type,
                'content': node_text
            })
            return  # Don't traverse children - we want the whole function
        
        # Top-level interfaces and types (TypeScript specific)
        elif node.type in ['interface_declaration', 'type_alias_declaration'] and len(parent_types) <= 1:
            name = extract_node_name(node, source_code)
            semantic_nodes.append({
                'node': node,
                'name': name,
                'start_byte': node.start_byte,
                'end_byte': node.end_byte,
                'type': node.type,
                'content': node_text
            })
            return
        
        # Top-level variable declarations (components, hooks, constants)
        elif node.type == 'variable_declaration' and len(parent_types) <= 1:
            # Check if it looks like a component or important declaration
            if any(pattern in node_text for pattern in ['forwardRef', '= (' , 'useState', 'useEffect', 'createContext', 'makePrefixer']):
                name = extract_node_name(node, source_code)
                semantic_nodes.append({
                    'node': node,
                    'name': name,
                    'start_byte': node.start_byte,
                    'end_byte': node.end_byte,
                    'type': 'component_or_hook',
                    'content': node_text
                })
                return
        
        # Top-level export statements (but check what they're exporting)
        elif node.type == 'export_statement' and len(parent_types) <= 1:
            name = extract_node_name(node, source_code)
            # Only include if it's a substantial export (not just a re-export)
            if len(node_text.strip()) > 50:  # Substantial content
                semantic_nodes.append({
                    'node': node,
                    'name': name,
                    'start_byte': node.start_byte,
                    'end_byte': node.end_byte,
                    'type': node.type,
                    'content': node_text
                })
                return
        
        # Continue traversing children for other nodes
        for child in node.children:
            traverse(child, current_parent_types)
    
    traverse(tree.root_node)
    
    # Sort by start position and remove overlaps
    semantic_nodes.sort(key=lambda x: x['start_byte'])
    
    # Remove nested/overlapping nodes
    filtered_nodes = []
    for node in semantic_nodes:
        # Check if this node is contained within any existing node
        is_contained = False
        for existing in filtered_nodes:
            if (existing['start_byte'] <= node['start_byte'] and 
                existing['end_byte'] >= node['end_byte']):
                is_contained = True
                break
        
        if not is_contained:
            # Also check if this node contains any existing nodes
            to_remove = []
            for i, existing in enumerate(filtered_nodes):
                if (node['start_byte'] <= existing['start_byte'] and 
                    node['end_byte'] >= existing['end_byte']):
                    to_remove.append(i)
            
            # Remove contained nodes
            for i in reversed(to_remove):
                filtered_nodes.pop(i)
            
            filtered_nodes.append(node)
    
    return filtered_nodes

def create_semantic_chunks(semantic_nodes: List[Dict[str, Any]]) -> List[Chunk]:
    """Create chunks from semantic nodes"""
    chunks = []
    
    for node_info in semantic_nodes:
        chunk = Chunk(
            start_byte=node_info['start_byte'],
            end_byte=node_info['end_byte'],
            content=node_info['content'],
            node_type=node_info['type'],
            name=node_info['name'],
            depth=0
        )
        chunks.append(chunk)
    
    return chunks

def sub_chunk_by_statements(chunk: Chunk, tree, source_code: str, depth: int = 0) -> List[Chunk]:
    """Sub-chunk by breaking down into logical statements/blocks"""
    if depth >= MAX_RECURSION_DEPTH or chunk.token_count <= MAX_CHUNK_TOKENS:
        return [chunk]
    
    print(f"    Breaking down {chunk.name} ({chunk.token_count} tokens) into smaller pieces...")
    
    # Simple line-based splitting for now
    lines = chunk.content.split('\n')
    sub_chunks = []
    current_lines = []
    current_size = 0
    
    for line in lines:
        line_tokens = count_tokens(line)
        
        if current_size + line_tokens > MAX_CHUNK_TOKENS and current_lines:
            # Create sub-chunk
            sub_content = '\n'.join(current_lines)
            if sub_content.strip():
                sub_chunk = Chunk(
                    start_byte=chunk.start_byte,  # Approximate
                    end_byte=chunk.start_byte + len(sub_content),
                    content=sub_content,
                    node_type=f"{chunk.node_type}_part",
                    name=f"{chunk.name}_part_{len(sub_chunks)+1}",
                    depth=depth + 1
                )
                sub_chunks.append(sub_chunk)
            
            current_lines = [line]
            current_size = line_tokens
        else:
            current_lines.append(line)
            current_size += line_tokens
    
    # Add remaining lines
    if current_lines:
        sub_content = '\n'.join(current_lines)
        if sub_content.strip():
            sub_chunk = Chunk(
                start_byte=chunk.start_byte,
                end_byte=chunk.end_byte,
                content=sub_content,
                node_type=f"{chunk.node_type}_part",
                name=f"{chunk.name}_part_{len(sub_chunks)+1}",
                depth=depth + 1
            )
            sub_chunks.append(sub_chunk)
    
    chunk.sub_chunks = sub_chunks
    return sub_chunks if len(sub_chunks) > 1 else [chunk]

def process_js_ts_file(file_path: Path) -> List[Chunk]:
    """Process a single JavaScript/TypeScript file and return semantic chunks"""
    print(f"\n=== Processing: {file_path.name} ===")
    
    # Read file
    with open(file_path, 'r', encoding='utf-8') as f:
        source_code = f.read()
    
    print(f"File size: {len(source_code)} characters")
    print(f"File type: {file_path.suffix}")
    
    # Parse with Tree-sitter TSX parser (works for all JS/TS variants)
    tree = parser.parse(source_code.encode('utf-8'))
    
    if tree.root_node.has_error:
        print("⚠️ Parse errors detected")
    
    # Find semantic chunks
    semantic_nodes = find_semantic_chunks(tree, source_code)
    print(f"Found {len(semantic_nodes)} semantic units")
    
    # Show what we found
    for node in semantic_nodes:
        preview = node['content'][:100].replace('\n', ' ').strip()
        print(f"  - {node['type']}: {node['name']} ({count_tokens(node['content'])} tokens)")
        print(f"    Preview: {preview}...")
    
    # Create chunks
    base_chunks = create_semantic_chunks(semantic_nodes)
    print(f"Created {len(base_chunks)} semantic chunks")
    
    # Apply sub-chunking for oversized chunks
    final_chunks = []
    oversized_count = 0
    
    for chunk in base_chunks:
        if chunk.token_count > MAX_CHUNK_TOKENS:
            print(f"  Sub-chunking {chunk.name} ({chunk.token_count} tokens)")
            sub_chunks = sub_chunk_by_statements(chunk, tree, source_code)
            final_chunks.extend(sub_chunks)
            oversized_count += 1
        else:
            final_chunks.append(chunk)
    
    if oversized_count > 0:
        print(f"Sub-chunked {oversized_count} oversized chunks")
    print(f"Final result: {len(final_chunks)} total chunks")
    
    return final_chunks

def print_chunk_summary(chunks: List[Chunk], file_name: str):
    """Print detailed summary of chunks"""
    print(f"\n--- Semantic Chunk Summary for {file_name} ---")
    
    for i, chunk in enumerate(chunks, 1):
        indent = "  " * chunk.depth
        content_lines = len(chunk.content.split('\n'))
        
        print(f"{indent}{i}. {chunk.name}")
        print(f"{indent}   Type: {chunk.node_type}")
        print(f"{indent}   Size: {chunk.token_count} tokens, {content_lines} lines")
        print(f"{indent}   Content preview:")
        
        # Show first few lines of actual content
        content_lines_list = chunk.content.split('\n')
        for j, line in enumerate(content_lines_list[:3]):
            print(f"{indent}     {line.strip()}")
        if len(content_lines_list) > 3:
            print(f"{indent}     ... ({len(content_lines_list) - 3} more lines)")
        print()

def main():
    """Main function to test semantic chunking"""
    print("🚀 Semantic JavaScript/TypeScript Chunking Test")
    print(f"Max chunk tokens: {MAX_CHUNK_TOKENS}")
    print(f"Max recursion depth: {MAX_RECURSION_DEPTH}")
    print(f"Supported extensions: {', '.join(SUPPORTED_EXTENSIONS)}")
    
    # Get directory from user or use current directory
    directory = input("\nEnter directory path (or press Enter for current directory): ").strip()
    if not directory:
        directory = "."
    
    target_dir = Path(directory)
    if not target_dir.exists():
        print(f"❌ Directory not found: {directory}")
        return
    
    # Find all supported files
    all_files = []
    for ext in SUPPORTED_EXTENSIONS:
        files = list(target_dir.rglob(f"*{ext}"))
        all_files.extend(files)
    
    if not all_files:
        print(f"❌ No supported files found in {directory}")
        print(f"Looking for: {', '.join(SUPPORTED_EXTENSIONS)}")
        return
    
    print(f"📁 Found {len(all_files)} supported files:")
    # Group by extension for summary
    by_ext = {}
    for f in all_files:
        ext = f.suffix
        by_ext[ext] = by_ext.get(ext, 0) + 1
    
    for ext, count in sorted(by_ext.items()):
        print(f"  {ext}: {count} files")
    
    # Process each file
    all_chunks = []
    for file_path in all_files:
        try:
            chunks = process_js_ts_file(file_path)
            all_chunks.extend(chunks)
            print_chunk_summary(chunks, file_path.name)
        except Exception as e:
            print(f"❌ Error processing {file_path}: {e}")
    
    # Overall summary
    print(f"\n🎉 OVERALL SUMMARY")
    print(f"Files processed: {len(all_files)}")
    print(f"Total chunks created: {len(all_chunks)}")
    
    if all_chunks:
        avg_tokens = sum(c.token_count for c in all_chunks) / len(all_chunks)
        max_tokens = max(c.token_count for c in all_chunks)
        min_tokens = min(c.token_count for c in all_chunks)
        
        print(f"Average chunk size: {avg_tokens:.0f} tokens")
        print(f"Largest chunk: {max_tokens} tokens")
        print(f"Smallest chunk: {min_tokens} tokens")
        
        # Count by node type
        type_counts = {}
        for chunk in all_chunks:
            type_counts[chunk.node_type] = type_counts.get(chunk.node_type, 0) + 1
        
        print(f"\nChunk types:")
        for node_type, count in sorted(type_counts.items()):
            print(f"  {node_type}: {count}")

if __name__ == "__main__":
    main()
# Out:
# ✅ Using TSX parser for TypeScript/JavaScript files
# 🚀 Semantic JavaScript/TypeScript Chunking Test
# Max chunk tokens: 1000
# Max recursion depth: 3
# Supported extensions: .tsx, .ts, .js, .jsx
# 📁 Found 7 supported files:
#   .ts: 2 files
#   .tsx: 5 files
#
# === Processing: AccordionPanel.tsx ===
# File size: 1754 characters
# File type: .tsx
# Found 2 semantic units
#   - export_statement: interface_AccordionPanelProps (36 tokens)
#     Preview: export interface AccordionPanelProps extends ComponentPropsWithoutRef<"div"> {   /**    * The conten...
#   - export_statement: const_AccordionPanel (269 tokens)
#     Preview: export const AccordionPanel = forwardRef<HTMLDivElement, AccordionPanelProps>(   function AccordionP...
# Created 2 semantic chunks
# Final result: 2 total chunks
#
# --- Semantic Chunk Summary for AccordionPanel.tsx ---
# 1. interface_AccordionPanelProps
#    Type: export_statement
#    Size: 36 tokens, 6 lines
#    Content preview:
#      export interface AccordionPanelProps extends ComponentPropsWithoutRef<"div"> {
#      /**
#      * The content of the Accordion Panel
#      ... (3 more lines)
#
# 2. const_AccordionPanel
#    Type: export_statement
#    Size: 269 tokens, 44 lines
#    Content preview:
#      export const AccordionPanel = forwardRef<HTMLDivElement, AccordionPanelProps>(
#      function AccordionPanel(props, ref) {
#      const { children, className, id, ...rest } = props;
#      ... (41 more lines)
#
#
# === Processing: AccordionHeader.tsx ===
# File size: 2522 characters
# File type: .tsx
# Found 3 semantic units
#   - export_statement: interface_AccordionHeaderProps (38 tokens)
#     Preview: export interface AccordionHeaderProps   extends ComponentPropsWithoutRef<"button"> {   /**    * The...
#   - function_declaration: ExpansionIcon (66 tokens)
#     Preview: function ExpansionIcon({ expanded }: { expanded: boolean }) {   const { CollapseIcon, ExpandIcon } =...
#   - export_statement: const_AccordionHeader (360 tokens)
#     Preview: export const AccordionHeader = forwardRef<   HTMLButtonElement,   AccordionHeaderProps >(function Ac...
# Created 3 semantic chunks
# Final result: 3 total chunks
#
# --- Semantic Chunk Summary for AccordionHeader.tsx ---
# 1. interface_AccordionHeaderProps
#    Type: export_statement
#    Size: 38 tokens, 7 lines
#    Content preview:
#      export interface AccordionHeaderProps
#      extends ComponentPropsWithoutRef<"button"> {
#      /**
#      ... (4 more lines)
#
# 2. ExpansionIcon
#    Type: function_declaration
#    Size: 66 tokens, 8 lines
#    Content preview:
#      function ExpansionIcon({ expanded }: { expanded: boolean }) {
#      const { CollapseIcon, ExpandIcon } = useIcon();
#      if (expanded) {
#      ... (5 more lines)
#
# 3. const_AccordionHeader
#    Type: export_statement
#    Size: 360 tokens, 64 lines
#    Content preview:
#      export const AccordionHeader = forwardRef<
#      HTMLButtonElement,
#      AccordionHeaderProps
#      ... (61 more lines)
#
#
# === Processing: Accordion.tsx ===
# File size: 2780 characters
# File type: .tsx
# Found 2 semantic units
#   - export_statement: interface_AccordionProps (182 tokens)
#     Preview: export interface AccordionProps   extends Omit<ComponentPropsWithoutRef<"div">, "onToggle"> {   /**...
#   - export_statement: const_Accordion (353 tokens)
#     Preview: export const Accordion = forwardRef<HTMLDivElement, AccordionProps>(   function Accordion(props, ref...
# Created 2 semantic chunks
# Final result: 2 total chunks
#
# --- Semantic Chunk Summary for Accordion.tsx ---
# 1. interface_AccordionProps
#    Type: export_statement
#    Size: 182 tokens, 31 lines
#    Content preview:
#      export interface AccordionProps
#      extends Omit<ComponentPropsWithoutRef<"div">, "onToggle"> {
#      /**
#      ... (28 more lines)
#
# 2. const_Accordion
#    Type: export_statement
#    Size: 353 tokens, 69 lines
#    Content preview:
#      export const Accordion = forwardRef<HTMLDivElement, AccordionProps>(
#      function Accordion(props, ref) {
#      const {
#      ... (66 more lines)
#
#
# === Processing: ComboBox.tsx ===
# File size: 13268 characters
# File type: .tsx
# Found 2 semantic units
#   - export_statement: export_statement (79 tokens)
#     Preview: export type ComboBoxProps<Item = string> = {   /**    * The options to display in the combo box....
#   - export_statement: const_ComboBox (2718 tokens)
#     Preview: export const ComboBox = forwardRef(function ComboBox<Item>(   props: ComboBoxProps<Item>,   ref: For...
# Created 2 semantic chunks
#   Sub-chunking const_ComboBox (2718 tokens)
#     Breaking down const_ComboBox (2718 tokens) into smaller pieces...
# Sub-chunked 1 oversized chunks
# Final result: 4 total chunks
#
# --- Semantic Chunk Summary for ComboBox.tsx ---
# 1. export_statement
#    Type: export_statement
#    Size: 79 tokens, 11 lines
#    Content preview:
#      export type ComboBoxProps<Item = string> = {
#      /**
#      * The options to display in the combo box.
#      ... (8 more lines)
#
#   2. const_ComboBox_part_1
#      Type: export_statement_part
#      Size: 1001 tokens, 176 lines
#      Content preview:
#        export const ComboBox = forwardRef(function ComboBox<Item>(
#        props: ComboBoxProps<Item>,
#        ref: ForwardedRef<HTMLDivElement>,
#        ... (173 more lines)
#
#   3. const_ComboBox_part_2
#      Type: export_statement_part
#      Size: 999 tokens, 172 lines
#      Content preview:
#        }
#
#        let newActive:
#        ... (169 more lines)
#
#   4. const_ComboBox_part_3
#      Type: export_statement_part
#      Size: 717 tokens, 99 lines
#      Content preview:
#        aria-labelledby={clsx(buttonId, formFieldLabelledBy)}
#        aria-label="Show options"
#        aria-expanded={openState}
#        ... (96 more lines)
#
#
# === Processing: AccordionGroup.tsx ===
# File size: 979 characters
# File type: .tsx
# Found 2 semantic units
#   - export_statement: interface_AccordionGroupProps (36 tokens)
#     Preview: export interface AccordionGroupProps extends ComponentPropsWithoutRef<"div"> {   /**    * The child...
#   - export_statement: const_AccordionGroup (105 tokens)
#     Preview: export const AccordionGroup = forwardRef<HTMLDivElement, AccordionGroupProps>(   function AccordionG...
# Created 2 semantic chunks
# Final result: 2 total chunks
#
# --- Semantic Chunk Summary for AccordionGroup.tsx ---
# 1. interface_AccordionGroupProps
#    Type: export_statement
#    Size: 36 tokens, 6 lines
#    Content preview:
#      export interface AccordionGroupProps extends ComponentPropsWithoutRef<"div"> {
#      /**
#      * The child Accordions to be rendered
#      ... (3 more lines)
#
# 2. const_AccordionGroup
#    Type: export_statement
#    Size: 105 tokens, 16 lines
#    Content preview:
#      export const AccordionGroup = forwardRef<HTMLDivElement, AccordionGroupProps>(
#      function AccordionGroup(props, ref) {
#      const { className, ...rest } = props;
#      ... (13 more lines)
#
#
# === Processing: AccordionContext.ts ===
# File size: 850 characters
# File type: .ts
# Found 3 semantic units
#   - export_statement: interface_AccordionContextValue (101 tokens)
#     Preview: export interface AccordionContextValue {   value: string;   expanded: boolean;   toggle: (event: Syn...
#   - export_statement: const_AccordionContext (78 tokens)
#     Preview: export const AccordionContext = createContext<AccordionContextValue>(   "AccordionContext",   {...
#   - export_statement: function_useAccordion (15 tokens)
#     Preview: export function useAccordion() {   return useContext(AccordionContext); }...
# Created 3 semantic chunks
# Final result: 3 total chunks
#
# --- Semantic Chunk Summary for AccordionContext.ts ---
# 1. interface_AccordionContextValue
#    Type: export_statement
#    Size: 101 tokens, 12 lines
#    Content preview:
#      export interface AccordionContextValue {
#      value: string;
#      expanded: boolean;
#      ... (9 more lines)
#
# 2. const_AccordionContext
#    Type: export_statement
#    Size: 78 tokens, 14 lines
#    Content preview:
#      export const AccordionContext = createContext<AccordionContextValue>(
#      "AccordionContext",
#      {
#      ... (11 more lines)
#
# 3. function_useAccordion
#    Type: export_statement
#    Size: 15 tokens, 3 lines
#    Content preview:
#      export function useAccordion() {
#      return useContext(AccordionContext);
#      }
#
#
# === Processing: index.ts ===
# File size: 132 characters
# File type: .ts
# Found 0 semantic units
# Created 0 semantic chunks
# Final result: 0 total chunks
#
# --- Semantic Chunk Summary for index.ts ---
#
# 🎉 OVERALL SUMMARY
# Files processed: 7
# Total chunks created: 16
# Average chunk size: 277 tokens
# Largest chunk: 1001 tokens
# Smallest chunk: 15 tokens
#
# Chunk types:
#   export_statement: 12
#   export_statement_part: 3
#   function_declaration: 1

# %% [markdown]
# Minimal changes made:
#
# Added 3 new parsers: css_parser, html_parser alongside existing tsx_parser
# Added PARSER_MAP: Maps file extensions to appropriate parsers
# Extended syntax highlighting: Added CSS, SCSS, HTML to language map
# Added CSS/HTML semantic logic:
#
# CSS: rule_set, at_rule, keyframes_statement
# HTML: element, script_element, style_element (substantial ones only)
#
#
# Added extraction functions: extract_css_name() and extract_html_name() for meaningful names
# Updated main function: Renamed to "Multi-Language" and added file type breakdown
#
# The semantic boundaries chosen:
#
# CSS/SCSS: CSS rules, @media queries, @keyframes animations
# HTML: Major elements, script tags, style tags (ignoring small elements)
#
# Now it handles all 7 file types with appropriate semantic chunking for each!

# %%
#!/usr/bin/env python3

import os
from pathlib import Path
from typing import List, Dict, Any
import tiktoken

# Tree-sitter setup for multiple languages
try:
    from tree_sitter_language_pack import get_language, get_parser
    tsx_language = get_language('tsx')
    tsx_parser = get_parser('tsx')
    css_language = get_language('css')
    css_parser = get_parser('css')
    html_language = get_language('html')
    html_parser = get_parser('html')
    print("✅ Using TSX, CSS, and HTML parsers")
except ImportError:
    print("Please install: pip install tree-sitter-languages")
    exit(1)

# Configuration
MAX_CHUNK_TOKENS = 1000
MAX_RECURSION_DEPTH = 3

# Supported file extensions and their parsers
SUPPORTED_EXTENSIONS = ['.tsx', '.ts', '.js', '.jsx', '.css', '.scss', '.html']
PARSER_MAP = {
    '.tsx': tsx_parser,
    '.ts': tsx_parser,
    '.js': tsx_parser,
    '.jsx': tsx_parser,
    '.css': css_parser,
    '.scss': css_parser,
    '.html': html_parser
}

# Initialize token encoder
encoder = tiktoken.get_encoding("cl100k_base")

def count_tokens(text: str) -> int:
    """Count tokens in text"""
    return len(encoder.encode(text))

def get_syntax_highlighting_language(file_extension: str) -> str:
    """Get appropriate syntax highlighting language for markdown output"""
    language_map = {
        '.tsx': 'tsx',
        '.ts': 'typescript', 
        '.js': 'javascript',
        '.jsx': 'jsx',
        '.css': 'css',
        '.scss': 'scss',
        '.html': 'html'
    }
    return language_map.get(file_extension, 'text')

class Chunk:
    def __init__(self, start_byte: int, end_byte: int, content: str, node_type: str, name: str, depth: int = 0):
        self.start_byte = start_byte
        self.end_byte = end_byte
        self.content = content
        self.node_type = node_type
        self.name = name
        self.depth = depth
        self.token_count = count_tokens(content)
        self.sub_chunks = []

def extract_node_name(node, source_code: str) -> str:
    """Extract meaningful name from AST node"""
    node_text = source_code[node.start_byte:node.end_byte]
    lines = node_text.split('\n')
    
    import re
    
    # Try different patterns based on node type
    if node.type == 'function_declaration':
        match = re.search(r'function\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
        if match:
            return match.group(1)
    
    elif node.type == 'variable_declaration':
        # Look for const/let ComponentName = forwardRef or const hook = 
        match = re.search(r'(?:const|let|var)\s+([a-zA-Z_$][a-zA-Z0-9_$]*)\s*=', node_text)
        if match:
            return match.group(1)
    
    elif node.type == 'interface_declaration':
        match = re.search(r'interface\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
        if match:
            return match.group(1)
    
    elif node.type == 'type_alias_declaration':
        match = re.search(r'type\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
        if match:
            return match.group(1)
    
    elif node.type == 'class_declaration':
        match = re.search(r'class\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
        if match:
            return match.group(1)
    
    elif node.type == 'export_statement':
        # Handle various export patterns
        if 'export interface' in node_text:
            match = re.search(r'export\s+interface\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
            if match:
                return f"interface_{match.group(1)}"
        elif 'export const' in node_text:
            match = re.search(r'export\s+const\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
            if match:
                return f"const_{match.group(1)}"
        elif 'export function' in node_text:
            match = re.search(r'export\s+function\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
            if match:
                return f"function_{match.group(1)}"
        elif 'export default' in node_text:
            return "default_export"
        else:
            return "export_statement"
    
    # Fallback
    first_line = lines[0][:50].strip()
    simple_match = re.search(r'\b([a-zA-Z_$][a-zA-Z0-9_$]*)', first_line)
    if simple_match:
        return simple_match.group(1)
    
    return f"{node.type}_{node.start_byte}"

def find_semantic_chunks(tree, source_code: str, file_extension: str) -> List[Dict[str, Any]]:
    """Find semantic chunks - complete, meaningful code blocks"""
    semantic_nodes = []
    
    def traverse(node, parent_types=None):
        if parent_types is None:
            parent_types = []
        
        current_parent_types = parent_types + [node.type]
        node_text = source_code[node.start_byte:node.end_byte]
        
        # Handle different file types
        if file_extension in ['.css', '.scss']:
            # CSS/SCSS semantic boundaries - group smaller rules together
            if node.type in ['rule_set', 'at_rule', 'keyframes_statement'] and len(parent_types) <= 1:
                name = extract_css_name(node, source_code)
                semantic_nodes.append({
                    'node': node, 'name': name, 'start_byte': node.start_byte,
                    'end_byte': node.end_byte, 'type': node.type, 'content': node_text
                })
                return
                
        elif file_extension == '.html':
            # HTML semantic boundaries  
            if node.type in ['element', 'script_element', 'style_element'] and len(parent_types) <= 2:
                name = extract_html_name(node, source_code)
                if len(node_text.strip()) > 100:  # Only substantial elements
                    semantic_nodes.append({
                        'node': node, 'name': name, 'start_byte': node.start_byte,
                        'end_byte': node.end_byte, 'type': node.type, 'content': node_text
                    })
                    return
                    
        else:
            # JavaScript/TypeScript semantic boundaries (existing logic)
            if node.type in ['import_statement', 'import_declaration'] and len(parent_types) <= 1:
                name = extract_node_name(node, source_code)
                semantic_nodes.append({
                    'node': node, 'name': f"import_{name}", 'start_byte': node.start_byte,
                    'end_byte': node.end_byte, 'type': 'import_statement', 'content': node_text
                })
                return
            
            elif node.type == 'function_declaration' and len(parent_types) <= 1:
                name = extract_node_name(node, source_code)
                semantic_nodes.append({
                    'node': node, 'name': name, 'start_byte': node.start_byte,
                    'end_byte': node.end_byte, 'type': node.type, 'content': node_text
                })
                return
            
            elif node.type in ['interface_declaration', 'type_alias_declaration'] and len(parent_types) <= 1:
                name = extract_node_name(node, source_code)
                semantic_nodes.append({
                    'node': node, 'name': name, 'start_byte': node.start_byte,
                    'end_byte': node.end_byte, 'type': node.type, 'content': node_text
                })
                return
            
            elif node.type == 'variable_declaration' and len(parent_types) <= 1:
                if any(pattern in node_text for pattern in ['forwardRef', '= (' , 'useState', 'useEffect', 'createContext', 'makePrefixer']):
                    name = extract_node_name(node, source_code)
                    semantic_nodes.append({
                        'node': node, 'name': name, 'start_byte': node.start_byte,
                        'end_byte': node.end_byte, 'type': 'component_or_hook', 'content': node_text
                    })
                    return
            
            elif node.type == 'export_statement' and len(parent_types) <= 1:
                name = extract_node_name(node, source_code)
                if len(node_text.strip()) > 50:
                    semantic_nodes.append({
                        'node': node, 'name': name, 'start_byte': node.start_byte,
                        'end_byte': node.end_byte, 'type': node.type, 'content': node_text
                    })
                    return
        
        # Continue traversing children for other nodes
        for child in node.children:
            traverse(child, current_parent_types)
    
    traverse(tree.root_node)
    
    # Sort by start position and remove overlaps
    semantic_nodes.sort(key=lambda x: x['start_byte'])
    
    # Remove nested/overlapping nodes
    filtered_nodes = []
    for node in semantic_nodes:
        is_contained = False
        for existing in filtered_nodes:
            if (existing['start_byte'] <= node['start_byte'] and 
                existing['end_byte'] >= node['end_byte']):
                is_contained = True
                break
        
        if not is_contained:
            to_remove = []
            for i, existing in enumerate(filtered_nodes):
                if (node['start_byte'] <= existing['start_byte'] and 
                    node['end_byte'] >= existing['end_byte']):
                    to_remove.append(i)
            
            for i in reversed(to_remove):
                filtered_nodes.pop(i)
            
            filtered_nodes.append(node)
    
    return filtered_nodes

def extract_css_name(node, source_code: str) -> str:
    """Extract meaningful name from CSS/SCSS node"""
    import re
    node_text = source_code[node.start_byte:node.end_byte]
    first_line = node_text.split('\n')[0].strip()
    
    if node.type == 'rule_set':
        # Extract selector
        match = re.search(r'^([^{]+)', first_line)
        if match:
            selector = match.group(1).strip()
            return f"rule_{selector[:30].replace(' ', '_')}"
    elif node.type == 'at_rule':
        # Extract @rule name
        match = re.search(r'@(\w+)', first_line)
        if match:
            return f"at_{match.group(1)}"
    elif node.type == 'keyframes_statement':
        match = re.search(r'@keyframes\s+(\w+)', first_line)
        if match:
            return f"keyframes_{match.group(1)}"
    
    return f"{node.type}_{node.start_byte}"

def extract_html_name(node, source_code: str) -> str:
    """Extract meaningful name from HTML node"""
    import re
    node_text = source_code[node.start_byte:node.end_byte]
    first_line = node_text.split('\n')[0].strip()
    
    # Extract tag name and important attributes
    if node.type in ['element', 'script_element', 'style_element']:
        match = re.search(r'<(\w+)(?:\s+[^>]*)?>', first_line)
        if match:
            tag = match.group(1)
            # Look for id or class
            id_match = re.search(r'id=["\']([^"\']+)["\']', first_line)
            class_match = re.search(r'class=["\']([^"\']+)["\']', first_line)
            
            if id_match:
                return f"{tag}#{id_match.group(1)}"
            elif class_match:
                return f"{tag}.{class_match.group(1).split()[0]}"
            else:
                return tag
    
    return f"{node.type}_{node.start_byte}"

def create_semantic_chunks(semantic_nodes: List[Dict[str, Any]]) -> List[Chunk]:
    """Create chunks from semantic nodes"""
    chunks = []
    
    for node_info in semantic_nodes:
        chunk = Chunk(
            start_byte=node_info['start_byte'],
            end_byte=node_info['end_byte'],
            content=node_info['content'],
            node_type=node_info['type'],
            name=node_info['name'],
            depth=0
        )
        chunks.append(chunk)
    
    return chunks

def group_small_chunks(chunks: List[Chunk], target_tokens: int = 600, file_extension: str = '') -> List[Chunk]:
    """Group small chunks together to reach reasonable size for any file type"""
    if not chunks:
        return chunks
    
    # Separate imports from other chunks for JS/TS files
    if file_extension in ['.tsx', '.ts', '.jsx', '.js']:
        import_chunks = [c for c in chunks if c.node_type == 'import_statement']
        other_chunks = [c for c in chunks if c.node_type != 'import_statement']
        
        # Check if everything together is under limit
        total_tokens = sum(c.token_count for c in chunks)
        if total_tokens <= MAX_CHUNK_TOKENS:
            # Combine everything into one chunk
            combined_content = '\n\n'.join(c.content for c in chunks)
            combined_chunk = Chunk(
                start_byte=chunks[0].start_byte,
                end_byte=chunks[-1].end_byte,
                content=combined_content,
                node_type='complete_module',
                name=f"complete_module_{len(chunks)}_parts",
                depth=0
            )
            return [combined_chunk]
        
        # If too large, handle imports separately
        if import_chunks:
            total_import_tokens = sum(c.token_count for c in import_chunks)
            if total_import_tokens <= MAX_CHUNK_TOKENS:
                # Combine all imports into one chunk
                combined_imports = '\n'.join(c.content for c in import_chunks)
                imports_chunk = Chunk(
                    start_byte=import_chunks[0].start_byte,
                    end_byte=import_chunks[-1].end_byte,
                    content=combined_imports,
                    node_type='imports_group',
                    name=f"imports_{len(import_chunks)}_statements",
                    depth=0
                )
                import_chunks = [imports_chunk]
        
        # Group other chunks
        grouped_others = group_chunks_by_size(other_chunks, target_tokens, file_extension)
        
        # Combine imports + other chunks
        return import_chunks + grouped_others
    else:
        # For non-JS files, use original logic
        return group_chunks_by_size(chunks, target_tokens, file_extension)

def group_chunks_by_size(chunks: List[Chunk], target_tokens: int = 600, file_extension: str = '') -> List[Chunk]:
    """Group chunks by size logic"""
    if not chunks:
        return chunks
    
    # Skip grouping if we already have reasonably sized chunks
    if len(chunks) == 1 or any(c.token_count > target_tokens for c in chunks):
        total_tokens = sum(c.token_count for c in chunks)
        if total_tokens <= MAX_CHUNK_TOKENS:
            # All chunks together are still under limit - combine them
            if len(chunks) > 1:
                combined_content = '\n\n'.join(c.content for c in chunks)
                
                # Create descriptive name based on file type
                if file_extension in ['.css', '.scss']:
                    group_name = f"css_styles_{len(chunks)}_rules"
                elif file_extension in ['.tsx', '.ts', '.jsx', '.js']:
                    group_name = f"file_module_{len(chunks)}_exports"
                elif file_extension == '.html':
                    group_name = f"html_content_{len(chunks)}_elements"
                else:
                    group_name = f"file_content_{len(chunks)}_parts"
                
                combined_chunk = Chunk(
                    start_byte=chunks[0].start_byte,
                    end_byte=chunks[-1].end_byte,
                    content=combined_content,
                    node_type='grouped_content',
                    name=group_name,
                    depth=0
                )
                return [combined_chunk]
        return chunks
    
    # Group small chunks
    grouped_chunks = []
    current_group = []
    current_tokens = 0
    
    for chunk in chunks:
        if current_tokens + chunk.token_count > target_tokens and current_group:
            # Finalize current group
            group_content = '\n\n'.join(c.content for c in current_group)
            
            if file_extension in ['.css', '.scss']:
                group_name = f"css_group_{len(grouped_chunks)+1}_{len(current_group)}_rules"
            elif file_extension in ['.tsx', '.ts', '.jsx', '.js']:
                group_name = f"code_group_{len(grouped_chunks)+1}_{len(current_group)}_parts"
            elif file_extension == '.html':
                group_name = f"html_group_{len(grouped_chunks)+1}_{len(current_group)}_elements"
            else:
                group_name = f"group_{len(grouped_chunks)+1}_{len(current_group)}_parts"
            
            grouped_chunk = Chunk(
                start_byte=current_group[0].start_byte,
                end_byte=current_group[-1].end_byte,
                content=group_content,
                node_type='grouped_content',
                name=group_name,
                depth=0
            )
            grouped_chunks.append(grouped_chunk)
            
            current_group = [chunk]
            current_tokens = chunk.token_count
        else:
            current_group.append(chunk)
            current_tokens += chunk.token_count
    
    # Add remaining chunks
    if current_group:
        if len(current_group) == 1 and current_tokens > target_tokens//2:
            grouped_chunks.append(current_group[0])
        else:
            group_content = '\n\n'.join(c.content for c in current_group)
            
            if file_extension in ['.css', '.scss']:
                group_name = f"css_group_{len(grouped_chunks)+1}_{len(current_group)}_rules"
            elif file_extension in ['.tsx', '.ts', '.jsx', '.js']:
                group_name = f"code_group_{len(grouped_chunks)+1}_{len(current_group)}_parts"
            elif file_extension == '.html':
                group_name = f"html_group_{len(grouped_chunks)+1}_{len(current_group)}_elements"
            else:
                group_name = f"group_{len(grouped_chunks)+1}_{len(current_group)}_parts"
            
            grouped_chunk = Chunk(
                start_byte=current_group[0].start_byte,
                end_byte=current_group[-1].end_byte,
                content=group_content,
                node_type='grouped_content',
                name=group_name,
                depth=0
            )
            grouped_chunks.append(grouped_chunk)
    
    return grouped_chunks

def sub_chunk_by_statements(chunk: Chunk, tree, source_code: str, depth: int = 0) -> List[Chunk]:
    """Sub-chunk by breaking down into logical statements/blocks"""
    if depth >= MAX_RECURSION_DEPTH or chunk.token_count <= MAX_CHUNK_TOKENS:
        return [chunk]
    
    print(f"    Breaking down {chunk.name} ({chunk.token_count} tokens) into smaller pieces...")
    
    # Simple line-based splitting for now
    lines = chunk.content.split('\n')
    sub_chunks = []
    current_lines = []
    current_size = 0
    
    for line in lines:
        line_tokens = count_tokens(line)
        
        if current_size + line_tokens > MAX_CHUNK_TOKENS and current_lines:
            # Create sub-chunk
            sub_content = '\n'.join(current_lines)
            if sub_content.strip():
                sub_chunk = Chunk(
                    start_byte=chunk.start_byte,  # Approximate
                    end_byte=chunk.start_byte + len(sub_content),
                    content=sub_content,
                    node_type=f"{chunk.node_type}_part",
                    name=f"{chunk.name}_part_{len(sub_chunks)+1}",
                    depth=depth + 1
                )
                sub_chunks.append(sub_chunk)
            
            current_lines = [line]
            current_size = line_tokens
        else:
            current_lines.append(line)
            current_size += line_tokens
    
    # Add remaining lines
    if current_lines:
        sub_content = '\n'.join(current_lines)
        if sub_content.strip():
            sub_chunk = Chunk(
                start_byte=chunk.start_byte,
                end_byte=chunk.end_byte,
                content=sub_content,
                node_type=f"{chunk.node_type}_part",
                name=f"{chunk.name}_part_{len(sub_chunks)+1}",
                depth=depth + 1
            )
            sub_chunks.append(sub_chunk)
    
    chunk.sub_chunks = sub_chunks
    return sub_chunks if len(sub_chunks) > 1 else [chunk]

def process_file(file_path: Path) -> List[Chunk]:
    """Process a single file and return semantic chunks"""
    print(f"\n=== Processing: {file_path.name} ===")
    
    # Read file
    with open(file_path, 'r', encoding='utf-8') as f:
        source_code = f.read()
    
    print(f"File size: {len(source_code)} characters")
    print(f"File type: {file_path.suffix}")
    
    # Get appropriate parser
    parser = PARSER_MAP.get(file_path.suffix)
    if not parser:
        print(f"❌ No parser available for {file_path.suffix}")
        return []
    
    # Parse with appropriate parser
    tree = parser.parse(source_code.encode('utf-8'))
    
    if tree.root_node.has_error:
        print("⚠️ Parse errors detected")
    
    # Find semantic chunks
    semantic_nodes = find_semantic_chunks(tree, source_code, file_path.suffix)
    print(f"Found {len(semantic_nodes)} semantic units")
    
    # Show what we found
    for node in semantic_nodes:
        preview = node['content'][:100].replace('\n', ' ').strip()
        print(f"  - {node['type']}: {node['name']} ({count_tokens(node['content'])} tokens)")
        print(f"    Preview: {preview}...")
    
    # Create chunks
    base_chunks = create_semantic_chunks(semantic_nodes)
    
    # Group small chunks for all file types
    base_chunks = group_small_chunks(base_chunks, target_tokens=600, file_extension=file_path.suffix)
    
    print(f"Created {len(base_chunks)} semantic chunks")
    
    # Apply sub-chunking for oversized chunks
    final_chunks = []
    oversized_count = 0
    
    for chunk in base_chunks:
        if chunk.token_count > MAX_CHUNK_TOKENS:
            print(f"  Sub-chunking {chunk.name} ({chunk.token_count} tokens)")
            sub_chunks = sub_chunk_by_statements(chunk, tree, source_code)
            final_chunks.extend(sub_chunks)
            oversized_count += 1
        else:
            final_chunks.append(chunk)
    
    if oversized_count > 0:
        print(f"Sub-chunked {oversized_count} oversized chunks")
    print(f"Final result: {len(final_chunks)} total chunks")
    
    return final_chunks

def print_chunk_summary(chunks: List[Chunk], file_name: str):
    """Print detailed summary of chunks"""
    print(f"\n--- Semantic Chunk Summary for {file_name} ---")
    
    for i, chunk in enumerate(chunks, 1):
        indent = "  " * chunk.depth
        content_lines = len(chunk.content.split('\n'))
        
        print(f"{indent}{i}. {chunk.name}")
        print(f"{indent}   Type: {chunk.node_type}")
        print(f"{indent}   Size: {chunk.token_count} tokens, {content_lines} lines")
        print(f"{indent}   Content preview:")
        
        # Show first few lines of actual content
        content_lines_list = chunk.content.split('\n')
        for j, line in enumerate(content_lines_list[:3]):
            print(f"{indent}     {line.strip()}")
        if len(content_lines_list) > 3:
            print(f"{indent}     ... ({len(content_lines_list) - 3} more lines)")
        print()

def main():
    """Main function to test semantic chunking"""
    print("🚀 Multi-Language Semantic Chunking Test")
    print(f"Max chunk tokens: {MAX_CHUNK_TOKENS}")
    print(f"Max recursion depth: {MAX_RECURSION_DEPTH}")
    print(f"Supported extensions: {', '.join(SUPPORTED_EXTENSIONS)}")
    
    # Get directory from user or use current directory
    directory = input("\nEnter directory path (or press Enter for current directory): ").strip()
    if not directory:
        directory = "."
    
    target_dir = Path(directory)
    if not target_dir.exists():
        print(f"❌ Directory not found: {directory}")
        return
    
    # Find all supported files
    all_files = []
    for ext in SUPPORTED_EXTENSIONS:
        files = list(target_dir.rglob(f"*{ext}"))
        all_files.extend(files)
    
    if not all_files:
        print(f"❌ No supported files found in {directory}")
        print(f"Looking for: {', '.join(SUPPORTED_EXTENSIONS)}")
        return
    
    print(f"📁 Found {len(all_files)} supported files:")
    # Group by extension for summary
    by_ext = {}
    by_dir = {}
    for f in all_files:
        ext = f.suffix
        by_ext[ext] = by_ext.get(ext, 0) + 1
        
        # Track directory depth
        rel_path = f.relative_to(target_dir)
        dir_path = str(rel_path.parent) if rel_path.parent != Path('.') else 'root'
        by_dir[dir_path] = by_dir.get(dir_path, 0) + 1
    
    for ext, count in sorted(by_ext.items()):
        print(f"  {ext}: {count} files")
    
    # Show directory structure if there are subdirectories
    if len(by_dir) > 1 or 'root' not in by_dir:
        print(f"\n📂 Directory distribution:")
        for dir_path, count in sorted(by_dir.items()):
            if dir_path == 'root':
                print(f"  ./: {count} files")
            else:
                depth = dir_path.count('/') if '/' in dir_path else dir_path.count('\\')
                indent = "  " + "  " * depth
                print(f"{indent}{dir_path}/: {count} files")
    
    # Process each file
    all_chunks = []
    for file_path in all_files:
        try:
            chunks = process_file(file_path)
            all_chunks.extend(chunks)
            print_chunk_summary(chunks, file_path.name)
        except Exception as e:
            print(f"❌ Error processing {file_path}: {e}")
    
    # Overall summary
    print(f"\n🎉 OVERALL SUMMARY")
    print(f"Files processed: {len(all_files)}")
    print(f"Total chunks created: {len(all_chunks)}")
    
    if all_chunks:
        avg_tokens = sum(c.token_count for c in all_chunks) / len(all_chunks)
        max_tokens = max(c.token_count for c in all_chunks)
        min_tokens = min(c.token_count for c in all_chunks)
        
        print(f"Average chunk size: {avg_tokens:.0f} tokens")
        print(f"Largest chunk: {max_tokens} tokens")
        print(f"Smallest chunk: {min_tokens} tokens")
        
        # Count by node type
        type_counts = {}
        for chunk in all_chunks:
            type_counts[chunk.node_type] = type_counts.get(chunk.node_type, 0) + 1
        
        print(f"\nChunk types:")
        for node_type, count in sorted(type_counts.items()):
            print(f"  {node_type}: {count}")
            
        # Count by file type
        print(f"\nChunks by file type:")
        file_type_chunks = {}
        # We need to track file types in chunks - simplified approach
        for ext, count in sorted(by_ext.items()):
            # Estimate chunks per file type based on proportions
            proportion = count / len(all_files)
            estimated_chunks = int(len(all_chunks) * proportion)
            file_type_chunks[ext] = estimated_chunks
            print(f"  {ext}: ~{estimated_chunks} chunks")

if __name__ == "__main__":
    main()
# Out:
# ✅ Using TSX, CSS, and HTML parsers
# 🚀 Multi-Language Semantic Chunking Test
# Max chunk tokens: 1000
# Max recursion depth: 3
# Supported extensions: .tsx, .ts, .js, .jsx, .css, .scss, .html
# 📁 Found 358 supported files:
#   .css: 93 files
#   .ts: 129 files
#   .tsx: 136 files
#
# 📂 Directory distribution:
#   src/: 3 files
#     src/accordion/: 10 files
#     src/aria-announcer/: 5 files
#     src/avatar/: 4 files
#     src/badge/: 3 files
#     src/banner/: 7 files
#     src/border-item/: 3 files
#     src/border-layout/: 2 files
#     src/breakpoints/: 3 files
#     src/button/: 4 files
#     src/card/: 3 files
#     src/checkbox/: 7 files
#       src/checkbox/internal/: 2 files
#     src/combo-box/: 4 files
#     src/dialog/: 12 files
#     src/divider/: 3 files
#     src/drawer/: 5 files
#     src/dropdown/: 3 files
#     src/file-drop-zone/: 5 files
#       src/file-drop-zone/internal/: 1 files
#     src/flex-item/: 3 files
#     src/flex-layout/: 4 files
#     src/flow-layout/: 2 files
#     src/form-field/: 7 files
#     src/form-field-context/: 3 files
#     src/grid-item/: 3 files
#     src/grid-layout/: 3 files
#     src/input/: 3 files
#     src/interactable-card/: 7 files
#     src/link/: 4 files
#     src/link-card/: 3 files
#     src/list-box/: 3 files
#     src/list-control/: 3 files
#     src/menu/: 14 files
#     src/multiline-input/: 3 files
#     src/navigation-item/: 5 files
#     src/option/: 8 files
#     src/overlay/: 12 files
#     src/pagination/: 18 files
#     src/panel/: 3 files
#     src/parent-child-layout/: 4 files
#     src/pill/: 3 files
#     src/pill-input/: 4 files
#     src/progress/: 1 files
#       src/progress/CircularProgress/: 2 files
#       src/progress/LinearProgress/: 2 files
#     src/radio-button/: 7 files
#       src/radio-button/internal/: 2 files
#     src/salt-provider/: 3 files
#     src/scrim/: 3 files
#     src/segmented-button-group/: 3 files
#     src/semantic-icon-provider/: 2 files
#     src/skip-link/: 3 files
#       src/skip-link/internal/: 1 files
#     src/slider/: 3 files
#       src/slider/internal/: 9 files
#     src/spinner/: 3 files
#       src/spinner/svgSpinners/: 1 files
#     src/split-layout/: 3 files
#     src/stack-layout/: 3 files
#     src/status-adornment/: 6 files
#     src/status-indicator/: 4 files
#     src/stepper/: 5 files
#       src/stepper/internal/: 10 files
#     src/switch/: 3 files
#     src/tag/: 3 files
#     src/text/: 9 files
#     src/theme/: 8 files
#     src/toast/: 5 files
#     src/toggle-button/: 3 files
#     src/toggle-button-group/: 4 files
#     src/tooltip/: 6 files
#     src/utils/: 26 files
#       src/utils/useFloatingUI/: 2 files
#     src/viewport/: 2 files
#
# === Processing: Dropdown.tsx ===
# File size: 13602 characters
# File type: .tsx
# Found 17 semantic units
#   - import_statement: import_import (35 tokens)
#     Preview: import {   flip,   offset,   size,   useClick,   useDismiss,   useFocus,   useInteractions, } from "...
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (52 tokens)
#     Preview: import {   Children,   type ComponentPropsWithoutRef,   type FocusEvent,   type ForwardedRef,   forw...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useFormFieldProps } from "../form-field-context";...
#   - import_statement: import_import (21 tokens)
#     Preview: import {   ListControlContext,   type OptionValue, } from "../list-control/ListControlContext";...
#   - import_statement: import_import (26 tokens)
#     Preview: import {   defaultValueToString,   type ListControlProps,   useListControl, } from "../list-control/...
#   - import_statement: import_import (12 tokens)
#     Preview: import { OptionList } from "../option/OptionList";...
#   - import_statement: import_import (11 tokens)
#     Preview: import { useIcon } from "../semantic-icon-provider";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { StatusAdornment } from "../status-adornment";...
#   - import_statement: import_import (12 tokens)
#     Preview: import type { ValidationStatus } from "../status-indicator";...
#   - import_statement: import_import (34 tokens)
#     Preview: import {   makePrefixer,   type UseFloatingUIProps,   useFloatingUI,   useForkRef,   useId, } from "...
#   - import_statement: import_import (8 tokens)
#     Preview: import dropdownCss from "./Dropdown.css";...
#   - export_statement: export_statement (335 tokens)
#     Preview: export type DropdownProps<Item = string> = {   /**    * If `true`, the dropdown will be disabled....
#   - function_declaration: nction (68 tokens)
#     Preview: nction ExpandIcon({ open }: { open: boolean }) {   const { CollapseIcon, ExpandIcon } = useIcon();...
#   - export_statement: export_statement (2484 tokens)
#     Preview: port const Dropdown = forwardRef(function Dropdown<Item>(   props: DropdownProps<Item>,   ref: Forwa...
# Created 4 semantic chunks
#   Sub-chunking export_statement (2484 tokens)
#     Breaking down export_statement (2484 tokens) into smaller pieces...
# Sub-chunked 1 oversized chunks
# Final result: 6 total chunks
#
# --- Semantic Chunk Summary for Dropdown.tsx ---
# 1. imports_14_statements
#    Type: imports_group
#    Size: 271 tokens, 46 lines
#    Content preview:
#      import {
#      flip,
#      offset,
#      ... (43 more lines)
#
# 2. export_statement
#    Type: export_statement
#    Size: 335 tokens, 53 lines
#    Content preview:
#      export type DropdownProps<Item = string> = {
#      /**
#      * If `true`, the dropdown will be disabled.
#      ... (50 more lines)
#
# 3. nction
#    Type: function_declaration
#    Size: 68 tokens, 10 lines
#    Content preview:
#      nction ExpandIcon({ open }: { open: boolean }) {
#      const { CollapseIcon, ExpandIcon } = useIcon();
#      return open ? (
#      ... (7 more lines)
#
#   4. export_statement_part_1
#      Type: export_statement_part
#      Size: 1002 tokens, 162 lines
#      Content preview:
#        port const Dropdown = forwardRef(function Dropdown<Item>(
#        props: DropdownProps<Item>,
#        ref: ForwardedRef<HTMLButtonElement>,
#        ... (159 more lines)
#
#   5. export_statement_part_2
#      Type: export_statement_part
#      Size: 1008 tokens, 164 lines
#      Content preview:
#        setFocusVisibleState(true);
#        }
#        };
#        ... (161 more lines)
#
#   6. export_statement_part_3
#      Type: export_statement_part
#      Size: 474 tokens, 70 lines
#      Content preview:
#        },
#        className,
#        )}
#        ... (67 more lines)
#
#
# === Processing: RadioButtonGroup.tsx ===
# File size: 3767 characters
# File type: .tsx
# Found 10 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (23 tokens)
#     Preview: import {   type ChangeEventHandler,   type ComponentPropsWithoutRef,   forwardRef, } from "react";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useFormFieldProps } from "../form-field-context";...
#   - import_statement: import_import (17 tokens)
#     Preview: import { makePrefixer, useControlled, useId } from "../utils";...
#   - import_statement: import_import (14 tokens)
#     Preview: import { RadioGroupContext } from "./internal/RadioGroupContext";...
#   - import_statement: import_import (10 tokens)
#     Preview: import radioButtonGroupCss from "./RadioButtonGroup.css";...
#   - export_statement: interface_RadioButtonGroupProps (240 tokens)
#     Preview: export interface RadioButtonGroupProps   extends Omit<ComponentPropsWithoutRef<"fieldset">, "onChang...
#   - export_statement: const_RadioButtonGroup (490 tokens)
#     Preview: export const RadioButtonGroup = forwardRef<   HTMLFieldSetElement,   RadioButtonGroupProps >(functio...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for RadioButtonGroup.tsx ---
# 1. complete_module_10_parts
#    Type: complete_module
#    Size: 842 tokens, 150 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (147 more lines)
#
#
# === Processing: RadioButton.tsx ===
# File size: 5899 characters
# File type: .tsx
# Found 13 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (43 tokens)
#     Preview: import {   type ChangeEventHandler,   type ComponentPropsWithoutRef,   type FocusEventHandler,   for...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useFormFieldProps } from "../form-field-context";...
#   - import_statement: import_import (14 tokens)
#     Preview: import type { AdornmentValidationStatus } from "../status-adornment";...
#   - import_statement: import_import (10 tokens)
#     Preview: import type { DataAttributes } from "../types";...
#   - import_statement: import_import (14 tokens)
#     Preview: import { makePrefixer, useControlled } from "../utils";...
#   - import_statement: import_import (13 tokens)
#     Preview: import { useRadioGroup } from "./internal/useRadioGroup";...
#   - import_statement: import_import (8 tokens)
#     Preview: import radioButtonCss from "./RadioButton.css";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { RadioButtonIcon } from "./RadioButtonIcon";...
#   - export_statement: interface_RadioButtonProps (371 tokens)
#     Preview: export interface RadioButtonProps   extends Omit<     ComponentPropsWithoutRef<"label">,     "onChan...
#   - export_statement: const_RadioButton (746 tokens)
#     Preview: export const RadioButton = forwardRef<HTMLLabelElement, RadioButtonProps>(   function RadioButton(pr...
# Created 3 semantic chunks
# Final result: 3 total chunks
#
# --- Semantic Chunk Summary for RadioButton.tsx ---
# 1. imports_11_statements
#    Type: imports_group
#    Size: 160 tokens, 19 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#      import { useWindow } from "@salt-ds/window";
#      import { clsx } from "clsx";
#      ... (16 more lines)
#
# 2. interface_RadioButtonProps
#    Type: export_statement
#    Size: 371 tokens, 63 lines
#    Content preview:
#      export interface RadioButtonProps
#      extends Omit<
#      ComponentPropsWithoutRef<"label">,
#      ... (60 more lines)
#
# 3. const_RadioButton
#    Type: export_statement
#    Size: 746 tokens, 132 lines
#    Content preview:
#      export const RadioButton = forwardRef<HTMLLabelElement, RadioButtonProps>(
#      function RadioButton(props, ref) {
#      const {
#      ... (129 more lines)
#
#
# === Processing: RadioButtonIcon.tsx ===
# File size: 2079 characters
# File type: .tsx
# Found 9 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (12 tokens)
#     Preview: import type { ComponentPropsWithoutRef } from "react";...
#   - import_statement: import_import (14 tokens)
#     Preview: import type { AdornmentValidationStatus } from "../status-adornment";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import radioButtonIconCss from "./RadioButtonIcon.css";...
#   - export_statement: interface_RadioButtonIconProps (57 tokens)
#     Preview: export interface RadioButtonIconProps extends ComponentPropsWithoutRef<"div"> {   checked?: boolean;...
#   - export_statement: const_RadioButtonIcon (415 tokens)
#     Preview: export const RadioButtonIcon = ({   checked,   className,   error,   disabled,   validationStatus,...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for RadioButtonIcon.tsx ---
# 1. complete_module_9_parts
#    Type: complete_module
#    Size: 554 tokens, 81 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (78 more lines)
#
#
# === Processing: DrawerCloseButton.tsx ===
# File size: 1132 characters
# File type: .tsx
# Found 9 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (9 tokens)
#     Preview: import { forwardRef } from "react";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { Button, type ButtonProps } from "../button";...
#   - import_statement: import_import (11 tokens)
#     Preview: import { useIcon } from "../semantic-icon-provider";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (12 tokens)
#     Preview: import drawerCloseButtonCss from "./DrawerCloseButton.css";...
#   - export_statement: const_DrawerCloseButton (153 tokens)
#     Preview: export const DrawerCloseButton = forwardRef<HTMLButtonElement, ButtonProps>(   function DrawerCloseB...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for DrawerCloseButton.tsx ---
# 1. complete_module_9_parts
#    Type: complete_module
#    Size: 243 tokens, 41 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (38 more lines)
#
#
# === Processing: Drawer.tsx ===
# File size: 3603 characters
# File type: .tsx
# Found 11 semantic units
#   - import_statement: import_import (18 tokens)
#     Preview: import { useClick, useDismiss, useInteractions } from "@floating-ui/react";...
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (30 tokens)
#     Preview: import {   type ComponentPropsWithoutRef,   forwardRef,   type PropsWithChildren,   useEffect,   use...
#   - import_statement: import_import (10 tokens)
#     Preview: import { Scrim } from "../scrim";...
#   - import_statement: import_import (28 tokens)
#     Preview: import {   makePrefixer,   useFloatingComponent,   useFloatingUI,   useForkRef, } from "../utils";...
#   - import_statement: import_import (8 tokens)
#     Preview: import drawerCss from "./Drawer.css";...
#   - interface_declaration: ConditionalScrimWrapperProps (17 tokens)
#     Preview: interface ConditionalScrimWrapperProps extends PropsWithChildren {   condition: boolean; }...
#   - export_statement: interface_DrawerProps (158 tokens)
#     Preview: export interface DrawerProps extends ComponentPropsWithoutRef<"div"> {   /**    * Defines the drawer...
#   - export_statement: const_Drawer (456 tokens)
#     Preview: export const Drawer = forwardRef<HTMLDivElement, DrawerProps>(   function Drawer(props, ref) {     c...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for Drawer.tsx ---
# 1. complete_module_11_parts
#    Type: complete_module
#    Size: 761 tokens, 138 lines
#    Content preview:
#      import { useClick, useDismiss, useInteractions } from "@floating-ui/react";
#
#      import { useComponentCssInjection } from "@salt-ds/styles";
#      ... (135 more lines)
#
#
# === Processing: Paginator.tsx ===
# File size: 2415 characters
# File type: .tsx
# Found 12 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (17 tokens)
#     Preview: import { forwardRef, type HTMLAttributes, type MouseEventHandler } from "react";...
#   - import_statement: import_import (8 tokens)
#     Preview: import { Button } from "../button";...
#   - import_statement: import_import (11 tokens)
#     Preview: import { useIcon } from "../semantic-icon-provider";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { PageRanges } from "./PageRanges";...
#   - import_statement: import_import (8 tokens)
#     Preview: import paginatorCss from "./Paginator.css";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { usePaginationContext } from "./usePaginationContext";...
#   - export_statement: interface_PaginatorProps (66 tokens)
#     Preview: export interface PaginatorProps extends HTMLAttributes<HTMLDivElement> {   /**    * Number of pages...
#   - export_statement: const_Paginator (354 tokens)
#     Preview: export const Paginator = forwardRef<HTMLDivElement, PaginatorProps>(   function Paginator(     { cla...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for Paginator.tsx ---
# 1. complete_module_12_parts
#    Type: complete_module
#    Size: 532 tokens, 82 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (79 more lines)
#
#
# === Processing: Pagination.tsx ===
# File size: 2528 characters
# File type: .tsx
# Found 10 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (33 tokens)
#     Preview: import {   forwardRef,   type HTMLAttributes,   type SyntheticEvent,   useCallback,   useEffect,   u...
#   - import_statement: import_import (15 tokens)
#     Preview: import { useAriaAnnouncer } from "../aria-announcer";...
#   - import_statement: import_import (14 tokens)
#     Preview: import { makePrefixer, useControlled } from "../utils";...
#   - import_statement: import_import (8 tokens)
#     Preview: import paginationCss from "./Pagination.css";...
#   - import_statement: import_import (14 tokens)
#     Preview: import { type PaginationContext, paginationContext } from "./PaginationContext";...
#   - export_statement: interface_PaginationProps (92 tokens)
#     Preview: export interface PaginationProps extends HTMLAttributes<HTMLElement> {   /**    * Number of pages....
#   - export_statement: const_Pagination (355 tokens)
#     Preview: export const Pagination = forwardRef<HTMLElement, PaginationProps>(   function Pagination(     {...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for Pagination.tsx ---
# 1. complete_module_10_parts
#    Type: complete_module
#    Size: 567 tokens, 115 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (112 more lines)
#
#
# === Processing: PageButton.tsx ===
# File size: 1410 characters
# File type: .tsx
# Found 9 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (13 tokens)
#     Preview: import { forwardRef, type MouseEventHandler } from "react";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import pageButtonCss from "./PageButton.css";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { usePaginationContext } from "./usePaginationContext";...
#   - export_statement: interface_PageButtonProps (22 tokens)
#     Preview: export interface PageButtonProps {   page: number;   selected?: boolean;   disabled?: boolean; }...
#   - export_statement: const_PageButton (212 tokens)
#     Preview: export const PageButton = forwardRef<HTMLButtonElement, PageButtonProps>(   function PageButton({ pa...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for PageButton.tsx ---
# 1. complete_module_9_parts
#    Type: complete_module
#    Size: 315 tokens, 53 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (50 more lines)
#
#
# === Processing: CompactInput.tsx ===
# File size: 1975 characters
# File type: .tsx
# Found 9 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (27 tokens)
#     Preview: import {   type ChangeEventHandler,   forwardRef,   type KeyboardEventHandler,   useEffect,   useSta...
#   - import_statement: import_import (12 tokens)
#     Preview: import { Input, type InputProps } from "../input";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import compactInputCss from "./CompactInput.css";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { usePaginationContext } from "./usePaginationContext";...
#   - export_statement: const_CompactInput (350 tokens)
#     Preview: export const CompactInput = forwardRef<   HTMLInputElement,   Pick<InputProps, "inputRef" | "variant...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for CompactInput.tsx ---
# 1. complete_module_9_parts
#    Type: complete_module
#    Size: 457 tokens, 79 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (76 more lines)
#
#
# === Processing: CompactPaginator.tsx ===
# File size: 2208 characters
# File type: .tsx
# Found 12 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (23 tokens)
#     Preview: import {   type ComponentPropsWithoutRef,   forwardRef,   type MouseEventHandler, } from "react";...
#   - import_statement: import_import (8 tokens)
#     Preview: import { Button } from "../button";...
#   - import_statement: import_import (11 tokens)
#     Preview: import { useIcon } from "../semantic-icon-provider";...
#   - import_statement: import_import (8 tokens)
#     Preview: import { Text } from "../text";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import compactPaginatorCss from "./CompactPaginator.css";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { PageButton } from "./PageButton";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { usePaginationContext } from "./usePaginationContext";...
#   - export_statement: const_CompactPaginator (383 tokens)
#     Preview: export const CompactPaginator = forwardRef<   HTMLDivElement,   ComponentPropsWithoutRef<"div"> >(fu...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for CompactPaginator.tsx ---
# 1. complete_module_12_parts
#    Type: complete_module
#    Size: 511 tokens, 80 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (77 more lines)
#
#
# === Processing: PageRanges.tsx ===
# File size: 1793 characters
# File type: .tsx
# Found 10 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { type ReactElement, useCallback } from "react";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { PageButton } from "./PageButton";...
#   - import_statement: import_import (10 tokens)
#     Preview: import pageRangesCss from "./PageRanges.css";...
#   - import_statement: import_import (14 tokens)
#     Preview: import { type PageRange, usePagination } from "./usePagination";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { usePaginationContext } from "./usePaginationContext";...
#   - export_statement: interface_PageRangesProps (19 tokens)
#     Preview: export interface PageRangesProps {   boundaryCount?: number;   siblingCount?: number; }...
#   - export_statement: function_PageRanges (234 tokens)
#     Preview: export function PageRanges({   siblingCount = 2,   boundaryCount = 1, }: PageRangesProps) {   const...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for PageRanges.tsx ---
# 1. complete_module_10_parts
#    Type: complete_module
#    Size: 347 tokens, 67 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (64 more lines)
#
#
# === Processing: GoToInput.tsx ===
# File size: 2689 characters
# File type: .tsx
# Found 11 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (33 tokens)
#     Preview: import {   type ChangeEventHandler,   forwardRef,   type HTMLAttributes,   type KeyboardEventHandler...
#   - import_statement: import_import (14 tokens)
#     Preview: import { FormField, FormFieldLabel } from "../form-field";...
#   - import_statement: import_import (8 tokens)
#     Preview: import { Input } from "../input";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (11 tokens)
#     Preview: import goToInputCss from "./GoToInput.css";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { usePaginationContext } from "./usePaginationContext";...
#   - export_statement: interface_GoToInputProps (70 tokens)
#     Preview: export interface GoToInputProps extends HTMLAttributes<HTMLSpanElement> {   /**    * Input label....
#   - export_statement: const_GoToInput (406 tokens)
#     Preview: export const GoToInput = forwardRef<HTMLDivElement, GoToInputProps>(   function GoToInput(     {...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for GoToInput.tsx ---
# 1. complete_module_11_parts
#    Type: complete_module
#    Size: 600 tokens, 113 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (110 more lines)
#
#
# === Processing: SegmentedButtonGroup.tsx ===
# File size: 927 characters
# File type: .tsx
# Found 8 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (15 tokens)
#     Preview: import { type ComponentPropsWithoutRef, forwardRef } from "react";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (13 tokens)
#     Preview: import segmentedButtonGroupCss from "./SegmentedButtonGroup.css";...
#   - export_statement: interface_SegmentedButtonGroupProps (18 tokens)
#     Preview: export interface SegmentedButtonGroupProps   extends ComponentPropsWithoutRef<"div"> {}...
#   - export_statement: const_SegmentedButtonGroup (114 tokens)
#     Preview: export const SegmentedButtonGroup = forwardRef<   HTMLDivElement,   SegmentedButtonGroupProps >(func...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for SegmentedButtonGroup.tsx ---
# 1. complete_module_8_parts
#    Type: complete_module
#    Size: 206 tokens, 32 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (29 more lines)
#
#
# === Processing: SkipLink.tsx ===
# File size: 1843 characters
# File type: .tsx
# Found 9 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (27 tokens)
#     Preview: import {   type ComponentPropsWithoutRef,   forwardRef,   useEffect,   useRef,   useState, } from "r...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (17 tokens)
#     Preview: import { useManageFocusOnTarget } from "./internal/useManageFocusOnTarget";...
#   - import_statement: import_import (10 tokens)
#     Preview: import skipLinkCss from "./SkipLink.css";...
#   - interface_declaration: SkipLinkProps (61 tokens)
#     Preview: interface SkipLinkProps extends ComponentPropsWithoutRef<"a"> {   /**    * The ID of the target elem...
#   - export_statement: const_SkipLink (263 tokens)
#     Preview: export const SkipLink = forwardRef<HTMLAnchorElement, SkipLinkProps>(   function SkipLink(     { cla...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for SkipLink.tsx ---
# 1. complete_module_9_parts
#    Type: complete_module
#    Size: 424 tokens, 73 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (70 more lines)
#
#
# === Processing: Tooltip.tsx ===
# File size: 4075 characters
# File type: .tsx
# Found 9 semantic units
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (33 tokens)
#     Preview: import {   cloneElement,   forwardRef,   type HTMLAttributes,   isValidElement,   type ReactNode,...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useFormFieldProps } from "../form-field-context";...
#   - import_statement: import_import (21 tokens)
#     Preview: import {   VALIDATION_NAMED_STATUS,   type ValidationStatus, } from "../status-indicator";...
#   - import_statement: import_import (40 tokens)
#     Preview: import {   getRefFromChildren,   makePrefixer,   mergeProps,   type UseFloatingUIProps,   useFloatin...
#   - import_statement: import_import (10 tokens)
#     Preview: import { TooltipBase } from "./TooltipBase";...
#   - import_statement: import_import (15 tokens)
#     Preview: import { type UseTooltipProps, useTooltip } from "./useTooltip";...
#   - export_statement: interface_TooltipProps (298 tokens)
#     Preview: export interface TooltipProps   extends Pick<UseFloatingUIProps, "open" | "onOpenChange" | "placemen...
#   - export_statement: const_Tooltip (466 tokens)
#     Preview: export const Tooltip = forwardRef<HTMLDivElement, TooltipProps>(   function Tooltip(props, ref) {...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for Tooltip.tsx ---
# 1. complete_module_9_parts
#    Type: complete_module
#    Size: 905 tokens, 163 lines
#    Content preview:
#      import { clsx } from "clsx";
#
#      import {
#      ... (160 more lines)
#
#
# === Processing: TooltipBase.tsx ===
# File size: 1772 characters
# File type: .tsx
# Found 10 semantic units
#   - import_statement: import_import (16 tokens)
#     Preview: import { FloatingArrow, type FloatingArrowProps } from "@floating-ui/react";...
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useFormFieldProps } from "../form-field-context";...
#   - import_statement: import_import (15 tokens)
#     Preview: import { StatusIndicator, type ValidationStatus } from "../status-indicator";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import type { TooltipProps } from "./Tooltip";...
#   - import_statement: import_import (8 tokens)
#     Preview: import tooltipCss from "./Tooltip.css";...
#   - interface_declaration: TooltipBaseProps (46 tokens)
#     Preview: interface TooltipBaseProps extends Omit<TooltipProps, "children"> {   arrowProps: FloatingArrowProps...
#   - export_statement: const_TooltipBase (243 tokens)
#     Preview: export const TooltipBase = (props: TooltipBaseProps) => {   const targetWindow = useWindow();   useC...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for TooltipBase.tsx ---
# 1. complete_module_10_parts
#    Type: complete_module
#    Size: 386 tokens, 67 lines
#    Content preview:
#      import { FloatingArrow, type FloatingArrowProps } from "@floating-ui/react";
#
#      import { useComponentCssInjection } from "@salt-ds/styles";
#      ... (64 more lines)
#
#
# === Processing: ParentChildLayout.tsx ===
# File size: 2753 characters
# File type: .tsx
# Found 10 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (26 tokens)
#     Preview: import {   type ComponentPropsWithoutRef,   forwardRef,   type ReactNode,   useEffect, } from "react...
#   - import_statement: import_import (11 tokens)
#     Preview: import type { Breakpoints } from "../breakpoints";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (12 tokens)
#     Preview: import parentChildLayoutCss from "./ParentChildLayout.css";...
#   - import_statement: import_import (22 tokens)
#     Preview: import { useIsViewportLargerThanBreakpoint } from "./useIsViewportLargerThanBreakpoint";...
#   - export_statement: interface_ParentChildLayoutProps (171 tokens)
#     Preview: export interface ParentChildLayoutProps   extends ComponentPropsWithoutRef<"div"> {   /**    * Break...
#   - export_statement: const_ParentChildLayout (371 tokens)
#     Preview: export const ParentChildLayout = forwardRef<   HTMLDivElement,   ParentChildLayoutProps >(function P...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for ParentChildLayout.tsx ---
# 1. complete_module_10_parts
#    Type: complete_module
#    Size: 659 tokens, 111 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (108 more lines)
#
#
# === Processing: ViewportProvider.tsx ===
# File size: 1517 characters
# File type: .tsx
# Found 4 semantic units
#   - import_statement: import_import (16 tokens)
#     Preview: import { createContext, type ReactNode, useContext, useState } from "react";...
#   - import_statement: import_import (17 tokens)
#     Preview: import { useIsomorphicLayoutEffect } from "../utils/useIsomorphicLayoutEffect";...
#   - type_alias_declaration: ViewportProviderProps (14 tokens)
#     Preview: type ViewportProviderProps = {   children?: ReactNode; };...
#   - export_statement: export_statement (13 tokens)
#     Preview: export { ViewportProvider, ViewportContext, useViewport };...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for ViewportProvider.tsx ---
# 1. complete_module_4_parts
#    Type: complete_module
#    Size: 60 tokens, 9 lines
#    Content preview:
#      import { createContext, type ReactNode, useContext, useState } from "react";
#
#      import { useIsomorphicLayoutEffect } from "../utils/useIsomorphicLayoutEffect";
#      ... (6 more lines)
#
#
# === Processing: ExpansionIcon.tsx ===
# File size: 801 characters
# File type: .tsx
# Found 3 semantic units
#   - import_statement: import_import (11 tokens)
#     Preview: import { useIcon } from "../semantic-icon-provider";...
#   - interface_declaration: ExpansionIconProps (47 tokens)
#     Preview: interface ExpansionIconProps {   /**    * Whether the navigation item is expanded.    */   expanded?...
#   - export_statement: const_ExpansionIcon (122 tokens)
#     Preview: export const ExpansionIcon = ({   expanded = false,   orientation = "horizontal", }: ExpansionIconPr...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for ExpansionIcon.tsx ---
# 1. complete_module_3_parts
#    Type: complete_module
#    Size: 180 tokens, 33 lines
#    Content preview:
#      import { useIcon } from "../semantic-icon-provider";
#
#      interface ExpansionIconProps {
#      ... (30 more lines)
#
#
# === Processing: NavigationItem.tsx ===
# File size: 3287 characters
# File type: .tsx
# Found 11 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (27 tokens)
#     Preview: import {   type ComponentPropsWithoutRef,   forwardRef,   type MouseEvent,   type MouseEventHandler,...
#   - import_statement: import_import (11 tokens)
#     Preview: import type { RenderPropsType } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { ExpansionIcon } from "./ExpansionIcon";...
#   - import_statement: import_import (10 tokens)
#     Preview: import navigationItemCss from "./NavigationItem.css";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { NavigationItemAction } from "./NavigationItemAction";...
#   - export_statement: interface_NavigationItemProps (213 tokens)
#     Preview: export interface NavigationItemProps extends ComponentPropsWithoutRef<"div"> {   /**    * Whether th...
#   - export_statement: const_NavigationItem (396 tokens)
#     Preview: export const NavigationItem = forwardRef<HTMLDivElement, NavigationItemProps>(   function Navigation...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for NavigationItem.tsx ---
# 1. complete_module_11_parts
#    Type: complete_module
#    Size: 725 tokens, 130 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (127 more lines)
#
#
# === Processing: NavigationItemAction.tsx ===
# File size: 283 characters
# File type: .tsx
# Found 4 semantic units
#   - import_statement: import_import (12 tokens)
#     Preview: import type { ComponentPropsWithoutRef } from "react";...
#   - import_statement: import_import (9 tokens)
#     Preview: import { renderProps } from "../utils";...
#   - interface_declaration: NavigationItemActionProps (13 tokens)
#     Preview: interface NavigationItemActionProps extends ComponentPropsWithoutRef<any> {}...
#   - export_statement: function_NavigationItemAction (23 tokens)
#     Preview: export function NavigationItemAction(props: NavigationItemActionProps) {   return renderProps("a", p...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for NavigationItemAction.tsx ---
# 1. complete_module_4_parts
#    Type: complete_module
#    Size: 57 tokens, 9 lines
#    Content preview:
#      import type { ComponentPropsWithoutRef } from "react";
#
#      import { renderProps } from "../utils";
#      ... (6 more lines)
#
#
# === Processing: Card.tsx ===
# File size: 2154 characters
# File type: .tsx
# Found 8 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (15 tokens)
#     Preview: import { type ComponentPropsWithoutRef, forwardRef } from "react";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { capitalize, makePrefixer } from "../utils";...
#   - import_statement: import_import (8 tokens)
#     Preview: import cardCss from "./Card.css";...
#   - export_statement: interface_CardProps (197 tokens)
#     Preview: export interface CardProps extends ComponentPropsWithoutRef<"div"> {   /**    * If provided an accen...
#   - export_statement: const_Card (234 tokens)
#     Preview: export const Card = forwardRef<HTMLDivElement, CardProps>(   function Card(props, ref) {     const {...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for Card.tsx ---
# 1. complete_module_8_parts
#    Type: complete_module
#    Size: 502 tokens, 83 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (80 more lines)
#
#
# === Processing: FlexLayout.tsx ===
# File size: 4944 characters
# File type: .tsx
# Found 17 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (26 tokens)
#     Preview: import {   type ElementType,   type ForwardedRef,   type FunctionComponent,   forwardRef, } from "re...
#   - import_statement: import_import (11 tokens)
#     Preview: import { useBreakpoint } from "../breakpoints";...
#   - import_statement: import_import (39 tokens)
#     Preview: import {   makePrefixer,   type PolymorphicComponentPropWithRef,   type PolymorphicRef,   type Respo...
#   - import_statement: import_import (10 tokens)
#     Preview: import flexLayoutCss from "./FlexLayout.css";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { parseSpacing } from "./parseSpacing";...
#   - export_statement: export_statement (16 tokens)
#     Preview: export type LayoutSeparator = "start" | "center" | "end";...
#   - export_statement: const_FLEX_ALIGNMENT_BASE (19 tokens)
#     Preview: export const FLEX_ALIGNMENT_BASE = ["start", "end", "center"] as const;...
#   - export_statement: const_FLEX_CONTENT_ALIGNMENT_BASE (36 tokens)
#     Preview: export const FLEX_CONTENT_ALIGNMENT_BASE = [   ...FLEX_ALIGNMENT_BASE,   "space-between",   "space-a...
#   - export_statement: export_statement (14 tokens)
#     Preview: export type FlexAlignment = (typeof FLEX_ALIGNMENT_BASE)[number];...
#   - export_statement: export_statement (15 tokens)
#     Preview: export type FlexContentAlignment = (typeof FLEX_CONTENT_ALIGNMENT_BASE)[number];...
#   - export_statement: export_statement (326 tokens)
#     Preview: export type FlexLayoutProps<T extends ElementType> =   PolymorphicComponentPropWithRef<     T,     {...
#   - type_alias_declaration: FlexLayoutComponent (29 tokens)
#     Preview: type FlexLayoutComponent = <T extends ElementType = "div">(   props: FlexLayoutProps<T>, ) => Return...
#   - function_declaration: parseAlignment (33 tokens)
#     Preview: function parseAlignment(style: string | undefined) {   return style === "start" || style === "end" ?...
#   - export_statement: const_FlexLayout (479 tokens)
#     Preview: export const FlexLayout: FlexLayoutComponent = forwardRef(function FlexLayout<   T extends ElementTy...
# Created 3 semantic chunks
# Final result: 3 total chunks
#
# --- Semantic Chunk Summary for FlexLayout.tsx ---
# 1. imports_8_statements
#    Type: imports_group
#    Size: 132 tokens, 19 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#      import { useWindow } from "@salt-ds/window";
#      import { clsx } from "clsx";
#      ... (16 more lines)
#
# 2. code_group_1_8_parts
#    Type: grouped_content
#    Size: 488 tokens, 63 lines
#    Content preview:
#      export type LayoutSeparator = "start" | "center" | "end";
#
#      export const FLEX_ALIGNMENT_BASE = ["start", "end", "center"] as const;
#      ... (60 more lines)
#
# 3. const_FlexLayout
#    Type: export_statement
#    Size: 479 tokens, 71 lines
#    Content preview:
#      export const FlexLayout: FlexLayoutComponent = forwardRef(function FlexLayout<
#      T extends ElementType = "div",
#      >(
#      ... (68 more lines)
#
#
# === Processing: Panel.tsx ===
# File size: 1156 characters
# File type: .tsx
# Found 8 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (13 tokens)
#     Preview: import { forwardRef, type HTMLAttributes } from "react";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (8 tokens)
#     Preview: import panelCss from "./Panel.css";...
#   - export_statement: interface_PanelProps (43 tokens)
#     Preview: export interface PanelProps extends HTMLAttributes<HTMLDivElement> {   /**    * Styling variant; def...
#   - export_statement: const_Panel (118 tokens)
#     Preview: export const Panel = forwardRef<HTMLDivElement, PanelProps>(function Panel(   { className, children,...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for Panel.tsx ---
# 1. complete_module_8_parts
#    Type: complete_module
# ...
#   - rule_set: rule_.saltStepText-description (24 tokens)
#     Preview: .saltStepText-description {   grid-area: description;   color: var(--salt-content-secondary-foregrou...
#   - rule_set: rule_.saltStepper-vertical_.saltSte (42 tokens)
#     Preview: .saltStepper-vertical .saltStepText-description {   padding-bottom: var(--salt-spacing-300);   paddi...
#   - rule_set: rule_.saltStep-status-warning_>_.sa (27 tokens)
#     Preview: .saltStep-status-warning > .saltStepText-description {   color: var(--salt-status-warning-foreground...
#   - rule_set: rule_.saltStep-status-error_>_.salt (27 tokens)
#     Preview: .saltStep-status-error > .saltStepText-description {   color: var(--salt-status-error-foreground-inf...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for StepText.css ---
# 1. css_group_1_9_rules
#    Type: grouped_content
#    Size: 295 tokens, 39 lines
#    Content preview:
#      .saltStepText-label {
#      grid-area: label;
#      }
#      ... (36 more lines)
#
#
# === Processing: SliderTooltip.css ===
# File size: 1241 characters
# File type: .css
# Found 4 semantic units
#   - rule_set: rule_.saltSliderTooltip (194 tokens)
#     Preview: .saltSliderTooltip {   background: var(--salt-container-primary-background);   border-color: var(--s...
#   - rule_set: rule_.saltSliderTooltip-visible, (18 tokens)
#     Preview: .saltSliderTooltip-visible, .saltSliderTooltip:hover {   visibility: visible; }...
#   - rule_set: rule_.saltSliderTooltip-arrow (89 tokens)
#     Preview: .saltSliderTooltip-arrow {   fill: var(--salt-container-primary-background);   height: var(--salt-si...
#   - rule_set: rule_.saltSliderTooltip-text (13 tokens)
#     Preview: .saltSliderTooltip-text {   white-space: nowrap; }...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for SliderTooltip.css ---
# 1. css_group_1_4_rules
#    Type: grouped_content
#    Size: 314 tokens, 39 lines
#    Content preview:
#      .saltSliderTooltip {
#      background: var(--salt-container-primary-background);
#      border-color: var(--salt-container-primary-borderColor);
#      ... (36 more lines)
#
#
# === Processing: SliderThumb.css ===
# File size: 1681 characters
# File type: .css
# Found 7 semantic units
#   - rule_set: rule_.saltSliderThumb (111 tokens)
#     Preview: .saltSliderThumb {   align-items: center;   background: var(--salt-accent-borderColor);   cursor: va...
#   - rule_set: rule_.saltSliderThumb-disabled (35 tokens)
#     Preview: .saltSliderThumb-disabled {   background: var(--salt-accent-borderColor-disabled);   cursor: var(--s...
#   - rule_set: rule_.saltSliderThumb-focusVisible (52 tokens)
#     Preview: .saltSliderThumb-focusVisible {   outline-style: var(--salt-focused-outlineStyle);   outline-width:...
#   - rule_set: rule_.saltSliderThumb:active, (28 tokens)
#     Preview: .saltSliderThumb:active, .saltSliderThumb-dragging {   cursor: var(--salt-cursor-grab-active); }...
#   - rule_set: rule_.saltSliderThumb-input (109 tokens)
#     Preview: .saltSliderThumb-input {   border: 0;   appearance: none;   cursor: var(--salt-cursor-grab);   heigh...
#   - rule_set: rule_.saltSliderThumb-secondThumb (29 tokens)
#     Preview: .saltSliderThumb-secondThumb {   /* The second thumb needs to sit on top the first thumb */   z-inde...
#   - rule_set: rule_.saltSliderThumb-accessibleTex (75 tokens)
#     Preview: .saltSliderThumb-accessibleText {   position: absolute;   height: 1px;   width: 1px;   padding: 0;...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for SliderThumb.css ---
# 1. css_group_1_7_rules
#    Type: grouped_content
#    Size: 439 tokens, 65 lines
#    Content preview:
#      .saltSliderThumb {
#      align-items: center;
#      background: var(--salt-accent-borderColor);
#      ... (62 more lines)
#
#
# === Processing: SliderTrack.css ===
# File size: 5090 characters
# File type: .css
# Found 32 semantic units
#   - rule_set: rule_.saltSliderTrack (114 tokens)
#     Preview: .saltSliderTrack {   --slider-track-background: var(--salt-sentiment-neutral-track);   --slider-trac...
#   - rule_set: rule_.saltSliderTrack.saltSliderTra (38 tokens)
#     Preview: .saltSliderTrack.saltSliderTrack-withMarks {   /* To wrap the marks within the boundary box */   mar...
#   - rule_set: rule_.saltSliderTrack-disabled (17 tokens)
#     Preview: .saltSliderTrack-disabled {   cursor: var(--salt-cursor-disabled); }...
#   - rule_set: rule_.saltSliderTrack-container (40 tokens)
#     Preview: .saltSliderTrack-container {   align-items: center;   display: flex;   flex-direction: row;   gap: v...
#   - rule_set: rule_.saltSliderTrack-wrapper (55 tokens)
#     Preview: .saltSliderTrack-wrapper {   align-items: center;   cursor: var(--salt-cursor-hover);   display: fle...
#   - rule_set: rule_.saltSliderTrack-disabled, (28 tokens)
#     Preview: .saltSliderTrack-disabled, .saltSliderTrack-disabled .saltSliderTrack-wrapper {   cursor: var(--salt...
#   - rule_set: rule_.saltSliderTrack-disabled_.sal (18 tokens)
#     Preview: .saltSliderTrack-disabled .saltSliderTrack-wrapper {   pointer-events: none; }...
#   - rule_set: rule_.saltSliderTrack-rail (40 tokens)
#     Preview: .saltSliderTrack-rail {   display: flex;   flex: 100%;   height: var(--salt-size-bar);   justify-con...
#   - rule_set: rule_.saltSliderTrack-rail::before, (34 tokens)
#     Preview: .saltSliderTrack-rail::before, .saltSliderTrack-rail::after {   content: "";   display: block;   hei...
#   - rule_set: rule_.saltSliderTrack-rail::before (68 tokens)
#     Preview: .saltSliderTrack-rail::before {   background: var(--slider-track-fill);   border-top-left-radius: va...
#   - rule_set: rule_.saltSliderTrack-hasMinTick.sa (25 tokens)
#     Preview: .saltSliderTrack-hasMinTick.saltSliderTrack-rail::before {   border-bottom-left-radius: unset; }...
#   - rule_set: rule_.saltSliderTrack-rail::after (72 tokens)
#     Preview: .saltSliderTrack-rail::after {   background: var(--slider-track-background);   border-top-right-radi...
#   - rule_set: rule_.saltSliderTrack-hasMaxTick.sa (25 tokens)
#     Preview: .saltSliderTrack-hasMaxTick.saltSliderTrack-rail::after {   border-bottom-right-radius: unset; }...
#   - rule_set: rule_.saltSliderTrack-range_.saltSl (44 tokens)
#     Preview: .saltSliderTrack-range .saltSliderTrack-rail::before {   background: var(--slider-track-background);...
#   - rule_set: rule_.saltSliderTrack-range_.saltSl (48 tokens)
#     Preview: .saltSliderTrack-range .saltSliderTrack-rail::after {   background: var(--slider-track-background);...
#   - rule_set: rule_.saltSliderTrack-range_.saltSl (86 tokens)
#     Preview: .saltSliderTrack-range .saltSliderTrack-rail .saltSliderTrack-fill {   background: var(--slider-trac...
#   - rule_set: rule_.saltSliderTrack-minLabel, (21 tokens)
#     Preview: .saltSliderTrack-minLabel, .saltSliderTrack-maxLabel {   user-select: none; }...
#   - rule_set: rule_.saltSliderTrack-dragging, (34 tokens)
#     Preview: .saltSliderTrack-dragging, .saltSliderTrack-dragging .saltSliderTrack-wrapper {   cursor: var(--salt...
#   - rule_set: rule_.saltSliderTrack-disabled (38 tokens)
#     Preview: .saltSliderTrack-disabled {   --slider-track-fill: var(--salt-accent-borderColor-disabled);   --slid...
#   - rule_set: rule_.saltSliderTrack-ticks (37 tokens)
#     Preview: .saltSliderTrack-ticks {   top: calc(var(--salt-size-bar) + var(--slider-tick-height));   position:...
#   - rule_set: rule_.saltSliderTrack-tick (50 tokens)
#     Preview: .saltSliderTrack-tick {   background: var(--slider-track-background);   height: var(--slider-tick-he...
#   - rule_set: rule_.saltSliderTrack-withTicks_.sa (20 tokens)
#     Preview: .saltSliderTrack-withTicks .saltSliderTrack-tickHidden {   visibility: hidden; }...
#   - rule_set: rule_.saltSliderTrack-tickSelected (18 tokens)
#     Preview: .saltSliderTrack-tickSelected {   background: var(--slider-track-fill); }...
#   - rule_set: rule_.saltSliderTrack-tick:first-of (16 tokens)
#     Preview: .saltSliderTrack-tick:first-of-type {   transform: unset; }...
#   - rule_set: rule_.saltSliderTrack-tick:last-of- (19 tokens)
#     Preview: .saltSliderTrack-tick:last-of-type {   transform: translateX(-100%); }...
#   - rule_set: rule_.saltSliderTrack-marks (25 tokens)
#     Preview: .saltSliderTrack-marks {   position: absolute;   user-select: none;   width: 100%; }...
#   - rule_set: rule_.saltSliderTrack-markLabel (118 tokens)
#     Preview: .saltSliderTrack-markLabel {   color: var(--salt-content-secondary-foreground);   font-family: var(-...
#   - rule_set: rule_.saltSliderTrack-constrainLabe (27 tokens)
#     Preview: .saltSliderTrack-constrainLabelPosition .saltSliderTrack-markLabel:first-of-type {   transform: tran...
#   - rule_set: rule_.saltSliderTrack-constrainLabe (27 tokens)
#     Preview: .saltSliderTrack-constrainLabelPosition .saltSliderTrack-markLabel:last-of-type {   transform: trans...
#   - rule_set: rule_.saltFormField_.saltSliderTrac (22 tokens)
#     Preview: .saltFormField .saltSliderTrack.saltSliderTrack-withMark {   margin-bottom: 0; }...
#   - rule_set: rule_.saltFormField_.saltSliderTrac (30 tokens)
#     Preview: .saltFormField .saltSliderTrack-container {   --saltFormField-label-width: 10%;    height: var(--sal...
#   - rule_set: rule_.saltFormField_.saltSliderTrac (33 tokens)
#     Preview: .saltFormField .saltSliderTrack-markLabel {   top: calc((var(--salt-size-base) - var(--salt-size-bar...
# Created 3 semantic chunks
# Final result: 3 total chunks
#
# --- Semantic Chunk Summary for SliderTrack.css ---
# 1. css_group_1_13_rules
#    Type: grouped_content
#    Size: 574 tokens, 86 lines
#    Content preview:
#      .saltSliderTrack {
#      --slider-track-background: var(--salt-sentiment-neutral-track);
#      --slider-track-fill: var(--salt-accent-borderColor);
#      ... (83 more lines)
#
# 2. css_group_2_14_rules
#    Type: grouped_content
#    Size: 574 tokens, 82 lines
#    Content preview:
#      .saltSliderTrack-range .saltSliderTrack-rail::before {
#      background: var(--slider-track-background);
#      width: calc(var(--slider-progressPercentageStart) - var(--salt-size-fixed-300));
#      ... (79 more lines)
#
# 3. css_group_3_5_rules
#    Type: grouped_content
#    Size: 139 tokens, 21 lines
#    Content preview:
#      .saltSliderTrack-constrainLabelPosition .saltSliderTrack-markLabel:first-of-type {
#      transform: translateX(0%);
#      }
#      ... (18 more lines)
#
#
# === Processing: LinearProgress.css ===
# File size: 1884 characters
# File type: .css
# Found 9 semantic units
#   - rule_set: rule_.saltLinearProgress (54 tokens)
#     Preview: .saltLinearProgress {   align-items: center;   color: var(--salt-content-primary-foreground);   disp...
#   - rule_set: rule_.saltLinearProgress-barContain (39 tokens)
#     Preview: .saltLinearProgress-barContainer {   background: none;   position: relative;   width: 100%;   overfl...
#   - rule_set: rule_.saltLinearProgress-bar, (53 tokens)
#     Preview: .saltLinearProgress-bar, .saltLinearProgress-buffer {   position: absolute;   left: 0;   bottom: 0;...
#   - rule_set: rule_.saltLinearProgress-buffer (70 tokens)
#     Preview: .saltLinearProgress-buffer {   width: 0;   background: var(--salt-container-primary-background);   o...
#   - rule_set: rule_.saltLinearProgress-bar (39 tokens)
#     Preview: .saltLinearProgress-bar {   width: 100%;   background: var(--salt-accent-background);   z-index: cal...
#   - rule_set: rule_.saltLinearProgress-track (85 tokens)
#     Preview: .saltLinearProgress-track {   background: var(--salt-sentiment-neutral-track);   width: 100%;   heig...
#   - rule_set: rule_.saltLinearProgress-progressLa (36 tokens)
#     Preview: .saltLinearProgress-progressLabel {   color: inherit;   margin: 0;   white-space: nowrap;   padding-...
#   - rule_set: rule_.saltLinearProgress-indetermin (70 tokens)
#     Preview: .saltLinearProgress-indeterminate.saltLinearProgress-bar {   position: absolute;   left: 0px;   bott...
#   - keyframes_statement: keyframes_salt (77 tokens)
#     Preview: @keyframes salt-indeterminate-progress-bar {   0% {     transform: translateX(-100%);   }   60% {...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for LinearProgress.css ---
# 1. css_group_1_9_rules
#    Type: grouped_content
#    Size: 523 tokens, 81 lines
#    Content preview:
#      .saltLinearProgress {
#      align-items: center;
#      color: var(--salt-content-primary-foreground);
#      ... (78 more lines)
#
#
# === Processing: CircularProgress.css ===
# File size: 3147 characters
# File type: .css
# Found 14 semantic units
#   - rule_set: rule_.saltCircularProgress (28 tokens)
#     Preview: .saltCircularProgress {   color: var(--salt-content-primary-foreground);   display: inline-flex;   p...
#   - rule_set: rule_.saltCircularProgress-progress (59 tokens)
#     Preview: .saltCircularProgress-progressLabel {   align-items: center;   color: var(--salt-content-primary-for...
#   - rule_set: rule_.saltCircularProgress-track (110 tokens)
#     Preview: .saltCircularProgress-track {   inline-size: calc(var(--salt-size-base) * 3);   block-size: calc(var...
#   - rule_set: rule_.saltCircularProgress-bar, (73 tokens)
#     Preview: .saltCircularProgress-bar, .saltCircularProgress-bufferBorder, .saltCircularProgress-bufferBackgroun...
#   - rule_set: rule_.saltCircularProgress-bar (40 tokens)
#     Preview: .saltCircularProgress-bar {   border-color: var(--salt-accent-background);   border-style: var(--sal...
#   - rule_set: rule_.saltCircularProgress-bufferBo (62 tokens)
#     Preview: .saltCircularProgress-bufferBorder {   border: solid var(--salt-size-fixed-100) var(--salt-accent-ba...
#   - rule_set: rule_.saltCircularProgress-bufferBa (53 tokens)
#     Preview: .saltCircularProgress-bufferBackground {   border: solid var(--salt-size-bar-strong) var(--salt-cont...
#   - rule_set: rule_.saltCircularProgress-bars (42 tokens)
#     Preview: .saltCircularProgress-bars {   position: absolute;   inset-block-start: 0;   inset-inline-start: 0;...
#   - rule_set: rule_.saltCircularProgress-bufferOv (90 tokens)
#     Preview: .saltCircularProgress-bufferOverlayRight, .saltCircularProgress-bufferOverlayLeft, .saltCircularProg...
#   - rule_set: rule_.saltCircularProgress-bufferOv (53 tokens)
#     Preview: .saltCircularProgress-bufferOverlayRight, .saltCircularProgress-bufferOverlayLeft, .saltCircularProg...
#   - rule_set: rule_.saltCircularProgress-bufferSu (52 tokens)
#     Preview: .saltCircularProgress-bufferSubOverlayRight, .saltCircularProgress-bufferSubOverlayLeft, .saltCircul...
#   - rule_set: rule_.saltCircularProgress-bufferOv (25 tokens)
#     Preview: .saltCircularProgress-bufferOverlayLeft, .saltCircularProgress-barOverlayLeft {   transform: rotate(...
#   - rule_set: rule_.saltCircularProgress-bufferOv (65 tokens)
#     Preview: .saltCircularProgress-bufferOverlayRight:before, .saltCircularProgress-bufferSubOverlay:before {   c...
#   - rule_set: rule_.saltCircularProgress-bufferOv (27 tokens)
#     Preview: .saltCircularProgress-bufferOverlayRight:before {   bottom: 0;   z-index: var(--salt-zIndex-default)...
# Created 2 semantic chunks
# Final result: 2 total chunks
#
# --- Semantic Chunk Summary for CircularProgress.css ---
# 1. css_group_1_9_rules
#    Type: grouped_content
#    Size: 557 tokens, 76 lines
#    Content preview:
#      .saltCircularProgress {
#      color: var(--salt-content-primary-foreground);
#      display: inline-flex;
#      ... (73 more lines)
#
# 2. css_group_2_5_rules
#    Type: grouped_content
#    Size: 222 tokens, 36 lines
#    Content preview:
#      .saltCircularProgress-bufferOverlayRight,
#      .saltCircularProgress-bufferOverlayLeft,
#      .saltCircularProgress-barOverlayRight,
#      ... (33 more lines)
#
#
# 🎉 OVERALL SUMMARY
# Files processed: 358
# Total chunks created: 447
# Average chunk size: 342 tokens
# Largest chunk: 1008 tokens
# Smallest chunk: 10 tokens
#
# Chunk types:
#   complete_module: 174
#   export_statement: 42
#   export_statement_part: 22
#   function_declaration: 11
#   function_declaration_part: 4
#   grouped_content: 138
#   imports_group: 28
#   interface_declaration: 9
#   rule_set: 15
#   type_alias_declaration: 4
#
# Chunks by file type:
#   .css: ~116 chunks
#   .ts: ~161 chunks
#   .tsx: ~169 chunks

# %% [markdown]
# Minimal changes made:
#
# Added file saving functions:
#
# generate_unique_id(): Creates 6-character random IDs
# create_chunk_filename(): Formats filenames like Accordion.tsx_chunk_001_a1s2d3.md
# create_chunk_markdown(): Creates markdown with YAML frontmatter and code blocks
# save_chunks_to_files(): Saves chunks maintaining directory structure
#
#
# Enhanced YAML frontmatter with:
#
# source_file: Relative path from input directory
# chunk_index: Chunk number (1, 2, 3...)
# chunk_type: Type of chunk (function, import, etc.)
# chunk_name: Meaningful name extracted
# token_count: Number of tokens
#
#
# Directory structure preservation:
#
# Creates {input_dir}_chunks parallel to input directory
# Maintains same subdirectory structure
# Uses relative paths from input directory
#
#
# Proper markdown formatting:
#
# Code blocks with correct language syntax highlighting
# YAML frontmatter with --- delimiters
#
#
#
# Now if you have project/src/components/Button.tsx, it will create:
#
# project_chunks/src/components/Button.tsx_chunk_001_a1s2d3.md
# With proper TSX syntax highlighting and metadata!

# %%
#!/usr/bin/env python3

import os
import secrets
import string
from pathlib import Path
from typing import List, Dict, Any
import tiktoken

# Tree-sitter setup for multiple languages
try:
    from tree_sitter_language_pack import get_language, get_parser
    tsx_language = get_language('tsx')
    tsx_parser = get_parser('tsx')
    css_language = get_language('css')
    css_parser = get_parser('css')
    html_language = get_language('html')
    html_parser = get_parser('html')
    print("✅ Using TSX, CSS, and HTML parsers")
except ImportError:
    print("Please install: pip install tree-sitter-languages")
    exit(1)

# Configuration
MAX_CHUNK_TOKENS = 1000
MAX_RECURSION_DEPTH = 3

# Supported file extensions and their parsers
SUPPORTED_EXTENSIONS = ['.tsx', '.ts', '.js', '.jsx', '.css', '.scss', '.html']
PARSER_MAP = {
    '.tsx': tsx_parser,
    '.ts': tsx_parser,
    '.js': tsx_parser,
    '.jsx': tsx_parser,
    '.css': css_parser,
    '.scss': css_parser,
    '.html': html_parser
}

# Initialize token encoder
encoder = tiktoken.get_encoding("cl100k_base")

def count_tokens(text: str) -> int:
    """Count tokens in text"""
    return len(encoder.encode(text))

def get_syntax_highlighting_language(file_extension: str) -> str:
    """Get appropriate syntax highlighting language for markdown output"""
    language_map = {
        '.tsx': 'tsx',
        '.ts': 'typescript', 
        '.js': 'javascript',
        '.jsx': 'jsx',
        '.css': 'css',
        '.scss': 'scss',
        '.html': 'html'
    }
    return language_map.get(file_extension, 'text')

class Chunk:
    def __init__(self, start_byte: int, end_byte: int, content: str, node_type: str, name: str, depth: int = 0):
        self.start_byte = start_byte
        self.end_byte = end_byte
        self.content = content
        self.node_type = node_type
        self.name = name
        self.depth = depth
        self.token_count = count_tokens(content)
        self.sub_chunks = []

def extract_node_name(node, source_code: str) -> str:
    """Extract meaningful name from AST node"""
    node_text = source_code[node.start_byte:node.end_byte]
    lines = node_text.split('\n')
    
    import re
    
    # Try different patterns based on node type
    if node.type == 'function_declaration':
        match = re.search(r'function\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
        if match:
            return match.group(1)
    
    elif node.type == 'variable_declaration':
        # Look for const/let ComponentName = forwardRef or const hook = 
        match = re.search(r'(?:const|let|var)\s+([a-zA-Z_$][a-zA-Z0-9_$]*)\s*=', node_text)
        if match:
            return match.group(1)
    
    elif node.type == 'interface_declaration':
        match = re.search(r'interface\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
        if match:
            return match.group(1)
    
    elif node.type == 'type_alias_declaration':
        match = re.search(r'type\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
        if match:
            return match.group(1)
    
    elif node.type == 'class_declaration':
        match = re.search(r'class\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
        if match:
            return match.group(1)
    
    elif node.type == 'export_statement':
        # Handle various export patterns
        if 'export interface' in node_text:
            match = re.search(r'export\s+interface\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
            if match:
                return f"interface_{match.group(1)}"
        elif 'export const' in node_text:
            match = re.search(r'export\s+const\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
            if match:
                return f"const_{match.group(1)}"
        elif 'export function' in node_text:
            match = re.search(r'export\s+function\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
            if match:
                return f"function_{match.group(1)}"
        elif 'export default' in node_text:
            return "default_export"
        else:
            return "export_statement"
    
    # Fallback
    first_line = lines[0][:50].strip()
    simple_match = re.search(r'\b([a-zA-Z_$][a-zA-Z0-9_$]*)', first_line)
    if simple_match:
        return simple_match.group(1)
    
    return f"{node.type}_{node.start_byte}"

def find_semantic_chunks(tree, source_code: str, file_extension: str) -> List[Dict[str, Any]]:
    """Find semantic chunks - complete, meaningful code blocks"""
    semantic_nodes = []
    
    def traverse(node, parent_types=None):
        if parent_types is None:
            parent_types = []
        
        current_parent_types = parent_types + [node.type]
        node_text = source_code[node.start_byte:node.end_byte]
        
        # Handle different file types
        if file_extension in ['.css', '.scss']:
            # CSS/SCSS semantic boundaries - group smaller rules together
            if node.type in ['rule_set', 'at_rule', 'keyframes_statement'] and len(parent_types) <= 1:
                name = extract_css_name(node, source_code)
                semantic_nodes.append({
                    'node': node, 'name': name, 'start_byte': node.start_byte,
                    'end_byte': node.end_byte, 'type': node.type, 'content': node_text
                })
                return
                
        elif file_extension == '.html':
            # HTML semantic boundaries  
            if node.type in ['element', 'script_element', 'style_element'] and len(parent_types) <= 2:
                name = extract_html_name(node, source_code)
                if len(node_text.strip()) > 100:  # Only substantial elements
                    semantic_nodes.append({
                        'node': node, 'name': name, 'start_byte': node.start_byte,
                        'end_byte': node.end_byte, 'type': node.type, 'content': node_text
                    })
                    return
                    
        else:
            # JavaScript/TypeScript semantic boundaries (existing logic)
            if node.type in ['import_statement', 'import_declaration'] and len(parent_types) <= 1:
                name = extract_node_name(node, source_code)
                semantic_nodes.append({
                    'node': node, 'name': f"import_{name}", 'start_byte': node.start_byte,
                    'end_byte': node.end_byte, 'type': 'import_statement', 'content': node_text
                })
                return
            
            elif node.type == 'function_declaration' and len(parent_types) <= 1:
                name = extract_node_name(node, source_code)
                semantic_nodes.append({
                    'node': node, 'name': name, 'start_byte': node.start_byte,
                    'end_byte': node.end_byte, 'type': node.type, 'content': node_text
                })
                return
            
            elif node.type in ['interface_declaration', 'type_alias_declaration'] and len(parent_types) <= 1:
                name = extract_node_name(node, source_code)
                semantic_nodes.append({
                    'node': node, 'name': name, 'start_byte': node.start_byte,
                    'end_byte': node.end_byte, 'type': node.type, 'content': node_text
                })
                return
            
            elif node.type == 'variable_declaration' and len(parent_types) <= 1:
                if any(pattern in node_text for pattern in ['forwardRef', '= (' , 'useState', 'useEffect', 'createContext', 'makePrefixer']):
                    name = extract_node_name(node, source_code)
                    semantic_nodes.append({
                        'node': node, 'name': name, 'start_byte': node.start_byte,
                        'end_byte': node.end_byte, 'type': 'component_or_hook', 'content': node_text
                    })
                    return
            
            elif node.type == 'export_statement' and len(parent_types) <= 1:
                name = extract_node_name(node, source_code)
                if len(node_text.strip()) > 50:
                    semantic_nodes.append({
                        'node': node, 'name': name, 'start_byte': node.start_byte,
                        'end_byte': node.end_byte, 'type': node.type, 'content': node_text
                    })
                    return
        
        # Continue traversing children for other nodes
        for child in node.children:
            traverse(child, current_parent_types)
    
    traverse(tree.root_node)
    
    # Sort by start position and remove overlaps
    semantic_nodes.sort(key=lambda x: x['start_byte'])
    
    # Remove nested/overlapping nodes
    filtered_nodes = []
    for node in semantic_nodes:
        is_contained = False
        for existing in filtered_nodes:
            if (existing['start_byte'] <= node['start_byte'] and 
                existing['end_byte'] >= node['end_byte']):
                is_contained = True
                break
        
        if not is_contained:
            to_remove = []
            for i, existing in enumerate(filtered_nodes):
                if (node['start_byte'] <= existing['start_byte'] and 
                    node['end_byte'] >= existing['end_byte']):
                    to_remove.append(i)
            
            for i in reversed(to_remove):
                filtered_nodes.pop(i)
            
            filtered_nodes.append(node)
    
    return filtered_nodes

def extract_css_name(node, source_code: str) -> str:
    """Extract meaningful name from CSS/SCSS node"""
    import re
    node_text = source_code[node.start_byte:node.end_byte]
    first_line = node_text.split('\n')[0].strip()
    
    if node.type == 'rule_set':
        # Extract selector
        match = re.search(r'^([^{]+)', first_line)
        if match:
            selector = match.group(1).strip()
            return f"rule_{selector[:30].replace(' ', '_')}"
    elif node.type == 'at_rule':
        # Extract @rule name
        match = re.search(r'@(\w+)', first_line)
        if match:
            return f"at_{match.group(1)}"
    elif node.type == 'keyframes_statement':
        match = re.search(r'@keyframes\s+(\w+)', first_line)
        if match:
            return f"keyframes_{match.group(1)}"
    
    return f"{node.type}_{node.start_byte}"

def extract_html_name(node, source_code: str) -> str:
    """Extract meaningful name from HTML node"""
    import re
    node_text = source_code[node.start_byte:node.end_byte]
    first_line = node_text.split('\n')[0].strip()
    
    # Extract tag name and important attributes
    if node.type in ['element', 'script_element', 'style_element']:
        match = re.search(r'<(\w+)(?:\s+[^>]*)?>', first_line)
        if match:
            tag = match.group(1)
            # Look for id or class
            id_match = re.search(r'id=["\']([^"\']+)["\']', first_line)
            class_match = re.search(r'class=["\']([^"\']+)["\']', first_line)
            
            if id_match:
                return f"{tag}#{id_match.group(1)}"
            elif class_match:
                return f"{tag}.{class_match.group(1).split()[0]}"
            else:
                return tag
    
    return f"{node.type}_{node.start_byte}"

def create_semantic_chunks(semantic_nodes: List[Dict[str, Any]]) -> List[Chunk]:
    """Create chunks from semantic nodes"""
    chunks = []
    
    for node_info in semantic_nodes:
        chunk = Chunk(
            start_byte=node_info['start_byte'],
            end_byte=node_info['end_byte'],
            content=node_info['content'],
            node_type=node_info['type'],
            name=node_info['name'],
            depth=0
        )
        chunks.append(chunk)
    
    return chunks

def group_small_chunks(chunks: List[Chunk], target_tokens: int = 600, file_extension: str = '') -> List[Chunk]:
    """Group small chunks together to reach reasonable size for any file type"""
    if not chunks:
        return chunks
    
    # Separate imports from other chunks for JS/TS files
    if file_extension in ['.tsx', '.ts', '.jsx', '.js']:
        import_chunks = [c for c in chunks if c.node_type == 'import_statement']
        other_chunks = [c for c in chunks if c.node_type != 'import_statement']
        
        # Check if everything together is under limit
        total_tokens = sum(c.token_count for c in chunks)
        if total_tokens <= MAX_CHUNK_TOKENS:
            # Combine everything into one chunk
            combined_content = '\n\n'.join(c.content for c in chunks)
            combined_chunk = Chunk(
                start_byte=chunks[0].start_byte,
                end_byte=chunks[-1].end_byte,
                content=combined_content,
                node_type='complete_module',
                name=f"complete_module_{len(chunks)}_parts",
                depth=0
            )
            return [combined_chunk]
        
        # If too large, handle imports separately
        if import_chunks:
            total_import_tokens = sum(c.token_count for c in import_chunks)
            if total_import_tokens <= MAX_CHUNK_TOKENS:
                # Combine all imports into one chunk
                combined_imports = '\n'.join(c.content for c in import_chunks)
                imports_chunk = Chunk(
                    start_byte=import_chunks[0].start_byte,
                    end_byte=import_chunks[-1].end_byte,
                    content=combined_imports,
                    node_type='imports_group',
                    name=f"imports_{len(import_chunks)}_statements",
                    depth=0
                )
                import_chunks = [imports_chunk]
        
        # Group other chunks
        grouped_others = group_chunks_by_size(other_chunks, target_tokens, file_extension)
        
        # Combine imports + other chunks
        return import_chunks + grouped_others
    else:
        # For non-JS files, use original logic
        return group_chunks_by_size(chunks, target_tokens, file_extension)

def group_chunks_by_size(chunks: List[Chunk], target_tokens: int = 600, file_extension: str = '') -> List[Chunk]:
    """Group chunks by size logic"""
    if not chunks:
        return chunks
    
    # Skip grouping if we already have reasonably sized chunks
    if len(chunks) == 1 or any(c.token_count > target_tokens for c in chunks):
        total_tokens = sum(c.token_count for c in chunks)
        if total_tokens <= MAX_CHUNK_TOKENS:
            # All chunks together are still under limit - combine them
            if len(chunks) > 1:
                combined_content = '\n\n'.join(c.content for c in chunks)
                
                # Create descriptive name based on file type
                if file_extension in ['.css', '.scss']:
                    group_name = f"css_styles_{len(chunks)}_rules"
                elif file_extension in ['.tsx', '.ts', '.jsx', '.js']:
                    group_name = f"file_module_{len(chunks)}_exports"
                elif file_extension == '.html':
                    group_name = f"html_content_{len(chunks)}_elements"
                else:
                    group_name = f"file_content_{len(chunks)}_parts"
                
                combined_chunk = Chunk(
                    start_byte=chunks[0].start_byte,
                    end_byte=chunks[-1].end_byte,
                    content=combined_content,
                    node_type='grouped_content',
                    name=group_name,
                    depth=0
                )
                return [combined_chunk]
        return chunks
    
    # Group small chunks
    grouped_chunks = []
    current_group = []
    current_tokens = 0
    
    for chunk in chunks:
        if current_tokens + chunk.token_count > target_tokens and current_group:
            # Finalize current group
            group_content = '\n\n'.join(c.content for c in current_group)
            
            if file_extension in ['.css', '.scss']:
                group_name = f"css_group_{len(grouped_chunks)+1}_{len(current_group)}_rules"
            elif file_extension in ['.tsx', '.ts', '.jsx', '.js']:
                group_name = f"code_group_{len(grouped_chunks)+1}_{len(current_group)}_parts"
            elif file_extension == '.html':
                group_name = f"html_group_{len(grouped_chunks)+1}_{len(current_group)}_elements"
            else:
                group_name = f"group_{len(grouped_chunks)+1}_{len(current_group)}_parts"
            
            grouped_chunk = Chunk(
                start_byte=current_group[0].start_byte,
                end_byte=current_group[-1].end_byte,
                content=group_content,
                node_type='grouped_content',
                name=group_name,
                depth=0
            )
            grouped_chunks.append(grouped_chunk)
            
            current_group = [chunk]
            current_tokens = chunk.token_count
        else:
            current_group.append(chunk)
            current_tokens += chunk.token_count
    
    # Add remaining chunks
    if current_group:
        if len(current_group) == 1 and current_tokens > target_tokens//2:
            grouped_chunks.append(current_group[0])
        else:
            group_content = '\n\n'.join(c.content for c in current_group)
            
            if file_extension in ['.css', '.scss']:
                group_name = f"css_group_{len(grouped_chunks)+1}_{len(current_group)}_rules"
            elif file_extension in ['.tsx', '.ts', '.jsx', '.js']:
                group_name = f"code_group_{len(grouped_chunks)+1}_{len(current_group)}_parts"
            elif file_extension == '.html':
                group_name = f"html_group_{len(grouped_chunks)+1}_{len(current_group)}_elements"
            else:
                group_name = f"group_{len(grouped_chunks)+1}_{len(current_group)}_parts"
            
            grouped_chunk = Chunk(
                start_byte=current_group[0].start_byte,
                end_byte=current_group[-1].end_byte,
                content=group_content,
                node_type='grouped_content',
                name=group_name,
                depth=0
            )
            grouped_chunks.append(grouped_chunk)
    
    return grouped_chunks

def sub_chunk_by_statements(chunk: Chunk, tree, source_code: str, depth: int = 0) -> List[Chunk]:
    """Sub-chunk by breaking down into logical statements/blocks"""
    if depth >= MAX_RECURSION_DEPTH or chunk.token_count <= MAX_CHUNK_TOKENS:
        return [chunk]
    
    print(f"    Breaking down {chunk.name} ({chunk.token_count} tokens) into smaller pieces...")
    
    # Simple line-based splitting for now
    lines = chunk.content.split('\n')
    sub_chunks = []
    current_lines = []
    current_size = 0
    
    for line in lines:
        line_tokens = count_tokens(line)
        
        if current_size + line_tokens > MAX_CHUNK_TOKENS and current_lines:
            # Create sub-chunk
            sub_content = '\n'.join(current_lines)
            if sub_content.strip():
                sub_chunk = Chunk(
                    start_byte=chunk.start_byte,  # Approximate
                    end_byte=chunk.start_byte + len(sub_content),
                    content=sub_content,
                    node_type=f"{chunk.node_type}_part",
                    name=f"{chunk.name}_part_{len(sub_chunks)+1}",
                    depth=depth + 1
                )
                sub_chunks.append(sub_chunk)
            
            current_lines = [line]
            current_size = line_tokens
        else:
            current_lines.append(line)
            current_size += line_tokens
    
    # Add remaining lines
    if current_lines:
        sub_content = '\n'.join(current_lines)
        if sub_content.strip():
            sub_chunk = Chunk(
                start_byte=chunk.start_byte,
                end_byte=chunk.end_byte,
                content=sub_content,
                node_type=f"{chunk.node_type}_part",
                name=f"{chunk.name}_part_{len(sub_chunks)+1}",
                depth=depth + 1
            )
            sub_chunks.append(sub_chunk)
    
    chunk.sub_chunks = sub_chunks
    return sub_chunks if len(sub_chunks) > 1 else [chunk]

def process_file(file_path: Path) -> List[Chunk]:
    """Process a single file and return semantic chunks"""
    print(f"\n=== Processing: {file_path.name} ===")
    
    # Read file
    with open(file_path, 'r', encoding='utf-8') as f:
        source_code = f.read()
    
    print(f"File size: {len(source_code)} characters")
    print(f"File type: {file_path.suffix}")
    
    # Get appropriate parser
    parser = PARSER_MAP.get(file_path.suffix)
    if not parser:
        print(f"❌ No parser available for {file_path.suffix}")
        return []
    
    # Parse with appropriate parser
    tree = parser.parse(source_code.encode('utf-8'))
    
    if tree.root_node.has_error:
        print("⚠️ Parse errors detected")
    
    # Find semantic chunks
    semantic_nodes = find_semantic_chunks(tree, source_code, file_path.suffix)
    print(f"Found {len(semantic_nodes)} semantic units")
    
    # Show what we found
    for node in semantic_nodes:
        preview = node['content'][:100].replace('\n', ' ').strip()
        print(f"  - {node['type']}: {node['name']} ({count_tokens(node['content'])} tokens)")
        print(f"    Preview: {preview}...")
    
    # Create chunks
    base_chunks = create_semantic_chunks(semantic_nodes)
    
    # Group small chunks for all file types
    base_chunks = group_small_chunks(base_chunks, target_tokens=600, file_extension=file_path.suffix)
    
    print(f"Created {len(base_chunks)} semantic chunks")
    
    # Apply sub-chunking for oversized chunks
    final_chunks = []
    oversized_count = 0
    
    for chunk in base_chunks:
        if chunk.token_count > MAX_CHUNK_TOKENS:
            print(f"  Sub-chunking {chunk.name} ({chunk.token_count} tokens)")
            sub_chunks = sub_chunk_by_statements(chunk, tree, source_code)
            final_chunks.extend(sub_chunks)
            oversized_count += 1
        else:
            final_chunks.append(chunk)
    
    if oversized_count > 0:
        print(f"Sub-chunked {oversized_count} oversized chunks")
    print(f"Final result: {len(final_chunks)} total chunks")
    
    return final_chunks

def generate_unique_id(length: int = 6) -> str:
    """Generate a random unique ID"""
    alphabet = string.ascii_lowercase + string.digits
    return ''.join(secrets.choice(alphabet) for _ in range(length))

def create_chunk_filename(original_filename: str, chunk_number: int, unique_id: str) -> str:
    """Create chunk filename: Accordion.tsx_chunk_001_a1s2d3.md"""
    return f"{original_filename}_chunk_{chunk_number:03d}_{unique_id}.md"

def get_markdown_language(file_extension: str) -> str:
    """Get markdown language for code blocks"""
    lang_map = {
        '.tsx': 'tsx',
        '.ts': 'typescript', 
        '.js': 'javascript',
        '.jsx': 'jsx',
        '.css': 'css',
        '.scss': 'scss',
        '.html': 'html'
    }
    return lang_map.get(file_extension, 'text')

def create_chunk_markdown(chunk: Chunk, source_file_path: str, file_extension: str) -> str:
    """Create markdown content with YAML frontmatter"""
    language = get_markdown_language(file_extension)
    
    markdown_content = f"""---
source_file: {source_file_path}
chunk_index: {getattr(chunk, 'index', 1)}
chunk_type: {chunk.node_type}
chunk_name: {chunk.name}
token_count: {chunk.token_count}
---

# {chunk.name}

```{language}
{chunk.content}
```
"""
    return markdown_content

def save_chunks_to_files(chunks: List[Chunk], 
                        original_file_path: Path, 
                        input_directory: Path,
                        output_base: Path) -> List[str]:
    """Save chunks as markdown files maintaining directory structure"""
    if not chunks:
        return []
    
    # Calculate relative path from input directory
    try:
        rel_path = original_file_path.relative_to(input_directory)
    except ValueError:
        # If file is not under input directory, use just the filename
        rel_path = original_file_path.name
    
    # Create output directory structure
    output_dir = output_base / rel_path.parent
    output_dir.mkdir(parents=True, exist_ok=True)
    
    # Generate unique ID for this file
    file_unique_id = generate_unique_id()
    
    saved_files = []
    
    # Add chunk index to each chunk and save
    for i, chunk in enumerate(chunks, 1):
        chunk.index = i  # Add index attribute
        
        # Create chunk filename
        chunk_filename = create_chunk_filename(
            original_file_path.name, 
            i, 
            file_unique_id
        )
        
        # Create markdown content
        markdown_content = create_chunk_markdown(
            chunk, 
            str(rel_path), 
            original_file_path.suffix
        )
        
        # Write to file
        chunk_file_path = output_dir / chunk_filename
        try:
            with open(chunk_file_path, 'w', encoding='utf-8') as f:
                f.write(markdown_content)
            
            saved_files.append(str(chunk_file_path))
            print(f"  ✅ Saved: {chunk_filename}")
            
        except Exception as e:
            print(f"  ❌ Error saving {chunk_filename}: {e}")
    
    return saved_files
    """Print detailed summary of chunks"""
    print(f"\n--- Semantic Chunk Summary for {file_name} ---")
    
    for i, chunk in enumerate(chunks, 1):
        indent = "  " * chunk.depth
        content_lines = len(chunk.content.split('\n'))
        
        print(f"{indent}{i}. {chunk.name}")
        print(f"{indent}   Type: {chunk.node_type}")
        print(f"{indent}   Size: {chunk.token_count} tokens, {content_lines} lines")
        print(f"{indent}   Content preview:")
        
        # Show first few lines of actual content
        content_lines_list = chunk.content.split('\n')
        for j, line in enumerate(content_lines_list[:3]):
            print(f"{indent}     {line.strip()}")
        if len(content_lines_list) > 3:
            print(f"{indent}     ... ({len(content_lines_list) - 3} more lines)")
        print()

def main():
    """Main function to test semantic chunking"""
    print("🚀 Multi-Language Semantic Chunking Test")
    print(f"Max chunk tokens: {MAX_CHUNK_TOKENS}")
    print(f"Max recursion depth: {MAX_RECURSION_DEPTH}")
    print(f"Supported extensions: {', '.join(SUPPORTED_EXTENSIONS)}")
    
    # Get directory from user or use current directory
    directory = input("\nEnter directory path (or press Enter for current directory): ").strip()
    if not directory:
        directory = "."
    
    target_dir = Path(directory)
    if not target_dir.exists():
        print(f"❌ Directory not found: {directory}")
        return
    
    # Find all supported files
    all_files = []
    for ext in SUPPORTED_EXTENSIONS:
        files = list(target_dir.rglob(f"*{ext}"))
        all_files.extend(files)
    
    if not all_files:
        print(f"❌ No supported files found in {directory}")
        print(f"Looking for: {', '.join(SUPPORTED_EXTENSIONS)}")
        return
    
    print(f"📁 Found {len(all_files)} supported files:")
    # Group by extension for summary
    by_ext = {}
    by_dir = {}
    for f in all_files:
        ext = f.suffix
        by_ext[ext] = by_ext.get(ext, 0) + 1
        
        # Track directory depth
        rel_path = f.relative_to(target_dir)
        dir_path = str(rel_path.parent) if rel_path.parent != Path('.') else 'root'
        by_dir[dir_path] = by_dir.get(dir_path, 0) + 1
    
    for ext, count in sorted(by_ext.items()):
        print(f"  {ext}: {count} files")
    
    # Show directory structure if there are subdirectories
    if len(by_dir) > 1 or 'root' not in by_dir:
        print(f"\n📂 Directory distribution:")
        for dir_path, count in sorted(by_dir.items()):
            if dir_path == 'root':
                print(f"  ./: {count} files")
            else:
                depth = dir_path.count('/') if '/' in dir_path else dir_path.count('\\')
                indent = "  " + "  " * depth
                print(f"{indent}{dir_path}/: {count} files")
    
    # Process each file
    all_chunks = []
    all_saved_files = []
    
    # Create output directory
    output_directory = target_dir.parent / f"{target_dir.name}_chunks"
    print(f"\n📁 Output directory: {output_directory}")
    
    for file_path in all_files:
        try:
            chunks = process_file(file_path)
            all_chunks.extend(chunks)
            print_chunk_summary(chunks, file_path.name)
            
            # Save chunks to files
            saved_files = save_chunks_to_files(chunks, file_path, target_dir, output_directory)
            all_saved_files.extend(saved_files)
            
        except Exception as e:
            print(f"❌ Error processing {file_path}: {e}")
    
    # Overall summary
    print(f"\n🎉 OVERALL SUMMARY")
    print(f"Files processed: {len(all_files)}")
    print(f"Total chunks created: {len(all_chunks)}")
    print(f"Total chunk files saved: {len(all_saved_files)}")
    print(f"Output directory: {output_directory}")
    
    if all_chunks:
        avg_tokens = sum(c.token_count for c in all_chunks) / len(all_chunks)
        max_tokens = max(c.token_count for c in all_chunks)
        min_tokens = min(c.token_count for c in all_chunks)
        
        print(f"Average chunk size: {avg_tokens:.0f} tokens")
        print(f"Largest chunk: {max_tokens} tokens")
        print(f"Smallest chunk: {min_tokens} tokens")
        
        # Count by node type
        type_counts = {}
        for chunk in all_chunks:
            type_counts[chunk.node_type] = type_counts.get(chunk.node_type, 0) + 1
        
        print(f"\nChunk types:")
        for node_type, count in sorted(type_counts.items()):
            print(f"  {node_type}: {count}")
            
        # Count by file type
        print(f"\nChunks by file type:")
        file_type_chunks = {}
        # We need to track file types in chunks - simplified approach
        for ext, count in sorted(by_ext.items()):
            # Estimate chunks per file type based on proportions
            proportion = count / len(all_files)
            estimated_chunks = int(len(all_chunks) * proportion)
            file_type_chunks[ext] = estimated_chunks
            print(f"  {ext}: ~{estimated_chunks} chunks")

if __name__ == "__main__":
    main()
# Out:
# ✅ Using TSX, CSS, and HTML parsers
# 🚀 Multi-Language Semantic Chunking Test
# Max chunk tokens: 1000
# Max recursion depth: 3
# Supported extensions: .tsx, .ts, .js, .jsx, .css, .scss, .html
# 📁 Found 358 supported files:
#   .css: 93 files
#   .ts: 129 files
#   .tsx: 136 files
#
# 📂 Directory distribution:
#   src/: 3 files
#     src/accordion/: 10 files
#     src/aria-announcer/: 5 files
#     src/avatar/: 4 files
#     src/badge/: 3 files
#     src/banner/: 7 files
#     src/border-item/: 3 files
#     src/border-layout/: 2 files
#     src/breakpoints/: 3 files
#     src/button/: 4 files
#     src/card/: 3 files
#     src/checkbox/: 7 files
#       src/checkbox/internal/: 2 files
#     src/combo-box/: 4 files
#     src/dialog/: 12 files
#     src/divider/: 3 files
#     src/drawer/: 5 files
#     src/dropdown/: 3 files
#     src/file-drop-zone/: 5 files
#       src/file-drop-zone/internal/: 1 files
#     src/flex-item/: 3 files
#     src/flex-layout/: 4 files
#     src/flow-layout/: 2 files
#     src/form-field/: 7 files
#     src/form-field-context/: 3 files
#     src/grid-item/: 3 files
#     src/grid-layout/: 3 files
#     src/input/: 3 files
#     src/interactable-card/: 7 files
#     src/link/: 4 files
#     src/link-card/: 3 files
#     src/list-box/: 3 files
#     src/list-control/: 3 files
#     src/menu/: 14 files
#     src/multiline-input/: 3 files
#     src/navigation-item/: 5 files
#     src/option/: 8 files
#     src/overlay/: 12 files
#     src/pagination/: 18 files
#     src/panel/: 3 files
#     src/parent-child-layout/: 4 files
#     src/pill/: 3 files
#     src/pill-input/: 4 files
#     src/progress/: 1 files
#       src/progress/CircularProgress/: 2 files
#       src/progress/LinearProgress/: 2 files
#     src/radio-button/: 7 files
#       src/radio-button/internal/: 2 files
#     src/salt-provider/: 3 files
#     src/scrim/: 3 files
#     src/segmented-button-group/: 3 files
#     src/semantic-icon-provider/: 2 files
#     src/skip-link/: 3 files
#       src/skip-link/internal/: 1 files
#     src/slider/: 3 files
#       src/slider/internal/: 9 files
#     src/spinner/: 3 files
#       src/spinner/svgSpinners/: 1 files
#     src/split-layout/: 3 files
#     src/stack-layout/: 3 files
#     src/status-adornment/: 6 files
#     src/status-indicator/: 4 files
#     src/stepper/: 5 files
#       src/stepper/internal/: 10 files
#     src/switch/: 3 files
#     src/tag/: 3 files
#     src/text/: 9 files
#     src/theme/: 8 files
#     src/toast/: 5 files
#     src/toggle-button/: 3 files
#     src/toggle-button-group/: 4 files
#     src/tooltip/: 6 files
#     src/utils/: 26 files
#       src/utils/useFloatingUI/: 2 files
#     src/viewport/: 2 files
#
# 📁 Output directory: /Users/tiyadiashok/python-projects/code_chunker/rag_chunks/pre_processed/code_sources/typescript/saltds_latest_chunks
#
# === Processing: Dropdown.tsx ===
# File size: 13602 characters
# File type: .tsx
# Found 17 semantic units
#   - import_statement: import_import (35 tokens)
#     Preview: import {   flip,   offset,   size,   useClick,   useDismiss,   useFocus,   useInteractions, } from "...
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (52 tokens)
#     Preview: import {   Children,   type ComponentPropsWithoutRef,   type FocusEvent,   type ForwardedRef,   forw...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useFormFieldProps } from "../form-field-context";...
#   - import_statement: import_import (21 tokens)
#     Preview: import {   ListControlContext,   type OptionValue, } from "../list-control/ListControlContext";...
#   - import_statement: import_import (26 tokens)
#     Preview: import {   defaultValueToString,   type ListControlProps,   useListControl, } from "../list-control/...
#   - import_statement: import_import (12 tokens)
#     Preview: import { OptionList } from "../option/OptionList";...
#   - import_statement: import_import (11 tokens)
#     Preview: import { useIcon } from "../semantic-icon-provider";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { StatusAdornment } from "../status-adornment";...
#   - import_statement: import_import (12 tokens)
#     Preview: import type { ValidationStatus } from "../status-indicator";...
#   - import_statement: import_import (34 tokens)
#     Preview: import {   makePrefixer,   type UseFloatingUIProps,   useFloatingUI,   useForkRef,   useId, } from "...
#   - import_statement: import_import (8 tokens)
#     Preview: import dropdownCss from "./Dropdown.css";...
#   - export_statement: export_statement (335 tokens)
#     Preview: export type DropdownProps<Item = string> = {   /**    * If `true`, the dropdown will be disabled....
#   - function_declaration: nction (68 tokens)
#     Preview: nction ExpandIcon({ open }: { open: boolean }) {   const { CollapseIcon, ExpandIcon } = useIcon();...
#   - export_statement: export_statement (2484 tokens)
#     Preview: port const Dropdown = forwardRef(function Dropdown<Item>(   props: DropdownProps<Item>,   ref: Forwa...
# Created 4 semantic chunks
#   Sub-chunking export_statement (2484 tokens)
#     Breaking down export_statement (2484 tokens) into smaller pieces...
# Sub-chunked 1 oversized chunks
# Final result: 6 total chunks
#
# --- Semantic Chunk Summary for Dropdown.tsx ---
# 1. imports_14_statements
#    Type: imports_group
#    Size: 271 tokens, 46 lines
#    Content preview:
#      import {
#      flip,
#      offset,
#      ... (43 more lines)
#
# 2. export_statement
#    Type: export_statement
#    Size: 335 tokens, 53 lines
#    Content preview:
#      export type DropdownProps<Item = string> = {
#      /**
#      * If `true`, the dropdown will be disabled.
#      ... (50 more lines)
#
# 3. nction
#    Type: function_declaration
#    Size: 68 tokens, 10 lines
#    Content preview:
#      nction ExpandIcon({ open }: { open: boolean }) {
#      const { CollapseIcon, ExpandIcon } = useIcon();
#      return open ? (
#      ... (7 more lines)
#
#   4. export_statement_part_1
#      Type: export_statement_part
#      Size: 1002 tokens, 162 lines
#      Content preview:
#        port const Dropdown = forwardRef(function Dropdown<Item>(
#        props: DropdownProps<Item>,
#        ref: ForwardedRef<HTMLButtonElement>,
#        ... (159 more lines)
#
#   5. export_statement_part_2
#      Type: export_statement_part
#      Size: 1008 tokens, 164 lines
#      Content preview:
#        setFocusVisibleState(true);
#        }
#        };
#        ... (161 more lines)
#
#   6. export_statement_part_3
#      Type: export_statement_part
#      Size: 474 tokens, 70 lines
#      Content preview:
#        },
#        className,
#        )}
#        ... (67 more lines)
#
#   ✅ Saved: Dropdown.tsx_chunk_001_h2nnc9.md
#   ✅ Saved: Dropdown.tsx_chunk_002_h2nnc9.md
#   ✅ Saved: Dropdown.tsx_chunk_003_h2nnc9.md
#   ✅ Saved: Dropdown.tsx_chunk_004_h2nnc9.md
#   ✅ Saved: Dropdown.tsx_chunk_005_h2nnc9.md
#   ✅ Saved: Dropdown.tsx_chunk_006_h2nnc9.md
#
# === Processing: RadioButtonGroup.tsx ===
# File size: 3767 characters
# File type: .tsx
# Found 10 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (23 tokens)
#     Preview: import {   type ChangeEventHandler,   type ComponentPropsWithoutRef,   forwardRef, } from "react";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useFormFieldProps } from "../form-field-context";...
#   - import_statement: import_import (17 tokens)
#     Preview: import { makePrefixer, useControlled, useId } from "../utils";...
#   - import_statement: import_import (14 tokens)
#     Preview: import { RadioGroupContext } from "./internal/RadioGroupContext";...
#   - import_statement: import_import (10 tokens)
#     Preview: import radioButtonGroupCss from "./RadioButtonGroup.css";...
#   - export_statement: interface_RadioButtonGroupProps (240 tokens)
#     Preview: export interface RadioButtonGroupProps   extends Omit<ComponentPropsWithoutRef<"fieldset">, "onChang...
#   - export_statement: const_RadioButtonGroup (490 tokens)
#     Preview: export const RadioButtonGroup = forwardRef<   HTMLFieldSetElement,   RadioButtonGroupProps >(functio...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for RadioButtonGroup.tsx ---
# 1. complete_module_10_parts
#    Type: complete_module
#    Size: 842 tokens, 150 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (147 more lines)
#
#   ✅ Saved: RadioButtonGroup.tsx_chunk_001_kc4cj6.md
#
# === Processing: RadioButton.tsx ===
# File size: 5899 characters
# File type: .tsx
# Found 13 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (43 tokens)
#     Preview: import {   type ChangeEventHandler,   type ComponentPropsWithoutRef,   type FocusEventHandler,   for...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useFormFieldProps } from "../form-field-context";...
#   - import_statement: import_import (14 tokens)
#     Preview: import type { AdornmentValidationStatus } from "../status-adornment";...
#   - import_statement: import_import (10 tokens)
#     Preview: import type { DataAttributes } from "../types";...
#   - import_statement: import_import (14 tokens)
#     Preview: import { makePrefixer, useControlled } from "../utils";...
#   - import_statement: import_import (13 tokens)
#     Preview: import { useRadioGroup } from "./internal/useRadioGroup";...
#   - import_statement: import_import (8 tokens)
#     Preview: import radioButtonCss from "./RadioButton.css";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { RadioButtonIcon } from "./RadioButtonIcon";...
#   - export_statement: interface_RadioButtonProps (371 tokens)
#     Preview: export interface RadioButtonProps   extends Omit<     ComponentPropsWithoutRef<"label">,     "onChan...
#   - export_statement: const_RadioButton (746 tokens)
#     Preview: export const RadioButton = forwardRef<HTMLLabelElement, RadioButtonProps>(   function RadioButton(pr...
# Created 3 semantic chunks
# Final result: 3 total chunks
#
# --- Semantic Chunk Summary for RadioButton.tsx ---
# 1. imports_11_statements
#    Type: imports_group
#    Size: 160 tokens, 19 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#      import { useWindow } from "@salt-ds/window";
#      import { clsx } from "clsx";
#      ... (16 more lines)
#
# 2. interface_RadioButtonProps
#    Type: export_statement
#    Size: 371 tokens, 63 lines
#    Content preview:
#      export interface RadioButtonProps
#      extends Omit<
#      ComponentPropsWithoutRef<"label">,
#      ... (60 more lines)
#
# 3. const_RadioButton
#    Type: export_statement
#    Size: 746 tokens, 132 lines
#    Content preview:
#      export const RadioButton = forwardRef<HTMLLabelElement, RadioButtonProps>(
#      function RadioButton(props, ref) {
#      const {
#      ... (129 more lines)
#
#   ✅ Saved: RadioButton.tsx_chunk_001_40v59t.md
#   ✅ Saved: RadioButton.tsx_chunk_002_40v59t.md
#   ✅ Saved: RadioButton.tsx_chunk_003_40v59t.md
#
# === Processing: RadioButtonIcon.tsx ===
# File size: 2079 characters
# File type: .tsx
# Found 9 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (12 tokens)
#     Preview: import type { ComponentPropsWithoutRef } from "react";...
#   - import_statement: import_import (14 tokens)
#     Preview: import type { AdornmentValidationStatus } from "../status-adornment";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import radioButtonIconCss from "./RadioButtonIcon.css";...
#   - export_statement: interface_RadioButtonIconProps (57 tokens)
#     Preview: export interface RadioButtonIconProps extends ComponentPropsWithoutRef<"div"> {   checked?: boolean;...
#   - export_statement: const_RadioButtonIcon (415 tokens)
#     Preview: export const RadioButtonIcon = ({   checked,   className,   error,   disabled,   validationStatus,...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for RadioButtonIcon.tsx ---
# 1. complete_module_9_parts
#    Type: complete_module
#    Size: 554 tokens, 81 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (78 more lines)
#
#   ✅ Saved: RadioButtonIcon.tsx_chunk_001_lnnuq1.md
#
# === Processing: DrawerCloseButton.tsx ===
# File size: 1132 characters
# File type: .tsx
# Found 9 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (9 tokens)
#     Preview: import { forwardRef } from "react";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { Button, type ButtonProps } from "../button";...
#   - import_statement: import_import (11 tokens)
#     Preview: import { useIcon } from "../semantic-icon-provider";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (12 tokens)
#     Preview: import drawerCloseButtonCss from "./DrawerCloseButton.css";...
#   - export_statement: const_DrawerCloseButton (153 tokens)
#     Preview: export const DrawerCloseButton = forwardRef<HTMLButtonElement, ButtonProps>(   function DrawerCloseB...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for DrawerCloseButton.tsx ---
# 1. complete_module_9_parts
#    Type: complete_module
#    Size: 243 tokens, 41 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (38 more lines)
#
#   ✅ Saved: DrawerCloseButton.tsx_chunk_001_eklurp.md
#
# === Processing: Drawer.tsx ===
# File size: 3603 characters
# File type: .tsx
# Found 11 semantic units
#   - import_statement: import_import (18 tokens)
#     Preview: import { useClick, useDismiss, useInteractions } from "@floating-ui/react";...
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (30 tokens)
#     Preview: import {   type ComponentPropsWithoutRef,   forwardRef,   type PropsWithChildren,   useEffect,   use...
#   - import_statement: import_import (10 tokens)
#     Preview: import { Scrim } from "../scrim";...
#   - import_statement: import_import (28 tokens)
#     Preview: import {   makePrefixer,   useFloatingComponent,   useFloatingUI,   useForkRef, } from "../utils";...
#   - import_statement: import_import (8 tokens)
#     Preview: import drawerCss from "./Drawer.css";...
#   - interface_declaration: ConditionalScrimWrapperProps (17 tokens)
#     Preview: interface ConditionalScrimWrapperProps extends PropsWithChildren {   condition: boolean; }...
#   - export_statement: interface_DrawerProps (158 tokens)
#     Preview: export interface DrawerProps extends ComponentPropsWithoutRef<"div"> {   /**    * Defines the drawer...
#   - export_statement: const_Drawer (456 tokens)
#     Preview: export const Drawer = forwardRef<HTMLDivElement, DrawerProps>(   function Drawer(props, ref) {     c...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for Drawer.tsx ---
# 1. complete_module_11_parts
#    Type: complete_module
#    Size: 761 tokens, 138 lines
#    Content preview:
#      import { useClick, useDismiss, useInteractions } from "@floating-ui/react";
#
#      import { useComponentCssInjection } from "@salt-ds/styles";
#      ... (135 more lines)
#
#   ✅ Saved: Drawer.tsx_chunk_001_rnmyar.md
#
# === Processing: Paginator.tsx ===
# File size: 2415 characters
# File type: .tsx
# Found 12 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (17 tokens)
#     Preview: import { forwardRef, type HTMLAttributes, type MouseEventHandler } from "react";...
#   - import_statement: import_import (8 tokens)
#     Preview: import { Button } from "../button";...
#   - import_statement: import_import (11 tokens)
#     Preview: import { useIcon } from "../semantic-icon-provider";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { PageRanges } from "./PageRanges";...
#   - import_statement: import_import (8 tokens)
#     Preview: import paginatorCss from "./Paginator.css";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { usePaginationContext } from "./usePaginationContext";...
#   - export_statement: interface_PaginatorProps (66 tokens)
#     Preview: export interface PaginatorProps extends HTMLAttributes<HTMLDivElement> {   /**    * Number of pages...
#   - export_statement: const_Paginator (354 tokens)
#     Preview: export const Paginator = forwardRef<HTMLDivElement, PaginatorProps>(   function Paginator(     { cla...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for Paginator.tsx ---
# 1. complete_module_12_parts
#    Type: complete_module
#    Size: 532 tokens, 82 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (79 more lines)
#
#   ✅ Saved: Paginator.tsx_chunk_001_4gn61b.md
#
# === Processing: Pagination.tsx ===
# File size: 2528 characters
# File type: .tsx
# Found 10 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (33 tokens)
#     Preview: import {   forwardRef,   type HTMLAttributes,   type SyntheticEvent,   useCallback,   useEffect,   u...
#   - import_statement: import_import (15 tokens)
#     Preview: import { useAriaAnnouncer } from "../aria-announcer";...
#   - import_statement: import_import (14 tokens)
#     Preview: import { makePrefixer, useControlled } from "../utils";...
#   - import_statement: import_import (8 tokens)
#     Preview: import paginationCss from "./Pagination.css";...
#   - import_statement: import_import (14 tokens)
#     Preview: import { type PaginationContext, paginationContext } from "./PaginationContext";...
#   - export_statement: interface_PaginationProps (92 tokens)
#     Preview: export interface PaginationProps extends HTMLAttributes<HTMLElement> {   /**    * Number of pages....
#   - export_statement: const_Pagination (355 tokens)
#     Preview: export const Pagination = forwardRef<HTMLElement, PaginationProps>(   function Pagination(     {...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for Pagination.tsx ---
# 1. complete_module_10_parts
#    Type: complete_module
#    Size: 567 tokens, 115 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (112 more lines)
#
#   ✅ Saved: Pagination.tsx_chunk_001_ytaraf.md
#
# === Processing: PageButton.tsx ===
# File size: 1410 characters
# File type: .tsx
# Found 9 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (13 tokens)
#     Preview: import { forwardRef, type MouseEventHandler } from "react";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import pageButtonCss from "./PageButton.css";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { usePaginationContext } from "./usePaginationContext";...
#   - export_statement: interface_PageButtonProps (22 tokens)
#     Preview: export interface PageButtonProps {   page: number;   selected?: boolean;   disabled?: boolean; }...
#   - export_statement: const_PageButton (212 tokens)
#     Preview: export const PageButton = forwardRef<HTMLButtonElement, PageButtonProps>(   function PageButton({ pa...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for PageButton.tsx ---
# 1. complete_module_9_parts
#    Type: complete_module
#    Size: 315 tokens, 53 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (50 more lines)
#
#   ✅ Saved: PageButton.tsx_chunk_001_ztfw62.md
#
# === Processing: CompactInput.tsx ===
# File size: 1975 characters
# File type: .tsx
# Found 9 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (27 tokens)
#     Preview: import {   type ChangeEventHandler,   forwardRef,   type KeyboardEventHandler,   useEffect,   useSta...
#   - import_statement: import_import (12 tokens)
#     Preview: import { Input, type InputProps } from "../input";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import compactInputCss from "./CompactInput.css";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { usePaginationContext } from "./usePaginationContext";...
#   - export_statement: const_CompactInput (350 tokens)
#     Preview: export const CompactInput = forwardRef<   HTMLInputElement,   Pick<InputProps, "inputRef" | "variant...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for CompactInput.tsx ---
# 1. complete_module_9_parts
#    Type: complete_module
#    Size: 457 tokens, 79 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (76 more lines)
#
#   ✅ Saved: CompactInput.tsx_chunk_001_gpug1v.md
#
# === Processing: CompactPaginator.tsx ===
# File size: 2208 characters
# File type: .tsx
# Found 12 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (23 tokens)
#     Preview: import {   type ComponentPropsWithoutRef,   forwardRef,   type MouseEventHandler, } from "react";...
#   - import_statement: import_import (8 tokens)
#     Preview: import { Button } from "../button";...
#   - import_statement: import_import (11 tokens)
#     Preview: import { useIcon } from "../semantic-icon-provider";...
#   - import_statement: import_import (8 tokens)
#     Preview: import { Text } from "../text";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import compactPaginatorCss from "./CompactPaginator.css";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { PageButton } from "./PageButton";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { usePaginationContext } from "./usePaginationContext";...
#   - export_statement: const_CompactPaginator (383 tokens)
#     Preview: export const CompactPaginator = forwardRef<   HTMLDivElement,   ComponentPropsWithoutRef<"div"> >(fu...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for CompactPaginator.tsx ---
# 1. complete_module_12_parts
#    Type: complete_module
#    Size: 511 tokens, 80 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (77 more lines)
#
#   ✅ Saved: CompactPaginator.tsx_chunk_001_buvnh1.md
#
# === Processing: PageRanges.tsx ===
# File size: 1793 characters
# File type: .tsx
# Found 10 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { type ReactElement, useCallback } from "react";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { PageButton } from "./PageButton";...
#   - import_statement: import_import (10 tokens)
#     Preview: import pageRangesCss from "./PageRanges.css";...
#   - import_statement: import_import (14 tokens)
#     Preview: import { type PageRange, usePagination } from "./usePagination";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { usePaginationContext } from "./usePaginationContext";...
#   - export_statement: interface_PageRangesProps (19 tokens)
#     Preview: export interface PageRangesProps {   boundaryCount?: number;   siblingCount?: number; }...
#   - export_statement: function_PageRanges (234 tokens)
#     Preview: export function PageRanges({   siblingCount = 2,   boundaryCount = 1, }: PageRangesProps) {   const...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for PageRanges.tsx ---
# 1. complete_module_10_parts
#    Type: complete_module
#    Size: 347 tokens, 67 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (64 more lines)
#
#   ✅ Saved: PageRanges.tsx_chunk_001_j2tbnt.md
#
# === Processing: GoToInput.tsx ===
# File size: 2689 characters
# File type: .tsx
# Found 11 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (33 tokens)
#     Preview: import {   type ChangeEventHandler,   forwardRef,   type HTMLAttributes,   type KeyboardEventHandler...
#   - import_statement: import_import (14 tokens)
#     Preview: import { FormField, FormFieldLabel } from "../form-field";...
#   - import_statement: import_import (8 tokens)
#     Preview: import { Input } from "../input";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (11 tokens)
#     Preview: import goToInputCss from "./GoToInput.css";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { usePaginationContext } from "./usePaginationContext";...
#   - export_statement: interface_GoToInputProps (70 tokens)
#     Preview: export interface GoToInputProps extends HTMLAttributes<HTMLSpanElement> {   /**    * Input label....
#   - export_statement: const_GoToInput (406 tokens)
#     Preview: export const GoToInput = forwardRef<HTMLDivElement, GoToInputProps>(   function GoToInput(     {...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for GoToInput.tsx ---
# 1. complete_module_11_parts
#    Type: complete_module
#    Size: 600 tokens, 113 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (110 more lines)
#
#   ✅ Saved: GoToInput.tsx_chunk_001_0h9y65.md
#
# === Processing: SegmentedButtonGroup.tsx ===
# File size: 927 characters
# File type: .tsx
# Found 8 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (15 tokens)
#     Preview: import { type ComponentPropsWithoutRef, forwardRef } from "react";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (13 tokens)
#     Preview: import segmentedButtonGroupCss from "./SegmentedButtonGroup.css";...
#   - export_statement: interface_SegmentedButtonGroupProps (18 tokens)
#     Preview: export interface SegmentedButtonGroupProps   extends ComponentPropsWithoutRef<"div"> {}...
#   - export_statement: const_SegmentedButtonGroup (114 tokens)
#     Preview: export const SegmentedButtonGroup = forwardRef<   HTMLDivElement,   SegmentedButtonGroupProps >(func...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for SegmentedButtonGroup.tsx ---
# 1. complete_module_8_parts
#    Type: complete_module
#    Size: 206 tokens, 32 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (29 more lines)
#
#   ✅ Saved: SegmentedButtonGroup.tsx_chunk_001_vcmsn8.md
#
# === Processing: SkipLink.tsx ===
# File size: 1843 characters
# File type: .tsx
# Found 9 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (27 tokens)
#     Preview: import {   type ComponentPropsWithoutRef,   forwardRef,   useEffect,   useRef,   useState, } from "r...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (17 tokens)
#     Preview: import { useManageFocusOnTarget } from "./internal/useManageFocusOnTarget";...
#   - import_statement: import_import (10 tokens)
#     Preview: import skipLinkCss from "./SkipLink.css";...
#   - interface_declaration: SkipLinkProps (61 tokens)
#     Preview: interface SkipLinkProps extends ComponentPropsWithoutRef<"a"> {   /**    * The ID of the target elem...
#   - export_statement: const_SkipLink (263 tokens)
#     Preview: export const SkipLink = forwardRef<HTMLAnchorElement, SkipLinkProps>(   function SkipLink(     { cla...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for SkipLink.tsx ---
# 1. complete_module_9_parts
#    Type: complete_module
#    Size: 424 tokens, 73 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (70 more lines)
#
#   ✅ Saved: SkipLink.tsx_chunk_001_uvwtyn.md
#
# === Processing: Tooltip.tsx ===
# File size: 4075 characters
# File type: .tsx
# Found 9 semantic units
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (33 tokens)
#     Preview: import {   cloneElement,   forwardRef,   type HTMLAttributes,   isValidElement,   type ReactNode,...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useFormFieldProps } from "../form-field-context";...
#   - import_statement: import_import (21 tokens)
#     Preview: import {   VALIDATION_NAMED_STATUS,   type ValidationStatus, } from "../status-indicator";...
#   - import_statement: import_import (40 tokens)
#     Preview: import {   getRefFromChildren,   makePrefixer,   mergeProps,   type UseFloatingUIProps,   useFloatin...
#   - import_statement: import_import (10 tokens)
#     Preview: import { TooltipBase } from "./TooltipBase";...
#   - import_statement: import_import (15 tokens)
#     Preview: import { type UseTooltipProps, useTooltip } from "./useTooltip";...
#   - export_statement: interface_TooltipProps (298 tokens)
#     Preview: export interface TooltipProps   extends Pick<UseFloatingUIProps, "open" | "onOpenChange" | "placemen...
#   - export_statement: const_Tooltip (466 tokens)
#     Preview: export const Tooltip = forwardRef<HTMLDivElement, TooltipProps>(   function Tooltip(props, ref) {...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for Tooltip.tsx ---
# 1. complete_module_9_parts
#    Type: complete_module
#    Size: 905 tokens, 163 lines
#    Content preview:
#      import { clsx } from "clsx";
#
#      import {
#      ... (160 more lines)
#
#   ✅ Saved: Tooltip.tsx_chunk_001_2pr2cd.md
#
# === Processing: TooltipBase.tsx ===
# File size: 1772 characters
# File type: .tsx
# Found 10 semantic units
#   - import_statement: import_import (16 tokens)
#     Preview: import { FloatingArrow, type FloatingArrowProps } from "@floating-ui/react";...
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useFormFieldProps } from "../form-field-context";...
#   - import_statement: import_import (15 tokens)
#     Preview: import { StatusIndicator, type ValidationStatus } from "../status-indicator";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import type { TooltipProps } from "./Tooltip";...
#   - import_statement: import_import (8 tokens)
#     Preview: import tooltipCss from "./Tooltip.css";...
#   - interface_declaration: TooltipBaseProps (46 tokens)
#     Preview: interface TooltipBaseProps extends Omit<TooltipProps, "children"> {   arrowProps: FloatingArrowProps...
#   - export_statement: const_TooltipBase (243 tokens)
#     Preview: export const TooltipBase = (props: TooltipBaseProps) => {   const targetWindow = useWindow();   useC...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for TooltipBase.tsx ---
# 1. complete_module_10_parts
#    Type: complete_module
#    Size: 386 tokens, 67 lines
#    Content preview:
#      import { FloatingArrow, type FloatingArrowProps } from "@floating-ui/react";
#
#      import { useComponentCssInjection } from "@salt-ds/styles";
#      ... (64 more lines)
#
#   ✅ Saved: TooltipBase.tsx_chunk_001_zaxnyx.md
#
# === Processing: ParentChildLayout.tsx ===
# File size: 2753 characters
# File type: .tsx
# Found 10 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (26 tokens)
#     Preview: import {   type ComponentPropsWithoutRef,   forwardRef,   type ReactNode,   useEffect, } from "react...
#   - import_statement: import_import (11 tokens)
#     Preview: import type { Breakpoints } from "../breakpoints";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (12 tokens)
#     Preview: import parentChildLayoutCss from "./ParentChildLayout.css";...
#   - import_statement: import_import (22 tokens)
#     Preview: import { useIsViewportLargerThanBreakpoint } from "./useIsViewportLargerThanBreakpoint";...
#   - export_statement: interface_ParentChildLayoutProps (171 tokens)
#     Preview: export interface ParentChildLayoutProps   extends ComponentPropsWithoutRef<"div"> {   /**    * Break...
#   - export_statement: const_ParentChildLayout (371 tokens)
#     Preview: export const ParentChildLayout = forwardRef<   HTMLDivElement,   ParentChildLayoutProps >(function P...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for ParentChildLayout.tsx ---
# 1. complete_module_10_parts
#    Type: complete_module
#    Size: 659 tokens, 111 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (108 more lines)
#
#   ✅ Saved: ParentChildLayout.tsx_chunk_001_0ttuhb.md
#
# === Processing: ViewportProvider.tsx ===
# File size: 1517 characters
# File type: .tsx
# Found 4 semantic units
#   - import_statement: import_import (16 tokens)
#     Preview: import { createContext, type ReactNode, useContext, useState } from "react";...
#   - import_statement: import_import (17 tokens)
#     Preview: import { useIsomorphicLayoutEffect } from "../utils/useIsomorphicLayoutEffect";...
#   - type_alias_declaration: ViewportProviderProps (14 tokens)
#     Preview: type ViewportProviderProps = {   children?: ReactNode; };...
#   - export_statement: export_statement (13 tokens)
#     Preview: export { ViewportProvider, ViewportContext, useViewport };...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for ViewportProvider.tsx ---
# 1. complete_module_4_parts
#    Type: complete_module
#    Size: 60 tokens, 9 lines
#    Content preview:
#      import { createContext, type ReactNode, useContext, useState } from "react";
#
#      import { useIsomorphicLayoutEffect } from "../utils/useIsomorphicLayoutEffect";
#      ... (6 more lines)
#
#   ✅ Saved: ViewportProvider.tsx_chunk_001_988hvb.md
#
# === Processing: ExpansionIcon.tsx ===
# File size: 801 characters
# File type: .tsx
# Found 3 semantic units
#   - import_statement: import_import (11 tokens)
#     Preview: import { useIcon } from "../semantic-icon-provider";...
#   - interface_declaration: ExpansionIconProps (47 tokens)
#     Preview: interface ExpansionIconProps {   /**    * Whether the navigation item is expanded.    */   expanded?...
#   - export_statement: const_ExpansionIcon (122 tokens)
#     Preview: export const ExpansionIcon = ({   expanded = false,   orientation = "horizontal", }: ExpansionIconPr...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for ExpansionIcon.tsx ---
# 1. complete_module_3_parts
#    Type: complete_module
#    Size: 180 tokens, 33 lines
#    Content preview:
#      import { useIcon } from "../semantic-icon-provider";
#
#      interface ExpansionIconProps {
#      ... (30 more lines)
#
#   ✅ Saved: ExpansionIcon.tsx_chunk_001_zbgurz.md
#
# === Processing: NavigationItem.tsx ===
# File size: 3287 characters
# File type: .tsx
# Found 11 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (27 tokens)
#     Preview: import {   type ComponentPropsWithoutRef,   forwardRef,   type MouseEvent,   type MouseEventHandler,...
#   - import_statement: import_import (11 tokens)
#     Preview: import type { RenderPropsType } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { ExpansionIcon } from "./ExpansionIcon";...
#   - import_statement: import_import (10 tokens)
#     Preview: import navigationItemCss from "./NavigationItem.css";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { NavigationItemAction } from "./NavigationItemAction";...
#   - export_statement: interface_NavigationItemProps (213 tokens)
#     Preview: export interface NavigationItemProps extends ComponentPropsWithoutRef<"div"> {   /**    * Whether th...
#   - export_statement: const_NavigationItem (396 tokens)
#     Preview: export const NavigationItem = forwardRef<HTMLDivElement, NavigationItemProps>(   function Navigation...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for NavigationItem.tsx ---
# 1. complete_module_11_parts
#    Type: complete_module
#    Size: 725 tokens, 130 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (127 more lines)
#
#   ✅ Saved: NavigationItem.tsx_chunk_001_rtetuv.md
#
# === Processing: NavigationItemAction.tsx ===
# File size: 283 characters
# File type: .tsx
# Found 4 semantic units
#   - import_statement: import_import (12 tokens)
#     Preview: import type { ComponentPropsWithoutRef } from "react";...
#   - import_statement: import_import (9 tokens)
#     Preview: import { renderProps } from "../utils";...
#   - interface_declaration: NavigationItemActionProps (13 tokens)
#     Preview: interface NavigationItemActionProps extends ComponentPropsWithoutRef<any> {}...
#   - export_statement: function_NavigationItemAction (23 tokens)
#     Preview: export function NavigationItemAction(props: NavigationItemActionProps) {   return renderProps("a", p...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for NavigationItemAction.tsx ---
# 1. complete_module_4_parts
#    Type: complete_module
#    Size: 57 tokens, 9 lines
#    Content preview:
#      import type { ComponentPropsWithoutRef } from "react";
#
#      import { renderProps } from "../utils";
#      ... (6 more lines)
#
#   ✅ Saved: NavigationItemAction.tsx_chunk_001_m7uiv6.md
#
# === Processing: Card.tsx ===
# File size: 2154 characters
# File type: .tsx
# Found 8 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (15 tokens)
#     Preview: import { type ComponentPropsWithoutRef, forwardRef } from "react";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { capitalize, makePrefixer } from "../utils";...
#   - import_statement: import_import (8 tokens)
#     Preview: import cardCss from "./Card.css";...
#   - export_statement: interface_CardProps (197 tokens)
#     Preview: export interface CardProps extends ComponentPropsWithoutRef<"div"> {   /**    * If provided an accen...
#   - export_statement: const_Card (234 tokens)
#     Preview: export const Card = forwardRef<HTMLDivElement, CardProps>(   function Card(props, ref) {     const {...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for Card.tsx ---
# 1. complete_module_8_parts
#    Type: complete_module
#    Size: 502 tokens, 83 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (80 more lines)
#
#   ✅ Saved: Card.tsx_chunk_001_z5u4fx.md
#
# === Processing: FlexLayout.tsx ===
# File size: 4944 characters
# File type: .tsx
# Found 17 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (26 tokens)
#     Preview: import {   type ElementType,   type ForwardedRef,   type FunctionComponent,   forwardRef, } from "re...
#   - import_statement: import_import (11 tokens)
#     Preview: import { useBreakpoint } from "../breakpoints";...
#   - import_statement: import_import (39 tokens)
#     Preview: import {   makePrefixer,   type PolymorphicComponentPropWithRef,   type PolymorphicRef,   type Respo...
#   - import_statement: import_import (10 tokens)
#     Preview: import flexLayoutCss from "./FlexLayout.css";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { parseSpacing } from "./parseSpacing";...
#   - export_statement: export_statement (16 tokens)
#     Preview: export type LayoutSeparator = "start" | "center" | "end";...
#   - export_statement: const_FLEX_ALIGNMENT_BASE (19 tokens)
#     Preview: export const FLEX_ALIGNMENT_BASE = ["start", "end", "center"] as const;...
#   - export_statement: const_FLEX_CONTENT_ALIGNMENT_BASE (36 tokens)
#     Preview: export const FLEX_CONTENT_ALIGNMENT_BASE = [   ...FLEX_ALIGNMENT_BASE,   "space-between",   "space-a...
#   - export_statement: export_statement (14 tokens)
#     Preview: export type FlexAlignment = (typeof FLEX_ALIGNMENT_BASE)[number];...
#   - export_statement: export_statement (15 tokens)
#     Preview: export type FlexContentAlignment = (typeof FLEX_CONTENT_ALIGNMENT_BASE)[number];...
#   - export_statement: export_statement (326 tokens)
#     Preview: export type FlexLayoutProps<T extends ElementType> =   PolymorphicComponentPropWithRef<     T,     {...
#   - type_alias_declaration: FlexLayoutComponent (29 tokens)
#     Preview: type FlexLayoutComponent = <T extends ElementType = "div">(   props: FlexLayoutProps<T>, ) => Return...
#   - function_declaration: parseAlignment (33 tokens)
#     Preview: function parseAlignment(style: string | undefined) {   return style === "start" || style === "end" ?...
#   - export_statement: const_FlexLayout (479 tokens)
#     Preview: export const FlexLayout: FlexLayoutComponent = forwardRef(function FlexLayout<   T extends ElementTy...
# Created 3 semantic chunks
# Final result: 3 total chunks
#
# --- Semantic Chunk Summary for FlexLayout.tsx ---
# 1. imports_8_statements
#    Type: imports_group
#    Size: 132 tokens, 19 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#      import { useWindow } from "@salt-ds/window";
#      import { clsx } from "clsx";
#      ... (16 more lines)
#
# 2. code_group_1_8_parts
#    Type: grouped_content
#    Size: 488 tokens, 63 lines
#    Content preview:
#      export type LayoutSeparator = "start" | "center" | "end";
#
# ...
#   - rule_set: rule_.saltStep-status-error_>_.salt (27 tokens)
#     Preview: .saltStep-status-error > .saltStepText-description {   color: var(--salt-status-error-foreground-inf...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for StepText.css ---
# 1. css_group_1_9_rules
#    Type: grouped_content
#    Size: 295 tokens, 39 lines
#    Content preview:
#      .saltStepText-label {
#      grid-area: label;
#      }
#      ... (36 more lines)
#
#   ✅ Saved: StepText.css_chunk_001_bj8c0l.md
#
# === Processing: SliderTooltip.css ===
# File size: 1241 characters
# File type: .css
# Found 4 semantic units
#   - rule_set: rule_.saltSliderTooltip (194 tokens)
#     Preview: .saltSliderTooltip {   background: var(--salt-container-primary-background);   border-color: var(--s...
#   - rule_set: rule_.saltSliderTooltip-visible, (18 tokens)
#     Preview: .saltSliderTooltip-visible, .saltSliderTooltip:hover {   visibility: visible; }...
#   - rule_set: rule_.saltSliderTooltip-arrow (89 tokens)
#     Preview: .saltSliderTooltip-arrow {   fill: var(--salt-container-primary-background);   height: var(--salt-si...
#   - rule_set: rule_.saltSliderTooltip-text (13 tokens)
#     Preview: .saltSliderTooltip-text {   white-space: nowrap; }...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for SliderTooltip.css ---
# 1. css_group_1_4_rules
#    Type: grouped_content
#    Size: 314 tokens, 39 lines
#    Content preview:
#      .saltSliderTooltip {
#      background: var(--salt-container-primary-background);
#      border-color: var(--salt-container-primary-borderColor);
#      ... (36 more lines)
#
#   ✅ Saved: SliderTooltip.css_chunk_001_5d2rjy.md
#
# === Processing: SliderThumb.css ===
# File size: 1681 characters
# File type: .css
# Found 7 semantic units
#   - rule_set: rule_.saltSliderThumb (111 tokens)
#     Preview: .saltSliderThumb {   align-items: center;   background: var(--salt-accent-borderColor);   cursor: va...
#   - rule_set: rule_.saltSliderThumb-disabled (35 tokens)
#     Preview: .saltSliderThumb-disabled {   background: var(--salt-accent-borderColor-disabled);   cursor: var(--s...
#   - rule_set: rule_.saltSliderThumb-focusVisible (52 tokens)
#     Preview: .saltSliderThumb-focusVisible {   outline-style: var(--salt-focused-outlineStyle);   outline-width:...
#   - rule_set: rule_.saltSliderThumb:active, (28 tokens)
#     Preview: .saltSliderThumb:active, .saltSliderThumb-dragging {   cursor: var(--salt-cursor-grab-active); }...
#   - rule_set: rule_.saltSliderThumb-input (109 tokens)
#     Preview: .saltSliderThumb-input {   border: 0;   appearance: none;   cursor: var(--salt-cursor-grab);   heigh...
#   - rule_set: rule_.saltSliderThumb-secondThumb (29 tokens)
#     Preview: .saltSliderThumb-secondThumb {   /* The second thumb needs to sit on top the first thumb */   z-inde...
#   - rule_set: rule_.saltSliderThumb-accessibleTex (75 tokens)
#     Preview: .saltSliderThumb-accessibleText {   position: absolute;   height: 1px;   width: 1px;   padding: 0;...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for SliderThumb.css ---
# 1. css_group_1_7_rules
#    Type: grouped_content
#    Size: 439 tokens, 65 lines
#    Content preview:
#      .saltSliderThumb {
#      align-items: center;
#      background: var(--salt-accent-borderColor);
#      ... (62 more lines)
#
#   ✅ Saved: SliderThumb.css_chunk_001_v7dpwh.md
#
# === Processing: SliderTrack.css ===
# File size: 5090 characters
# File type: .css
# Found 32 semantic units
#   - rule_set: rule_.saltSliderTrack (114 tokens)
#     Preview: .saltSliderTrack {   --slider-track-background: var(--salt-sentiment-neutral-track);   --slider-trac...
#   - rule_set: rule_.saltSliderTrack.saltSliderTra (38 tokens)
#     Preview: .saltSliderTrack.saltSliderTrack-withMarks {   /* To wrap the marks within the boundary box */   mar...
#   - rule_set: rule_.saltSliderTrack-disabled (17 tokens)
#     Preview: .saltSliderTrack-disabled {   cursor: var(--salt-cursor-disabled); }...
#   - rule_set: rule_.saltSliderTrack-container (40 tokens)
#     Preview: .saltSliderTrack-container {   align-items: center;   display: flex;   flex-direction: row;   gap: v...
#   - rule_set: rule_.saltSliderTrack-wrapper (55 tokens)
#     Preview: .saltSliderTrack-wrapper {   align-items: center;   cursor: var(--salt-cursor-hover);   display: fle...
#   - rule_set: rule_.saltSliderTrack-disabled, (28 tokens)
#     Preview: .saltSliderTrack-disabled, .saltSliderTrack-disabled .saltSliderTrack-wrapper {   cursor: var(--salt...
#   - rule_set: rule_.saltSliderTrack-disabled_.sal (18 tokens)
#     Preview: .saltSliderTrack-disabled .saltSliderTrack-wrapper {   pointer-events: none; }...
#   - rule_set: rule_.saltSliderTrack-rail (40 tokens)
#     Preview: .saltSliderTrack-rail {   display: flex;   flex: 100%;   height: var(--salt-size-bar);   justify-con...
#   - rule_set: rule_.saltSliderTrack-rail::before, (34 tokens)
#     Preview: .saltSliderTrack-rail::before, .saltSliderTrack-rail::after {   content: "";   display: block;   hei...
#   - rule_set: rule_.saltSliderTrack-rail::before (68 tokens)
#     Preview: .saltSliderTrack-rail::before {   background: var(--slider-track-fill);   border-top-left-radius: va...
#   - rule_set: rule_.saltSliderTrack-hasMinTick.sa (25 tokens)
#     Preview: .saltSliderTrack-hasMinTick.saltSliderTrack-rail::before {   border-bottom-left-radius: unset; }...
#   - rule_set: rule_.saltSliderTrack-rail::after (72 tokens)
#     Preview: .saltSliderTrack-rail::after {   background: var(--slider-track-background);   border-top-right-radi...
#   - rule_set: rule_.saltSliderTrack-hasMaxTick.sa (25 tokens)
#     Preview: .saltSliderTrack-hasMaxTick.saltSliderTrack-rail::after {   border-bottom-right-radius: unset; }...
#   - rule_set: rule_.saltSliderTrack-range_.saltSl (44 tokens)
#     Preview: .saltSliderTrack-range .saltSliderTrack-rail::before {   background: var(--slider-track-background);...
#   - rule_set: rule_.saltSliderTrack-range_.saltSl (48 tokens)
#     Preview: .saltSliderTrack-range .saltSliderTrack-rail::after {   background: var(--slider-track-background);...
#   - rule_set: rule_.saltSliderTrack-range_.saltSl (86 tokens)
#     Preview: .saltSliderTrack-range .saltSliderTrack-rail .saltSliderTrack-fill {   background: var(--slider-trac...
#   - rule_set: rule_.saltSliderTrack-minLabel, (21 tokens)
#     Preview: .saltSliderTrack-minLabel, .saltSliderTrack-maxLabel {   user-select: none; }...
#   - rule_set: rule_.saltSliderTrack-dragging, (34 tokens)
#     Preview: .saltSliderTrack-dragging, .saltSliderTrack-dragging .saltSliderTrack-wrapper {   cursor: var(--salt...
#   - rule_set: rule_.saltSliderTrack-disabled (38 tokens)
#     Preview: .saltSliderTrack-disabled {   --slider-track-fill: var(--salt-accent-borderColor-disabled);   --slid...
#   - rule_set: rule_.saltSliderTrack-ticks (37 tokens)
#     Preview: .saltSliderTrack-ticks {   top: calc(var(--salt-size-bar) + var(--slider-tick-height));   position:...
#   - rule_set: rule_.saltSliderTrack-tick (50 tokens)
#     Preview: .saltSliderTrack-tick {   background: var(--slider-track-background);   height: var(--slider-tick-he...
#   - rule_set: rule_.saltSliderTrack-withTicks_.sa (20 tokens)
#     Preview: .saltSliderTrack-withTicks .saltSliderTrack-tickHidden {   visibility: hidden; }...
#   - rule_set: rule_.saltSliderTrack-tickSelected (18 tokens)
#     Preview: .saltSliderTrack-tickSelected {   background: var(--slider-track-fill); }...
#   - rule_set: rule_.saltSliderTrack-tick:first-of (16 tokens)
#     Preview: .saltSliderTrack-tick:first-of-type {   transform: unset; }...
#   - rule_set: rule_.saltSliderTrack-tick:last-of- (19 tokens)
#     Preview: .saltSliderTrack-tick:last-of-type {   transform: translateX(-100%); }...
#   - rule_set: rule_.saltSliderTrack-marks (25 tokens)
#     Preview: .saltSliderTrack-marks {   position: absolute;   user-select: none;   width: 100%; }...
#   - rule_set: rule_.saltSliderTrack-markLabel (118 tokens)
#     Preview: .saltSliderTrack-markLabel {   color: var(--salt-content-secondary-foreground);   font-family: var(-...
#   - rule_set: rule_.saltSliderTrack-constrainLabe (27 tokens)
#     Preview: .saltSliderTrack-constrainLabelPosition .saltSliderTrack-markLabel:first-of-type {   transform: tran...
#   - rule_set: rule_.saltSliderTrack-constrainLabe (27 tokens)
#     Preview: .saltSliderTrack-constrainLabelPosition .saltSliderTrack-markLabel:last-of-type {   transform: trans...
#   - rule_set: rule_.saltFormField_.saltSliderTrac (22 tokens)
#     Preview: .saltFormField .saltSliderTrack.saltSliderTrack-withMark {   margin-bottom: 0; }...
#   - rule_set: rule_.saltFormField_.saltSliderTrac (30 tokens)
#     Preview: .saltFormField .saltSliderTrack-container {   --saltFormField-label-width: 10%;    height: var(--sal...
#   - rule_set: rule_.saltFormField_.saltSliderTrac (33 tokens)
#     Preview: .saltFormField .saltSliderTrack-markLabel {   top: calc((var(--salt-size-base) - var(--salt-size-bar...
# Created 3 semantic chunks
# Final result: 3 total chunks
#
# --- Semantic Chunk Summary for SliderTrack.css ---
# 1. css_group_1_13_rules
#    Type: grouped_content
#    Size: 574 tokens, 86 lines
#    Content preview:
#      .saltSliderTrack {
#      --slider-track-background: var(--salt-sentiment-neutral-track);
#      --slider-track-fill: var(--salt-accent-borderColor);
#      ... (83 more lines)
#
# 2. css_group_2_14_rules
#    Type: grouped_content
#    Size: 574 tokens, 82 lines
#    Content preview:
#      .saltSliderTrack-range .saltSliderTrack-rail::before {
#      background: var(--slider-track-background);
#      width: calc(var(--slider-progressPercentageStart) - var(--salt-size-fixed-300));
#      ... (79 more lines)
#
# 3. css_group_3_5_rules
#    Type: grouped_content
#    Size: 139 tokens, 21 lines
#    Content preview:
#      .saltSliderTrack-constrainLabelPosition .saltSliderTrack-markLabel:first-of-type {
#      transform: translateX(0%);
#      }
#      ... (18 more lines)
#
#   ✅ Saved: SliderTrack.css_chunk_001_dhp4dc.md
#   ✅ Saved: SliderTrack.css_chunk_002_dhp4dc.md
#   ✅ Saved: SliderTrack.css_chunk_003_dhp4dc.md
#
# === Processing: LinearProgress.css ===
# File size: 1884 characters
# File type: .css
# Found 9 semantic units
#   - rule_set: rule_.saltLinearProgress (54 tokens)
#     Preview: .saltLinearProgress {   align-items: center;   color: var(--salt-content-primary-foreground);   disp...
#   - rule_set: rule_.saltLinearProgress-barContain (39 tokens)
#     Preview: .saltLinearProgress-barContainer {   background: none;   position: relative;   width: 100%;   overfl...
#   - rule_set: rule_.saltLinearProgress-bar, (53 tokens)
#     Preview: .saltLinearProgress-bar, .saltLinearProgress-buffer {   position: absolute;   left: 0;   bottom: 0;...
#   - rule_set: rule_.saltLinearProgress-buffer (70 tokens)
#     Preview: .saltLinearProgress-buffer {   width: 0;   background: var(--salt-container-primary-background);   o...
#   - rule_set: rule_.saltLinearProgress-bar (39 tokens)
#     Preview: .saltLinearProgress-bar {   width: 100%;   background: var(--salt-accent-background);   z-index: cal...
#   - rule_set: rule_.saltLinearProgress-track (85 tokens)
#     Preview: .saltLinearProgress-track {   background: var(--salt-sentiment-neutral-track);   width: 100%;   heig...
#   - rule_set: rule_.saltLinearProgress-progressLa (36 tokens)
#     Preview: .saltLinearProgress-progressLabel {   color: inherit;   margin: 0;   white-space: nowrap;   padding-...
#   - rule_set: rule_.saltLinearProgress-indetermin (70 tokens)
#     Preview: .saltLinearProgress-indeterminate.saltLinearProgress-bar {   position: absolute;   left: 0px;   bott...
#   - keyframes_statement: keyframes_salt (77 tokens)
#     Preview: @keyframes salt-indeterminate-progress-bar {   0% {     transform: translateX(-100%);   }   60% {...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for LinearProgress.css ---
# 1. css_group_1_9_rules
#    Type: grouped_content
#    Size: 523 tokens, 81 lines
#    Content preview:
#      .saltLinearProgress {
#      align-items: center;
#      color: var(--salt-content-primary-foreground);
#      ... (78 more lines)
#
#   ✅ Saved: LinearProgress.css_chunk_001_m85ux1.md
#
# === Processing: CircularProgress.css ===
# File size: 3147 characters
# File type: .css
# Found 14 semantic units
#   - rule_set: rule_.saltCircularProgress (28 tokens)
#     Preview: .saltCircularProgress {   color: var(--salt-content-primary-foreground);   display: inline-flex;   p...
#   - rule_set: rule_.saltCircularProgress-progress (59 tokens)
#     Preview: .saltCircularProgress-progressLabel {   align-items: center;   color: var(--salt-content-primary-for...
#   - rule_set: rule_.saltCircularProgress-track (110 tokens)
#     Preview: .saltCircularProgress-track {   inline-size: calc(var(--salt-size-base) * 3);   block-size: calc(var...
#   - rule_set: rule_.saltCircularProgress-bar, (73 tokens)
#     Preview: .saltCircularProgress-bar, .saltCircularProgress-bufferBorder, .saltCircularProgress-bufferBackgroun...
#   - rule_set: rule_.saltCircularProgress-bar (40 tokens)
#     Preview: .saltCircularProgress-bar {   border-color: var(--salt-accent-background);   border-style: var(--sal...
#   - rule_set: rule_.saltCircularProgress-bufferBo (62 tokens)
#     Preview: .saltCircularProgress-bufferBorder {   border: solid var(--salt-size-fixed-100) var(--salt-accent-ba...
#   - rule_set: rule_.saltCircularProgress-bufferBa (53 tokens)
#     Preview: .saltCircularProgress-bufferBackground {   border: solid var(--salt-size-bar-strong) var(--salt-cont...
#   - rule_set: rule_.saltCircularProgress-bars (42 tokens)
#     Preview: .saltCircularProgress-bars {   position: absolute;   inset-block-start: 0;   inset-inline-start: 0;...
#   - rule_set: rule_.saltCircularProgress-bufferOv (90 tokens)
#     Preview: .saltCircularProgress-bufferOverlayRight, .saltCircularProgress-bufferOverlayLeft, .saltCircularProg...
#   - rule_set: rule_.saltCircularProgress-bufferOv (53 tokens)
#     Preview: .saltCircularProgress-bufferOverlayRight, .saltCircularProgress-bufferOverlayLeft, .saltCircularProg...
#   - rule_set: rule_.saltCircularProgress-bufferSu (52 tokens)
#     Preview: .saltCircularProgress-bufferSubOverlayRight, .saltCircularProgress-bufferSubOverlayLeft, .saltCircul...
#   - rule_set: rule_.saltCircularProgress-bufferOv (25 tokens)
#     Preview: .saltCircularProgress-bufferOverlayLeft, .saltCircularProgress-barOverlayLeft {   transform: rotate(...
#   - rule_set: rule_.saltCircularProgress-bufferOv (65 tokens)
#     Preview: .saltCircularProgress-bufferOverlayRight:before, .saltCircularProgress-bufferSubOverlay:before {   c...
#   - rule_set: rule_.saltCircularProgress-bufferOv (27 tokens)
#     Preview: .saltCircularProgress-bufferOverlayRight:before {   bottom: 0;   z-index: var(--salt-zIndex-default)...
# Created 2 semantic chunks
# Final result: 2 total chunks
#
# --- Semantic Chunk Summary for CircularProgress.css ---
# 1. css_group_1_9_rules
#    Type: grouped_content
#    Size: 557 tokens, 76 lines
#    Content preview:
#      .saltCircularProgress {
#      color: var(--salt-content-primary-foreground);
#      display: inline-flex;
#      ... (73 more lines)
#
# 2. css_group_2_5_rules
#    Type: grouped_content
#    Size: 222 tokens, 36 lines
#    Content preview:
#      .saltCircularProgress-bufferOverlayRight,
#      .saltCircularProgress-bufferOverlayLeft,
#      .saltCircularProgress-barOverlayRight,
#      ... (33 more lines)
#
#   ✅ Saved: CircularProgress.css_chunk_001_v2wxnh.md
#   ✅ Saved: CircularProgress.css_chunk_002_v2wxnh.md
#
# 🎉 OVERALL SUMMARY
# Files processed: 358
# Total chunks created: 447
# Total chunk files saved: 447
# Output directory: /Users/tiyadiashok/python-projects/code_chunker/rag_chunks/pre_processed/code_sources/typescript/saltds_latest_chunks
# Average chunk size: 342 tokens
# Largest chunk: 1008 tokens
# Smallest chunk: 10 tokens
#
# Chunk types:
#   complete_module: 174
#   export_statement: 42
#   export_statement_part: 22
#   function_declaration: 11
#   function_declaration_part: 4
#   grouped_content: 138
#   imports_group: 28
#   interface_declaration: 9
#   rule_set: 15
#   type_alias_declaration: 4
#
# Chunks by file type:
#   .css: ~116 chunks
#   .ts: ~161 chunks
#   .tsx: ~169 chunks

# %% [markdown]
# Minimal changes made:
#
# Added .d.ts to supported extensions and parser mapping
# Added get_file_extension() function that properly detects .d.ts files (checks if filename ends with .d.ts before falling back to .suffix)
# Updated syntax highlighting to map .d.ts to typescript
# Updated all extension checks to use the new get_file_extension() function
#
# Now .d.ts files will be:
#
# ✅ Discovered during file scanning (as they end with .ts)
# ✅ Properly identified as .d.ts type
# ✅ Parsed with TypeScript parser
# ✅ Highlighted as typescript in markdown
# ✅ Saved with correct filenames like declarations.d.ts_chunk_001_a1b2c3.md
#
# The issue was that Path.suffix only returns the last extension (.ts) but we needed to detect the full .d.ts pattern!

# %%
#!/usr/bin/env python3

import os
import secrets
import string
from pathlib import Path
from typing import List, Dict, Any
import tiktoken

# Tree-sitter setup for multiple languages
try:
    from tree_sitter_language_pack import get_language, get_parser
    tsx_language = get_language('tsx')
    tsx_parser = get_parser('tsx')
    css_language = get_language('css')
    css_parser = get_parser('css')
    html_language = get_language('html')
    html_parser = get_parser('html')
    print("✅ Using TSX, CSS, and HTML parsers")
except ImportError:
    print("Please install: pip install tree-sitter-languages")
    exit(1)

# Configuration
MAX_CHUNK_TOKENS = 1000
MAX_RECURSION_DEPTH = 3

# Supported file extensions and their parsers
SUPPORTED_EXTENSIONS = ['.tsx', '.ts', '.js', '.jsx', '.css', '.scss', '.html']
PARSER_MAP = {
    '.tsx': tsx_parser,
    '.ts': tsx_parser,
    '.js': tsx_parser,
    '.jsx': tsx_parser,
    '.css': css_parser,
    '.scss': css_parser,
    '.html': html_parser
}

# Initialize token encoder
encoder = tiktoken.get_encoding("cl100k_base")

def count_tokens(text: str) -> int:
    """Count tokens in text"""
    return len(encoder.encode(text))

def get_syntax_highlighting_language(file_extension: str) -> str:
    """Get appropriate syntax highlighting language for markdown output"""
    language_map = {
        '.tsx': 'tsx',
        '.ts': 'typescript', 
        '.js': 'javascript',
        '.jsx': 'jsx',
        '.css': 'css',
        '.scss': 'scss',
        '.html': 'html'
    }
    return language_map.get(file_extension, 'text')

class Chunk:
    def __init__(self, start_byte: int, end_byte: int, content: str, node_type: str, name: str, depth: int = 0):
        self.start_byte = start_byte
        self.end_byte = end_byte
        self.content = content
        self.node_type = node_type
        self.name = name
        self.depth = depth
        self.token_count = count_tokens(content)
        self.sub_chunks = []

def extract_node_name(node, source_code: str) -> str:
    """Extract meaningful name from AST node"""
    node_text = source_code[node.start_byte:node.end_byte]
    lines = node_text.split('\n')
    
    import re
    
    # Try different patterns based on node type
    if node.type == 'function_declaration':
        match = re.search(r'function\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
        if match:
            return match.group(1)
    
    elif node.type == 'variable_declaration':
        # Look for const/let ComponentName = forwardRef or const hook = 
        match = re.search(r'(?:const|let|var)\s+([a-zA-Z_$][a-zA-Z0-9_$]*)\s*=', node_text)
        if match:
            return match.group(1)
    
    elif node.type == 'interface_declaration':
        match = re.search(r'interface\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
        if match:
            return match.group(1)
    
    elif node.type == 'type_alias_declaration':
        match = re.search(r'type\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
        if match:
            return match.group(1)
    
    elif node.type in ['module_declaration', 'ambient_declaration']:
        # Handle declare module statements
        match = re.search(r'declare\s+module\s+["\']([^"\']+)["\']', node_text)
        if match:
            return f"module_{match.group(1).replace('*', 'wildcard').replace('/', '_')}"
        match = re.search(r'module\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
        if match:
            return f"module_{match.group(1)}"
        return "declare_module"
    
    elif node.type == 'class_declaration':
        match = re.search(r'class\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
        if match:
            return match.group(1)
    
    elif node.type == 'export_statement':
        # Handle various export patterns
        if 'export interface' in node_text:
            match = re.search(r'export\s+interface\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
            if match:
                return f"interface_{match.group(1)}"
        elif 'export const' in node_text:
            match = re.search(r'export\s+const\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
            if match:
                return f"const_{match.group(1)}"
        elif 'export function' in node_text:
            match = re.search(r'export\s+function\s+([a-zA-Z_$][a-zA-Z0-9_$]*)', node_text)
            if match:
                return f"function_{match.group(1)}"
        elif 'export default' in node_text:
            return "default_export"
        else:
            return "export_statement"
    
    # Fallback
    first_line = lines[0][:50].strip()
    simple_match = re.search(r'\b([a-zA-Z_$][a-zA-Z0-9_$]*)', first_line)
    if simple_match:
        return simple_match.group(1)
    
    return f"{node.type}_{node.start_byte}"

def find_semantic_chunks(tree, source_code: str, file_extension: str) -> List[Dict[str, Any]]:
    """Find semantic chunks - complete, meaningful code blocks"""
    semantic_nodes = []
    
    def traverse(node, parent_types=None):
        if parent_types is None:
            parent_types = []
        
        current_parent_types = parent_types + [node.type]
        node_text = source_code[node.start_byte:node.end_byte]
        
        # Handle different file types
        if file_extension in ['.css', '.scss']:
            # CSS/SCSS semantic boundaries - group smaller rules together
            if node.type in ['rule_set', 'at_rule', 'keyframes_statement'] and len(parent_types) <= 1:
                name = extract_css_name(node, source_code)
                semantic_nodes.append({
                    'node': node, 'name': name, 'start_byte': node.start_byte,
                    'end_byte': node.end_byte, 'type': node.type, 'content': node_text
                })
                return
                
        elif file_extension == '.html':
            # HTML semantic boundaries  
            if node.type in ['element', 'script_element', 'style_element'] and len(parent_types) <= 2:
                name = extract_html_name(node, source_code)
                if len(node_text.strip()) > 100:  # Only substantial elements
                    semantic_nodes.append({
                        'node': node, 'name': name, 'start_byte': node.start_byte,
                        'end_byte': node.end_byte, 'type': node.type, 'content': node_text
                    })
                    return
                    
        else:
            # JavaScript/TypeScript semantic boundaries (existing logic)
            if node.type in ['import_statement', 'import_declaration'] and len(parent_types) <= 1:
                name = extract_node_name(node, source_code)
                semantic_nodes.append({
                    'node': node, 'name': f"import_{name}", 'start_byte': node.start_byte,
                    'end_byte': node.end_byte, 'type': 'import_statement', 'content': node_text
                })
                return
            
            elif node.type == 'function_declaration' and len(parent_types) <= 1:
                name = extract_node_name(node, source_code)
                semantic_nodes.append({
                    'node': node, 'name': name, 'start_byte': node.start_byte,
                    'end_byte': node.end_byte, 'type': node.type, 'content': node_text
                })
                return
            
            elif node.type in ['interface_declaration', 'type_alias_declaration', 'module_declaration', 'ambient_declaration'] and len(parent_types) <= 1:
                name = extract_node_name(node, source_code)
                semantic_nodes.append({
                    'node': node, 'name': name, 'start_byte': node.start_byte,
                    'end_byte': node.end_byte, 'type': node.type, 'content': node_text
                })
                return
            
            elif node.type == 'variable_declaration' and len(parent_types) <= 1:
                if any(pattern in node_text for pattern in ['forwardRef', '= (' , 'useState', 'useEffect', 'createContext', 'makePrefixer']):
                    name = extract_node_name(node, source_code)
                    semantic_nodes.append({
                        'node': node, 'name': name, 'start_byte': node.start_byte,
                        'end_byte': node.end_byte, 'type': 'component_or_hook', 'content': node_text
                    })
                    return
            
            elif node.type == 'export_statement' and len(parent_types) <= 1:
                name = extract_node_name(node, source_code)
                if len(node_text.strip()) > 50:
                    semantic_nodes.append({
                        'node': node, 'name': name, 'start_byte': node.start_byte,
                        'end_byte': node.end_byte, 'type': node.type, 'content': node_text
                    })
                    return
        
        # Continue traversing children for other nodes
        for child in node.children:
            traverse(child, current_parent_types)
    
    traverse(tree.root_node)
    
    # Sort by start position and remove overlaps
    semantic_nodes.sort(key=lambda x: x['start_byte'])
    
    # Remove nested/overlapping nodes
    filtered_nodes = []
    for node in semantic_nodes:
        is_contained = False
        for existing in filtered_nodes:
            if (existing['start_byte'] <= node['start_byte'] and 
                existing['end_byte'] >= node['end_byte']):
                is_contained = True
                break
        
        if not is_contained:
            to_remove = []
            for i, existing in enumerate(filtered_nodes):
                if (node['start_byte'] <= existing['start_byte'] and 
                    node['end_byte'] >= existing['end_byte']):
                    to_remove.append(i)
            
            for i in reversed(to_remove):
                filtered_nodes.pop(i)
            
            filtered_nodes.append(node)
    
    return filtered_nodes

def extract_css_name(node, source_code: str) -> str:
    """Extract meaningful name from CSS/SCSS node"""
    import re
    node_text = source_code[node.start_byte:node.end_byte]
    first_line = node_text.split('\n')[0].strip()
    
    if node.type == 'rule_set':
        # Extract selector
        match = re.search(r'^([^{]+)', first_line)
        if match:
            selector = match.group(1).strip()
            return f"rule_{selector[:30].replace(' ', '_')}"
    elif node.type == 'at_rule':
        # Extract @rule name
        match = re.search(r'@(\w+)', first_line)
        if match:
            return f"at_{match.group(1)}"
    elif node.type == 'keyframes_statement':
        match = re.search(r'@keyframes\s+(\w+)', first_line)
        if match:
            return f"keyframes_{match.group(1)}"
    
    return f"{node.type}_{node.start_byte}"

def extract_html_name(node, source_code: str) -> str:
    """Extract meaningful name from HTML node"""
    import re
    node_text = source_code[node.start_byte:node.end_byte]
    first_line = node_text.split('\n')[0].strip()
    
    # Extract tag name and important attributes
    if node.type in ['element', 'script_element', 'style_element']:
        match = re.search(r'<(\w+)(?:\s+[^>]*)?>', first_line)
        if match:
            tag = match.group(1)
            # Look for id or class
            id_match = re.search(r'id=["\']([^"\']+)["\']', first_line)
            class_match = re.search(r'class=["\']([^"\']+)["\']', first_line)
            
            if id_match:
                return f"{tag}#{id_match.group(1)}"
            elif class_match:
                return f"{tag}.{class_match.group(1).split()[0]}"
            else:
                return tag
    
    return f"{node.type}_{node.start_byte}"

def create_semantic_chunks(semantic_nodes: List[Dict[str, Any]]) -> List[Chunk]:
    """Create chunks from semantic nodes"""
    chunks = []
    
    for node_info in semantic_nodes:
        chunk = Chunk(
            start_byte=node_info['start_byte'],
            end_byte=node_info['end_byte'],
            content=node_info['content'],
            node_type=node_info['type'],
            name=node_info['name'],
            depth=0
        )
        chunks.append(chunk)
    
    return chunks

def group_small_chunks(chunks: List[Chunk], target_tokens: int = 600, file_extension: str = '') -> List[Chunk]:
    """Group small chunks together to reach reasonable size for any file type"""
    if not chunks:
        return chunks
    
    # Separate imports from other chunks for JS/TS files
    if file_extension in ['.tsx', '.ts', '.jsx', '.js']:
        import_chunks = [c for c in chunks if c.node_type == 'import_statement']
        other_chunks = [c for c in chunks if c.node_type != 'import_statement']
        
        # Check if everything together is under limit
        total_tokens = sum(c.token_count for c in chunks)
        if total_tokens <= MAX_CHUNK_TOKENS:
            # Combine everything into one chunk
            combined_content = '\n\n'.join(c.content for c in chunks)
            combined_chunk = Chunk(
                start_byte=chunks[0].start_byte,
                end_byte=chunks[-1].end_byte,
                content=combined_content,
                node_type='complete_module',
                name=f"complete_module_{len(chunks)}_parts",
                depth=0
            )
            return [combined_chunk]
        
        # If too large, handle imports separately
        if import_chunks:
            total_import_tokens = sum(c.token_count for c in import_chunks)
            if total_import_tokens <= MAX_CHUNK_TOKENS:
                # Combine all imports into one chunk
                combined_imports = '\n'.join(c.content for c in import_chunks)
                imports_chunk = Chunk(
                    start_byte=import_chunks[0].start_byte,
                    end_byte=import_chunks[-1].end_byte,
                    content=combined_imports,
                    node_type='imports_group',
                    name=f"imports_{len(import_chunks)}_statements",
                    depth=0
                )
                import_chunks = [imports_chunk]
        
        # Group other chunks
        grouped_others = group_chunks_by_size(other_chunks, target_tokens, file_extension)
        
        # Combine imports + other chunks
        return import_chunks + grouped_others
    else:
        # For non-JS files, use original logic
        return group_chunks_by_size(chunks, target_tokens, file_extension)

def group_chunks_by_size(chunks: List[Chunk], target_tokens: int = 600, file_extension: str = '') -> List[Chunk]:
    """Group chunks by size logic"""
    if not chunks:
        return chunks
    
    # Skip grouping if we already have reasonably sized chunks
    if len(chunks) == 1 or any(c.token_count > target_tokens for c in chunks):
        total_tokens = sum(c.token_count for c in chunks)
        if total_tokens <= MAX_CHUNK_TOKENS:
            # All chunks together are still under limit - combine them
            if len(chunks) > 1:
                combined_content = '\n\n'.join(c.content for c in chunks)
                
                # Create descriptive name based on file type
                if file_extension in ['.css', '.scss']:
                    group_name = f"css_styles_{len(chunks)}_rules"
                elif file_extension in ['.tsx', '.ts', '.jsx', '.js']:
                    group_name = f"file_module_{len(chunks)}_exports"
                elif file_extension == '.html':
                    group_name = f"html_content_{len(chunks)}_elements"
                else:
                    group_name = f"file_content_{len(chunks)}_parts"
                
                combined_chunk = Chunk(
                    start_byte=chunks[0].start_byte,
                    end_byte=chunks[-1].end_byte,
                    content=combined_content,
                    node_type='grouped_content',
                    name=group_name,
                    depth=0
                )
                return [combined_chunk]
        return chunks
    
    # Group small chunks
    grouped_chunks = []
    current_group = []
    current_tokens = 0
    
    for chunk in chunks:
        if current_tokens + chunk.token_count > target_tokens and current_group:
            # Finalize current group
            group_content = '\n\n'.join(c.content for c in current_group)
            
            if file_extension in ['.css', '.scss']:
                group_name = f"css_group_{len(grouped_chunks)+1}_{len(current_group)}_rules"
            elif file_extension in ['.tsx', '.ts', '.jsx', '.js']:
                group_name = f"code_group_{len(grouped_chunks)+1}_{len(current_group)}_parts"
            elif file_extension == '.html':
                group_name = f"html_group_{len(grouped_chunks)+1}_{len(current_group)}_elements"
            else:
                group_name = f"group_{len(grouped_chunks)+1}_{len(current_group)}_parts"
            
            grouped_chunk = Chunk(
                start_byte=current_group[0].start_byte,
                end_byte=current_group[-1].end_byte,
                content=group_content,
                node_type='grouped_content',
                name=group_name,
                depth=0
            )
            grouped_chunks.append(grouped_chunk)
            
            current_group = [chunk]
            current_tokens = chunk.token_count
        else:
            current_group.append(chunk)
            current_tokens += chunk.token_count
    
    # Add remaining chunks
    if current_group:
        if len(current_group) == 1 and current_tokens > target_tokens//2:
            grouped_chunks.append(current_group[0])
        else:
            group_content = '\n\n'.join(c.content for c in current_group)
            
            if file_extension in ['.css', '.scss']:
                group_name = f"css_group_{len(grouped_chunks)+1}_{len(current_group)}_rules"
            elif file_extension in ['.tsx', '.ts', '.jsx', '.js']:
                group_name = f"code_group_{len(grouped_chunks)+1}_{len(current_group)}_parts"
            elif file_extension == '.html':
                group_name = f"html_group_{len(grouped_chunks)+1}_{len(current_group)}_elements"
            else:
                group_name = f"group_{len(grouped_chunks)+1}_{len(current_group)}_parts"
            
            grouped_chunk = Chunk(
                start_byte=current_group[0].start_byte,
                end_byte=current_group[-1].end_byte,
                content=group_content,
                node_type='grouped_content',
                name=group_name,
                depth=0
            )
            grouped_chunks.append(grouped_chunk)
    
    return grouped_chunks

def sub_chunk_by_statements(chunk: Chunk, tree, source_code: str, depth: int = 0) -> List[Chunk]:
    """Sub-chunk by breaking down into logical statements/blocks"""
    if depth >= MAX_RECURSION_DEPTH or chunk.token_count <= MAX_CHUNK_TOKENS:
        return [chunk]
    
    print(f"    Breaking down {chunk.name} ({chunk.token_count} tokens) into smaller pieces...")
    
    # Simple line-based splitting for now
    lines = chunk.content.split('\n')
    sub_chunks = []
    current_lines = []
    current_size = 0
    
    for line in lines:
        line_tokens = count_tokens(line)
        
        if current_size + line_tokens > MAX_CHUNK_TOKENS and current_lines:
            # Create sub-chunk
            sub_content = '\n'.join(current_lines)
            if sub_content.strip():
                sub_chunk = Chunk(
                    start_byte=chunk.start_byte,  # Approximate
                    end_byte=chunk.start_byte + len(sub_content),
                    content=sub_content,
                    node_type=f"{chunk.node_type}_part",
                    name=f"{chunk.name}_part_{len(sub_chunks)+1}",
                    depth=depth + 1
                )
                sub_chunks.append(sub_chunk)
            
            current_lines = [line]
            current_size = line_tokens
        else:
            current_lines.append(line)
            current_size += line_tokens
    
    # Add remaining lines
    if current_lines:
        sub_content = '\n'.join(current_lines)
        if sub_content.strip():
            sub_chunk = Chunk(
                start_byte=chunk.start_byte,
                end_byte=chunk.end_byte,
                content=sub_content,
                node_type=f"{chunk.node_type}_part",
                name=f"{chunk.name}_part_{len(sub_chunks)+1}",
                depth=depth + 1
            )
            sub_chunks.append(sub_chunk)
    
    chunk.sub_chunks = sub_chunks
    return sub_chunks if len(sub_chunks) > 1 else [chunk]

def process_file(file_path: Path) -> List[Chunk]:
    """Process a single file and return semantic chunks"""
    print(f"\n=== Processing: {file_path.name} ===")
    
    # Read file
    with open(file_path, 'r', encoding='utf-8') as f:
        source_code = f.read()
    
    print(f"File size: {len(source_code)} characters")
    print(f"File type: {file_path.suffix}")
    
    # Get appropriate parser
    parser = PARSER_MAP.get(file_path.suffix)
    if not parser:
        print(f"❌ No parser available for {file_path.suffix}")
        return []
    
    # Parse with appropriate parser
    tree = parser.parse(source_code.encode('utf-8'))
    
    if tree.root_node.has_error:
        print("⚠️ Parse errors detected")
    
    # Find semantic chunks
    semantic_nodes = find_semantic_chunks(tree, source_code, file_path.suffix)
    print(f"Found {len(semantic_nodes)} semantic units")
    
    # Show what we found
    for node in semantic_nodes:
        preview = node['content'][:100].replace('\n', ' ').strip()
        print(f"  - {node['type']}: {node['name']} ({count_tokens(node['content'])} tokens)")
        print(f"    Preview: {preview}...")
    
    # Create chunks
    base_chunks = create_semantic_chunks(semantic_nodes)
    
    # Group small chunks for all file types
    base_chunks = group_small_chunks(base_chunks, target_tokens=600, file_extension=file_path.suffix)
    
    print(f"Created {len(base_chunks)} semantic chunks")
    
    # Apply sub-chunking for oversized chunks
    final_chunks = []
    oversized_count = 0
    
    for chunk in base_chunks:
        if chunk.token_count > MAX_CHUNK_TOKENS:
            print(f"  Sub-chunking {chunk.name} ({chunk.token_count} tokens)")
            sub_chunks = sub_chunk_by_statements(chunk, tree, source_code)
            final_chunks.extend(sub_chunks)
            oversized_count += 1
        else:
            final_chunks.append(chunk)
    
    if oversized_count > 0:
        print(f"Sub-chunked {oversized_count} oversized chunks")
    print(f"Final result: {len(final_chunks)} total chunks")
    
    return final_chunks

def generate_unique_id(length: int = 6) -> str:
    """Generate a random unique ID"""
    alphabet = string.ascii_lowercase + string.digits
    return ''.join(secrets.choice(alphabet) for _ in range(length))

def create_chunk_filename(original_filename: str, chunk_number: int, unique_id: str) -> str:
    """Create chunk filename: Accordion.tsx_chunk_001_a1s2d3.md"""
    return f"{original_filename}_chunk_{chunk_number:03d}_{unique_id}.md"

def get_markdown_language(file_extension: str) -> str:
    """Get markdown language for code blocks"""
    lang_map = {
        '.tsx': 'tsx',
        '.ts': 'typescript', 
        '.js': 'javascript',
        '.jsx': 'jsx',
        '.css': 'css',
        '.scss': 'scss',
        '.html': 'html'
    }
    return lang_map.get(file_extension, 'text')

def create_chunk_markdown(chunk: Chunk, source_file_path: str, file_extension: str) -> str:
    """Create markdown content with YAML frontmatter"""
    language = get_markdown_language(file_extension)
    
    markdown_content = f"""---
source_file: {source_file_path}
chunk_index: {getattr(chunk, 'index', 1)}
chunk_type: {chunk.node_type}
chunk_name: {chunk.name}
token_count: {chunk.token_count}
---

# {chunk.name}

```{language}
{chunk.content}
```
"""
    return markdown_content

def save_chunks_to_files(chunks: List[Chunk], 
                        original_file_path: Path, 
                        input_directory: Path,
                        output_base: Path) -> List[str]:
    """Save chunks as markdown files maintaining directory structure"""
    if not chunks:
        return []
    
    # Calculate relative path from input directory
    try:
        rel_path = original_file_path.relative_to(input_directory)
    except ValueError:
        # If file is not under input directory, use just the filename
        rel_path = original_file_path.name
    
    # Create output directory structure
    output_dir = output_base / rel_path.parent
    output_dir.mkdir(parents=True, exist_ok=True)
    
    # Generate unique ID for this file
    file_unique_id = generate_unique_id()
    
    saved_files = []
    
    # Add chunk index to each chunk and save
    for i, chunk in enumerate(chunks, 1):
        chunk.index = i  # Add index attribute
        
        # Create chunk filename
        chunk_filename = create_chunk_filename(
            original_file_path.name, 
            i, 
            file_unique_id
        )
        
        # Create markdown content
        markdown_content = create_chunk_markdown(
            chunk, 
            str(rel_path), 
            original_file_path.suffix
        )
        
        # Write to file
        chunk_file_path = output_dir / chunk_filename
        try:
            with open(chunk_file_path, 'w', encoding='utf-8') as f:
                f.write(markdown_content)
            
            saved_files.append(str(chunk_file_path))
            print(f"  ✅ Saved: {chunk_filename}")
            
        except Exception as e:
            print(f"  ❌ Error saving {chunk_filename}: {e}")
    
    return saved_files
def print_chunk_summary(chunks: List[Chunk], file_name: str):
    """Print detailed summary of chunks"""
    print(f"\n--- Semantic Chunk Summary for {file_name} ---")
    
    for i, chunk in enumerate(chunks, 1):
        indent = "  " * chunk.depth
        content_lines = len(chunk.content.split('\n'))
        
        print(f"{indent}{i}. {chunk.name}")
        print(f"{indent}   Type: {chunk.node_type}")
        print(f"{indent}   Size: {chunk.token_count} tokens, {content_lines} lines")
        print(f"{indent}   Content preview:")
        
        # Show first few lines of actual content
        content_lines_list = chunk.content.split('\n')
        for j, line in enumerate(content_lines_list[:3]):
            print(f"{indent}     {line.strip()}")
        if len(content_lines_list) > 3:
            print(f"{indent}     ... ({len(content_lines_list) - 3} more lines)")
        print()

def main():
    """Main function to test semantic chunking"""
    print("🚀 Multi-Language Semantic Chunking Test")
    print(f"Max chunk tokens: {MAX_CHUNK_TOKENS}")
    print(f"Max recursion depth: {MAX_RECURSION_DEPTH}")
    print(f"Supported extensions: {', '.join(SUPPORTED_EXTENSIONS)}")
    
    # Get directory from user or use current directory
    directory = input("\nEnter directory path (or press Enter for current directory): ").strip()
    if not directory:
        directory = "."
    
    target_dir = Path(directory)
    if not target_dir.exists():
        print(f"❌ Directory not found: {directory}")
        return
    
    # Find all supported files
    all_files = []
    for ext in SUPPORTED_EXTENSIONS:
        files = list(target_dir.rglob(f"*{ext}"))
        all_files.extend(files)
    
    if not all_files:
        print(f"❌ No supported files found in {directory}")
        print(f"Looking for: {', '.join(SUPPORTED_EXTENSIONS)}")
        return
    
    print(f"📁 Found {len(all_files)} supported files:")
    # Group by extension for summary
    by_ext = {}
    by_dir = {}
    for f in all_files:
        ext = f.suffix
        by_ext[ext] = by_ext.get(ext, 0) + 1
        
        # Track directory depth
        rel_path = f.relative_to(target_dir)
        dir_path = str(rel_path.parent) if rel_path.parent != Path('.') else 'root'
        by_dir[dir_path] = by_dir.get(dir_path, 0) + 1
    
    for ext, count in sorted(by_ext.items()):
        print(f"  {ext}: {count} files")
    
    # Show directory structure if there are subdirectories
    if len(by_dir) > 1 or 'root' not in by_dir:
        print(f"\n📂 Directory distribution:")
        for dir_path, count in sorted(by_dir.items()):
            if dir_path == 'root':
                print(f"  ./: {count} files")
            else:
                depth = dir_path.count('/') if '/' in dir_path else dir_path.count('\\')
                indent = "  " + "  " * depth
                print(f"{indent}{dir_path}/: {count} files")
    
    # Process each file
    all_chunks = []
    all_saved_files = []
    
    # Create output directory
    output_directory = target_dir.parent / f"{target_dir.name}_chunks"
    print(f"\n📁 Output directory: {output_directory}")
    
    for file_path in all_files:
        try:
            chunks = process_file(file_path)
            all_chunks.extend(chunks)
            print_chunk_summary(chunks, file_path.name)
            
            # Save chunks to files
            saved_files = save_chunks_to_files(chunks, file_path, target_dir, output_directory)
            all_saved_files.extend(saved_files)
            
        except Exception as e:
            print(f"❌ Error processing {file_path}: {e}")
    
    # Overall summary
    print(f"\n🎉 OVERALL SUMMARY")
    print(f"Files processed: {len(all_files)}")
    print(f"Total chunks created: {len(all_chunks)}")
    print(f"Total chunk files saved: {len(all_saved_files)}")
    print(f"Output directory: {output_directory}")
    
    if all_chunks:
        avg_tokens = sum(c.token_count for c in all_chunks) / len(all_chunks)
        max_tokens = max(c.token_count for c in all_chunks)
        min_tokens = min(c.token_count for c in all_chunks)
        
        print(f"Average chunk size: {avg_tokens:.0f} tokens")
        print(f"Largest chunk: {max_tokens} tokens")
        print(f"Smallest chunk: {min_tokens} tokens")
        
        # Count by node type
        type_counts = {}
        for chunk in all_chunks:
            type_counts[chunk.node_type] = type_counts.get(chunk.node_type, 0) + 1
        
        print(f"\nChunk types:")
        for node_type, count in sorted(type_counts.items()):
            print(f"  {node_type}: {count}")
            
        # Count by file type
        print(f"\nChunks by file type:")
        file_type_chunks = {}
        # We need to track file types in chunks - simplified approach
        for ext, count in sorted(by_ext.items()):
            # Estimate chunks per file type based on proportions
            proportion = count / len(all_files)
            estimated_chunks = int(len(all_chunks) * proportion)
            file_type_chunks[ext] = estimated_chunks
            print(f"  {ext}: ~{estimated_chunks} chunks")

if __name__ == "__main__":
    main()
# Out:
# ✅ Using TSX, CSS, and HTML parsers
# 🚀 Multi-Language Semantic Chunking Test
# Max chunk tokens: 1000
# Max recursion depth: 3
# Supported extensions: .tsx, .ts, .js, .jsx, .css, .scss, .html
# 📁 Found 358 supported files:
#   .css: 93 files
#   .ts: 129 files
#   .tsx: 136 files
#
# 📂 Directory distribution:
#   src/: 3 files
#     src/accordion/: 10 files
#     src/aria-announcer/: 5 files
#     src/avatar/: 4 files
#     src/badge/: 3 files
#     src/banner/: 7 files
#     src/border-item/: 3 files
#     src/border-layout/: 2 files
#     src/breakpoints/: 3 files
#     src/button/: 4 files
#     src/card/: 3 files
#     src/checkbox/: 7 files
#       src/checkbox/internal/: 2 files
#     src/combo-box/: 4 files
#     src/dialog/: 12 files
#     src/divider/: 3 files
#     src/drawer/: 5 files
#     src/dropdown/: 3 files
#     src/file-drop-zone/: 5 files
#       src/file-drop-zone/internal/: 1 files
#     src/flex-item/: 3 files
#     src/flex-layout/: 4 files
#     src/flow-layout/: 2 files
#     src/form-field/: 7 files
#     src/form-field-context/: 3 files
#     src/grid-item/: 3 files
#     src/grid-layout/: 3 files
#     src/input/: 3 files
#     src/interactable-card/: 7 files
#     src/link/: 4 files
#     src/link-card/: 3 files
#     src/list-box/: 3 files
#     src/list-control/: 3 files
#     src/menu/: 14 files
#     src/multiline-input/: 3 files
#     src/navigation-item/: 5 files
#     src/option/: 8 files
#     src/overlay/: 12 files
#     src/pagination/: 18 files
#     src/panel/: 3 files
#     src/parent-child-layout/: 4 files
#     src/pill/: 3 files
#     src/pill-input/: 4 files
#     src/progress/: 1 files
#       src/progress/CircularProgress/: 2 files
#       src/progress/LinearProgress/: 2 files
#     src/radio-button/: 7 files
#       src/radio-button/internal/: 2 files
#     src/salt-provider/: 3 files
#     src/scrim/: 3 files
#     src/segmented-button-group/: 3 files
#     src/semantic-icon-provider/: 2 files
#     src/skip-link/: 3 files
#       src/skip-link/internal/: 1 files
#     src/slider/: 3 files
#       src/slider/internal/: 9 files
#     src/spinner/: 3 files
#       src/spinner/svgSpinners/: 1 files
#     src/split-layout/: 3 files
#     src/stack-layout/: 3 files
#     src/status-adornment/: 6 files
#     src/status-indicator/: 4 files
#     src/stepper/: 5 files
#       src/stepper/internal/: 10 files
#     src/switch/: 3 files
#     src/tag/: 3 files
#     src/text/: 9 files
#     src/theme/: 8 files
#     src/toast/: 5 files
#     src/toggle-button/: 3 files
#     src/toggle-button-group/: 4 files
#     src/tooltip/: 6 files
#     src/utils/: 26 files
#       src/utils/useFloatingUI/: 2 files
#     src/viewport/: 2 files
#
# 📁 Output directory: /Users/tiyadiashok/python-projects/code_chunker/rag_chunks/pre_processed/code_sources/typescript/saltds_latest_chunks
#
# === Processing: Dropdown.tsx ===
# File size: 13602 characters
# File type: .tsx
# Found 17 semantic units
#   - import_statement: import_import (35 tokens)
#     Preview: import {   flip,   offset,   size,   useClick,   useDismiss,   useFocus,   useInteractions, } from "...
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (52 tokens)
#     Preview: import {   Children,   type ComponentPropsWithoutRef,   type FocusEvent,   type ForwardedRef,   forw...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useFormFieldProps } from "../form-field-context";...
#   - import_statement: import_import (21 tokens)
#     Preview: import {   ListControlContext,   type OptionValue, } from "../list-control/ListControlContext";...
#   - import_statement: import_import (26 tokens)
#     Preview: import {   defaultValueToString,   type ListControlProps,   useListControl, } from "../list-control/...
#   - import_statement: import_import (12 tokens)
#     Preview: import { OptionList } from "../option/OptionList";...
#   - import_statement: import_import (11 tokens)
#     Preview: import { useIcon } from "../semantic-icon-provider";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { StatusAdornment } from "../status-adornment";...
#   - import_statement: import_import (12 tokens)
#     Preview: import type { ValidationStatus } from "../status-indicator";...
#   - import_statement: import_import (34 tokens)
#     Preview: import {   makePrefixer,   type UseFloatingUIProps,   useFloatingUI,   useForkRef,   useId, } from "...
#   - import_statement: import_import (8 tokens)
#     Preview: import dropdownCss from "./Dropdown.css";...
#   - export_statement: export_statement (335 tokens)
#     Preview: export type DropdownProps<Item = string> = {   /**    * If `true`, the dropdown will be disabled....
#   - function_declaration: nction (68 tokens)
#     Preview: nction ExpandIcon({ open }: { open: boolean }) {   const { CollapseIcon, ExpandIcon } = useIcon();...
#   - export_statement: export_statement (2484 tokens)
#     Preview: port const Dropdown = forwardRef(function Dropdown<Item>(   props: DropdownProps<Item>,   ref: Forwa...
# Created 4 semantic chunks
#   Sub-chunking export_statement (2484 tokens)
#     Breaking down export_statement (2484 tokens) into smaller pieces...
# Sub-chunked 1 oversized chunks
# Final result: 6 total chunks
#
# --- Semantic Chunk Summary for Dropdown.tsx ---
# 1. imports_14_statements
#    Type: imports_group
#    Size: 271 tokens, 46 lines
#    Content preview:
#      import {
#      flip,
#      offset,
#      ... (43 more lines)
#
# 2. export_statement
#    Type: export_statement
#    Size: 335 tokens, 53 lines
#    Content preview:
#      export type DropdownProps<Item = string> = {
#      /**
#      * If `true`, the dropdown will be disabled.
#      ... (50 more lines)
#
# 3. nction
#    Type: function_declaration
#    Size: 68 tokens, 10 lines
#    Content preview:
#      nction ExpandIcon({ open }: { open: boolean }) {
#      const { CollapseIcon, ExpandIcon } = useIcon();
#      return open ? (
#      ... (7 more lines)
#
#   4. export_statement_part_1
#      Type: export_statement_part
#      Size: 1002 tokens, 162 lines
#      Content preview:
#        port const Dropdown = forwardRef(function Dropdown<Item>(
#        props: DropdownProps<Item>,
#        ref: ForwardedRef<HTMLButtonElement>,
#        ... (159 more lines)
#
#   5. export_statement_part_2
#      Type: export_statement_part
#      Size: 1008 tokens, 164 lines
#      Content preview:
#        setFocusVisibleState(true);
#        }
#        };
#        ... (161 more lines)
#
#   6. export_statement_part_3
#      Type: export_statement_part
#      Size: 474 tokens, 70 lines
#      Content preview:
#        },
#        className,
#        )}
#        ... (67 more lines)
#
#   ✅ Saved: Dropdown.tsx_chunk_001_u38k4i.md
#   ✅ Saved: Dropdown.tsx_chunk_002_u38k4i.md
#   ✅ Saved: Dropdown.tsx_chunk_003_u38k4i.md
#   ✅ Saved: Dropdown.tsx_chunk_004_u38k4i.md
#   ✅ Saved: Dropdown.tsx_chunk_005_u38k4i.md
#   ✅ Saved: Dropdown.tsx_chunk_006_u38k4i.md
#
# === Processing: RadioButtonGroup.tsx ===
# File size: 3767 characters
# File type: .tsx
# Found 10 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (23 tokens)
#     Preview: import {   type ChangeEventHandler,   type ComponentPropsWithoutRef,   forwardRef, } from "react";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useFormFieldProps } from "../form-field-context";...
#   - import_statement: import_import (17 tokens)
#     Preview: import { makePrefixer, useControlled, useId } from "../utils";...
#   - import_statement: import_import (14 tokens)
#     Preview: import { RadioGroupContext } from "./internal/RadioGroupContext";...
#   - import_statement: import_import (10 tokens)
#     Preview: import radioButtonGroupCss from "./RadioButtonGroup.css";...
#   - export_statement: interface_RadioButtonGroupProps (240 tokens)
#     Preview: export interface RadioButtonGroupProps   extends Omit<ComponentPropsWithoutRef<"fieldset">, "onChang...
#   - export_statement: const_RadioButtonGroup (490 tokens)
#     Preview: export const RadioButtonGroup = forwardRef<   HTMLFieldSetElement,   RadioButtonGroupProps >(functio...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for RadioButtonGroup.tsx ---
# 1. complete_module_10_parts
#    Type: complete_module
#    Size: 842 tokens, 150 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (147 more lines)
#
#   ✅ Saved: RadioButtonGroup.tsx_chunk_001_d97s98.md
#
# === Processing: RadioButton.tsx ===
# File size: 5899 characters
# File type: .tsx
# Found 13 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (43 tokens)
#     Preview: import {   type ChangeEventHandler,   type ComponentPropsWithoutRef,   type FocusEventHandler,   for...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useFormFieldProps } from "../form-field-context";...
#   - import_statement: import_import (14 tokens)
#     Preview: import type { AdornmentValidationStatus } from "../status-adornment";...
#   - import_statement: import_import (10 tokens)
#     Preview: import type { DataAttributes } from "../types";...
#   - import_statement: import_import (14 tokens)
#     Preview: import { makePrefixer, useControlled } from "../utils";...
#   - import_statement: import_import (13 tokens)
#     Preview: import { useRadioGroup } from "./internal/useRadioGroup";...
#   - import_statement: import_import (8 tokens)
#     Preview: import radioButtonCss from "./RadioButton.css";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { RadioButtonIcon } from "./RadioButtonIcon";...
#   - export_statement: interface_RadioButtonProps (371 tokens)
#     Preview: export interface RadioButtonProps   extends Omit<     ComponentPropsWithoutRef<"label">,     "onChan...
#   - export_statement: const_RadioButton (746 tokens)
#     Preview: export const RadioButton = forwardRef<HTMLLabelElement, RadioButtonProps>(   function RadioButton(pr...
# Created 3 semantic chunks
# Final result: 3 total chunks
#
# --- Semantic Chunk Summary for RadioButton.tsx ---
# 1. imports_11_statements
#    Type: imports_group
#    Size: 160 tokens, 19 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#      import { useWindow } from "@salt-ds/window";
#      import { clsx } from "clsx";
#      ... (16 more lines)
#
# 2. interface_RadioButtonProps
#    Type: export_statement
#    Size: 371 tokens, 63 lines
#    Content preview:
#      export interface RadioButtonProps
#      extends Omit<
#      ComponentPropsWithoutRef<"label">,
#      ... (60 more lines)
#
# 3. const_RadioButton
#    Type: export_statement
#    Size: 746 tokens, 132 lines
#    Content preview:
#      export const RadioButton = forwardRef<HTMLLabelElement, RadioButtonProps>(
#      function RadioButton(props, ref) {
#      const {
#      ... (129 more lines)
#
#   ✅ Saved: RadioButton.tsx_chunk_001_tsbhk8.md
#   ✅ Saved: RadioButton.tsx_chunk_002_tsbhk8.md
#   ✅ Saved: RadioButton.tsx_chunk_003_tsbhk8.md
#
# === Processing: RadioButtonIcon.tsx ===
# File size: 2079 characters
# File type: .tsx
# Found 9 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (12 tokens)
#     Preview: import type { ComponentPropsWithoutRef } from "react";...
#   - import_statement: import_import (14 tokens)
#     Preview: import type { AdornmentValidationStatus } from "../status-adornment";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import radioButtonIconCss from "./RadioButtonIcon.css";...
#   - export_statement: interface_RadioButtonIconProps (57 tokens)
#     Preview: export interface RadioButtonIconProps extends ComponentPropsWithoutRef<"div"> {   checked?: boolean;...
#   - export_statement: const_RadioButtonIcon (415 tokens)
#     Preview: export const RadioButtonIcon = ({   checked,   className,   error,   disabled,   validationStatus,...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for RadioButtonIcon.tsx ---
# 1. complete_module_9_parts
#    Type: complete_module
#    Size: 554 tokens, 81 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (78 more lines)
#
#   ✅ Saved: RadioButtonIcon.tsx_chunk_001_f3qkpm.md
#
# === Processing: DrawerCloseButton.tsx ===
# File size: 1132 characters
# File type: .tsx
# Found 9 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (9 tokens)
#     Preview: import { forwardRef } from "react";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { Button, type ButtonProps } from "../button";...
#   - import_statement: import_import (11 tokens)
#     Preview: import { useIcon } from "../semantic-icon-provider";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (12 tokens)
#     Preview: import drawerCloseButtonCss from "./DrawerCloseButton.css";...
#   - export_statement: const_DrawerCloseButton (153 tokens)
#     Preview: export const DrawerCloseButton = forwardRef<HTMLButtonElement, ButtonProps>(   function DrawerCloseB...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for DrawerCloseButton.tsx ---
# 1. complete_module_9_parts
#    Type: complete_module
#    Size: 243 tokens, 41 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (38 more lines)
#
#   ✅ Saved: DrawerCloseButton.tsx_chunk_001_aqm2n4.md
#
# === Processing: Drawer.tsx ===
# File size: 3603 characters
# File type: .tsx
# Found 11 semantic units
#   - import_statement: import_import (18 tokens)
#     Preview: import { useClick, useDismiss, useInteractions } from "@floating-ui/react";...
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (30 tokens)
#     Preview: import {   type ComponentPropsWithoutRef,   forwardRef,   type PropsWithChildren,   useEffect,   use...
#   - import_statement: import_import (10 tokens)
#     Preview: import { Scrim } from "../scrim";...
#   - import_statement: import_import (28 tokens)
#     Preview: import {   makePrefixer,   useFloatingComponent,   useFloatingUI,   useForkRef, } from "../utils";...
#   - import_statement: import_import (8 tokens)
#     Preview: import drawerCss from "./Drawer.css";...
#   - interface_declaration: ConditionalScrimWrapperProps (17 tokens)
#     Preview: interface ConditionalScrimWrapperProps extends PropsWithChildren {   condition: boolean; }...
#   - export_statement: interface_DrawerProps (158 tokens)
#     Preview: export interface DrawerProps extends ComponentPropsWithoutRef<"div"> {   /**    * Defines the drawer...
#   - export_statement: const_Drawer (456 tokens)
#     Preview: export const Drawer = forwardRef<HTMLDivElement, DrawerProps>(   function Drawer(props, ref) {     c...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for Drawer.tsx ---
# 1. complete_module_11_parts
#    Type: complete_module
#    Size: 761 tokens, 138 lines
#    Content preview:
#      import { useClick, useDismiss, useInteractions } from "@floating-ui/react";
#
#      import { useComponentCssInjection } from "@salt-ds/styles";
#      ... (135 more lines)
#
#   ✅ Saved: Drawer.tsx_chunk_001_q2ptum.md
#
# === Processing: Paginator.tsx ===
# File size: 2415 characters
# File type: .tsx
# Found 12 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (17 tokens)
#     Preview: import { forwardRef, type HTMLAttributes, type MouseEventHandler } from "react";...
#   - import_statement: import_import (8 tokens)
#     Preview: import { Button } from "../button";...
#   - import_statement: import_import (11 tokens)
#     Preview: import { useIcon } from "../semantic-icon-provider";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { PageRanges } from "./PageRanges";...
#   - import_statement: import_import (8 tokens)
#     Preview: import paginatorCss from "./Paginator.css";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { usePaginationContext } from "./usePaginationContext";...
#   - export_statement: interface_PaginatorProps (66 tokens)
#     Preview: export interface PaginatorProps extends HTMLAttributes<HTMLDivElement> {   /**    * Number of pages...
#   - export_statement: const_Paginator (354 tokens)
#     Preview: export const Paginator = forwardRef<HTMLDivElement, PaginatorProps>(   function Paginator(     { cla...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for Paginator.tsx ---
# 1. complete_module_12_parts
#    Type: complete_module
#    Size: 532 tokens, 82 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (79 more lines)
#
#   ✅ Saved: Paginator.tsx_chunk_001_whticj.md
#
# === Processing: Pagination.tsx ===
# File size: 2528 characters
# File type: .tsx
# Found 10 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (33 tokens)
#     Preview: import {   forwardRef,   type HTMLAttributes,   type SyntheticEvent,   useCallback,   useEffect,   u...
#   - import_statement: import_import (15 tokens)
#     Preview: import { useAriaAnnouncer } from "../aria-announcer";...
#   - import_statement: import_import (14 tokens)
#     Preview: import { makePrefixer, useControlled } from "../utils";...
#   - import_statement: import_import (8 tokens)
#     Preview: import paginationCss from "./Pagination.css";...
#   - import_statement: import_import (14 tokens)
#     Preview: import { type PaginationContext, paginationContext } from "./PaginationContext";...
#   - export_statement: interface_PaginationProps (92 tokens)
#     Preview: export interface PaginationProps extends HTMLAttributes<HTMLElement> {   /**    * Number of pages....
#   - export_statement: const_Pagination (355 tokens)
#     Preview: export const Pagination = forwardRef<HTMLElement, PaginationProps>(   function Pagination(     {...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for Pagination.tsx ---
# 1. complete_module_10_parts
#    Type: complete_module
#    Size: 567 tokens, 115 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (112 more lines)
#
#   ✅ Saved: Pagination.tsx_chunk_001_9t3bhi.md
#
# === Processing: PageButton.tsx ===
# File size: 1410 characters
# File type: .tsx
# Found 9 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (13 tokens)
#     Preview: import { forwardRef, type MouseEventHandler } from "react";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import pageButtonCss from "./PageButton.css";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { usePaginationContext } from "./usePaginationContext";...
#   - export_statement: interface_PageButtonProps (22 tokens)
#     Preview: export interface PageButtonProps {   page: number;   selected?: boolean;   disabled?: boolean; }...
#   - export_statement: const_PageButton (212 tokens)
#     Preview: export const PageButton = forwardRef<HTMLButtonElement, PageButtonProps>(   function PageButton({ pa...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for PageButton.tsx ---
# 1. complete_module_9_parts
#    Type: complete_module
#    Size: 315 tokens, 53 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (50 more lines)
#
#   ✅ Saved: PageButton.tsx_chunk_001_j3keer.md
#
# === Processing: CompactInput.tsx ===
# File size: 1975 characters
# File type: .tsx
# Found 9 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (27 tokens)
#     Preview: import {   type ChangeEventHandler,   forwardRef,   type KeyboardEventHandler,   useEffect,   useSta...
#   - import_statement: import_import (12 tokens)
#     Preview: import { Input, type InputProps } from "../input";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import compactInputCss from "./CompactInput.css";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { usePaginationContext } from "./usePaginationContext";...
#   - export_statement: const_CompactInput (350 tokens)
#     Preview: export const CompactInput = forwardRef<   HTMLInputElement,   Pick<InputProps, "inputRef" | "variant...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for CompactInput.tsx ---
# 1. complete_module_9_parts
#    Type: complete_module
#    Size: 457 tokens, 79 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (76 more lines)
#
#   ✅ Saved: CompactInput.tsx_chunk_001_l4rmev.md
#
# === Processing: CompactPaginator.tsx ===
# File size: 2208 characters
# File type: .tsx
# Found 12 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (23 tokens)
#     Preview: import {   type ComponentPropsWithoutRef,   forwardRef,   type MouseEventHandler, } from "react";...
#   - import_statement: import_import (8 tokens)
#     Preview: import { Button } from "../button";...
#   - import_statement: import_import (11 tokens)
#     Preview: import { useIcon } from "../semantic-icon-provider";...
#   - import_statement: import_import (8 tokens)
#     Preview: import { Text } from "../text";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import compactPaginatorCss from "./CompactPaginator.css";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { PageButton } from "./PageButton";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { usePaginationContext } from "./usePaginationContext";...
#   - export_statement: const_CompactPaginator (383 tokens)
#     Preview: export const CompactPaginator = forwardRef<   HTMLDivElement,   ComponentPropsWithoutRef<"div"> >(fu...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for CompactPaginator.tsx ---
# 1. complete_module_12_parts
#    Type: complete_module
#    Size: 511 tokens, 80 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (77 more lines)
#
#   ✅ Saved: CompactPaginator.tsx_chunk_001_qxwbh0.md
#
# === Processing: PageRanges.tsx ===
# File size: 1793 characters
# File type: .tsx
# Found 10 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { type ReactElement, useCallback } from "react";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { PageButton } from "./PageButton";...
#   - import_statement: import_import (10 tokens)
#     Preview: import pageRangesCss from "./PageRanges.css";...
#   - import_statement: import_import (14 tokens)
#     Preview: import { type PageRange, usePagination } from "./usePagination";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { usePaginationContext } from "./usePaginationContext";...
#   - export_statement: interface_PageRangesProps (19 tokens)
#     Preview: export interface PageRangesProps {   boundaryCount?: number;   siblingCount?: number; }...
#   - export_statement: function_PageRanges (234 tokens)
#     Preview: export function PageRanges({   siblingCount = 2,   boundaryCount = 1, }: PageRangesProps) {   const...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for PageRanges.tsx ---
# 1. complete_module_10_parts
#    Type: complete_module
#    Size: 347 tokens, 67 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (64 more lines)
#
#   ✅ Saved: PageRanges.tsx_chunk_001_5hbeic.md
#
# === Processing: GoToInput.tsx ===
# File size: 2689 characters
# File type: .tsx
# Found 11 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (33 tokens)
#     Preview: import {   type ChangeEventHandler,   forwardRef,   type HTMLAttributes,   type KeyboardEventHandler...
#   - import_statement: import_import (14 tokens)
#     Preview: import { FormField, FormFieldLabel } from "../form-field";...
#   - import_statement: import_import (8 tokens)
#     Preview: import { Input } from "../input";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (11 tokens)
#     Preview: import goToInputCss from "./GoToInput.css";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { usePaginationContext } from "./usePaginationContext";...
#   - export_statement: interface_GoToInputProps (70 tokens)
#     Preview: export interface GoToInputProps extends HTMLAttributes<HTMLSpanElement> {   /**    * Input label....
#   - export_statement: const_GoToInput (406 tokens)
#     Preview: export const GoToInput = forwardRef<HTMLDivElement, GoToInputProps>(   function GoToInput(     {...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for GoToInput.tsx ---
# 1. complete_module_11_parts
#    Type: complete_module
#    Size: 600 tokens, 113 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (110 more lines)
#
#   ✅ Saved: GoToInput.tsx_chunk_001_m6q09q.md
#
# === Processing: SegmentedButtonGroup.tsx ===
# File size: 927 characters
# File type: .tsx
# Found 8 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (15 tokens)
#     Preview: import { type ComponentPropsWithoutRef, forwardRef } from "react";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (13 tokens)
#     Preview: import segmentedButtonGroupCss from "./SegmentedButtonGroup.css";...
#   - export_statement: interface_SegmentedButtonGroupProps (18 tokens)
#     Preview: export interface SegmentedButtonGroupProps   extends ComponentPropsWithoutRef<"div"> {}...
#   - export_statement: const_SegmentedButtonGroup (114 tokens)
#     Preview: export const SegmentedButtonGroup = forwardRef<   HTMLDivElement,   SegmentedButtonGroupProps >(func...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for SegmentedButtonGroup.tsx ---
# 1. complete_module_8_parts
#    Type: complete_module
#    Size: 206 tokens, 32 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (29 more lines)
#
#   ✅ Saved: SegmentedButtonGroup.tsx_chunk_001_43nmyi.md
#
# === Processing: SkipLink.tsx ===
# File size: 1843 characters
# File type: .tsx
# Found 9 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (27 tokens)
#     Preview: import {   type ComponentPropsWithoutRef,   forwardRef,   useEffect,   useRef,   useState, } from "r...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (17 tokens)
#     Preview: import { useManageFocusOnTarget } from "./internal/useManageFocusOnTarget";...
#   - import_statement: import_import (10 tokens)
#     Preview: import skipLinkCss from "./SkipLink.css";...
#   - interface_declaration: SkipLinkProps (61 tokens)
#     Preview: interface SkipLinkProps extends ComponentPropsWithoutRef<"a"> {   /**    * The ID of the target elem...
#   - export_statement: const_SkipLink (263 tokens)
#     Preview: export const SkipLink = forwardRef<HTMLAnchorElement, SkipLinkProps>(   function SkipLink(     { cla...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for SkipLink.tsx ---
# 1. complete_module_9_parts
#    Type: complete_module
#    Size: 424 tokens, 73 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (70 more lines)
#
#   ✅ Saved: SkipLink.tsx_chunk_001_d03cj1.md
#
# === Processing: Tooltip.tsx ===
# File size: 4075 characters
# File type: .tsx
# Found 9 semantic units
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (33 tokens)
#     Preview: import {   cloneElement,   forwardRef,   type HTMLAttributes,   isValidElement,   type ReactNode,...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useFormFieldProps } from "../form-field-context";...
#   - import_statement: import_import (21 tokens)
#     Preview: import {   VALIDATION_NAMED_STATUS,   type ValidationStatus, } from "../status-indicator";...
#   - import_statement: import_import (40 tokens)
#     Preview: import {   getRefFromChildren,   makePrefixer,   mergeProps,   type UseFloatingUIProps,   useFloatin...
#   - import_statement: import_import (10 tokens)
#     Preview: import { TooltipBase } from "./TooltipBase";...
#   - import_statement: import_import (15 tokens)
#     Preview: import { type UseTooltipProps, useTooltip } from "./useTooltip";...
#   - export_statement: interface_TooltipProps (298 tokens)
#     Preview: export interface TooltipProps   extends Pick<UseFloatingUIProps, "open" | "onOpenChange" | "placemen...
#   - export_statement: const_Tooltip (466 tokens)
#     Preview: export const Tooltip = forwardRef<HTMLDivElement, TooltipProps>(   function Tooltip(props, ref) {...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for Tooltip.tsx ---
# 1. complete_module_9_parts
#    Type: complete_module
#    Size: 905 tokens, 163 lines
#    Content preview:
#      import { clsx } from "clsx";
#
#      import {
#      ... (160 more lines)
#
#   ✅ Saved: Tooltip.tsx_chunk_001_gbsna5.md
#
# === Processing: TooltipBase.tsx ===
# File size: 1772 characters
# File type: .tsx
# Found 10 semantic units
#   - import_statement: import_import (16 tokens)
#     Preview: import { FloatingArrow, type FloatingArrowProps } from "@floating-ui/react";...
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useFormFieldProps } from "../form-field-context";...
#   - import_statement: import_import (15 tokens)
#     Preview: import { StatusIndicator, type ValidationStatus } from "../status-indicator";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import type { TooltipProps } from "./Tooltip";...
#   - import_statement: import_import (8 tokens)
#     Preview: import tooltipCss from "./Tooltip.css";...
#   - interface_declaration: TooltipBaseProps (46 tokens)
#     Preview: interface TooltipBaseProps extends Omit<TooltipProps, "children"> {   arrowProps: FloatingArrowProps...
#   - export_statement: const_TooltipBase (243 tokens)
#     Preview: export const TooltipBase = (props: TooltipBaseProps) => {   const targetWindow = useWindow();   useC...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for TooltipBase.tsx ---
# 1. complete_module_10_parts
#    Type: complete_module
#    Size: 386 tokens, 67 lines
#    Content preview:
#      import { FloatingArrow, type FloatingArrowProps } from "@floating-ui/react";
#
#      import { useComponentCssInjection } from "@salt-ds/styles";
#      ... (64 more lines)
#
#   ✅ Saved: TooltipBase.tsx_chunk_001_xw7l2y.md
#
# === Processing: ParentChildLayout.tsx ===
# File size: 2753 characters
# File type: .tsx
# Found 10 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (26 tokens)
#     Preview: import {   type ComponentPropsWithoutRef,   forwardRef,   type ReactNode,   useEffect, } from "react...
#   - import_statement: import_import (11 tokens)
#     Preview: import type { Breakpoints } from "../breakpoints";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (12 tokens)
#     Preview: import parentChildLayoutCss from "./ParentChildLayout.css";...
#   - import_statement: import_import (22 tokens)
#     Preview: import { useIsViewportLargerThanBreakpoint } from "./useIsViewportLargerThanBreakpoint";...
#   - export_statement: interface_ParentChildLayoutProps (171 tokens)
#     Preview: export interface ParentChildLayoutProps   extends ComponentPropsWithoutRef<"div"> {   /**    * Break...
#   - export_statement: const_ParentChildLayout (371 tokens)
#     Preview: export const ParentChildLayout = forwardRef<   HTMLDivElement,   ParentChildLayoutProps >(function P...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for ParentChildLayout.tsx ---
# 1. complete_module_10_parts
#    Type: complete_module
#    Size: 659 tokens, 111 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (108 more lines)
#
#   ✅ Saved: ParentChildLayout.tsx_chunk_001_c22y3l.md
#
# === Processing: ViewportProvider.tsx ===
# File size: 1517 characters
# File type: .tsx
# Found 4 semantic units
#   - import_statement: import_import (16 tokens)
#     Preview: import { createContext, type ReactNode, useContext, useState } from "react";...
#   - import_statement: import_import (17 tokens)
#     Preview: import { useIsomorphicLayoutEffect } from "../utils/useIsomorphicLayoutEffect";...
#   - type_alias_declaration: ViewportProviderProps (14 tokens)
#     Preview: type ViewportProviderProps = {   children?: ReactNode; };...
#   - export_statement: export_statement (13 tokens)
#     Preview: export { ViewportProvider, ViewportContext, useViewport };...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for ViewportProvider.tsx ---
# 1. complete_module_4_parts
#    Type: complete_module
#    Size: 60 tokens, 9 lines
#    Content preview:
#      import { createContext, type ReactNode, useContext, useState } from "react";
#
#      import { useIsomorphicLayoutEffect } from "../utils/useIsomorphicLayoutEffect";
#      ... (6 more lines)
#
#   ✅ Saved: ViewportProvider.tsx_chunk_001_vdkfn7.md
#
# === Processing: ExpansionIcon.tsx ===
# File size: 801 characters
# File type: .tsx
# Found 3 semantic units
#   - import_statement: import_import (11 tokens)
#     Preview: import { useIcon } from "../semantic-icon-provider";...
#   - interface_declaration: ExpansionIconProps (47 tokens)
#     Preview: interface ExpansionIconProps {   /**    * Whether the navigation item is expanded.    */   expanded?...
#   - export_statement: const_ExpansionIcon (122 tokens)
#     Preview: export const ExpansionIcon = ({   expanded = false,   orientation = "horizontal", }: ExpansionIconPr...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for ExpansionIcon.tsx ---
# 1. complete_module_3_parts
#    Type: complete_module
#    Size: 180 tokens, 33 lines
#    Content preview:
#      import { useIcon } from "../semantic-icon-provider";
#
#      interface ExpansionIconProps {
#      ... (30 more lines)
#
#   ✅ Saved: ExpansionIcon.tsx_chunk_001_ux3knq.md
#
# === Processing: NavigationItem.tsx ===
# File size: 3287 characters
# File type: .tsx
# Found 11 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (27 tokens)
#     Preview: import {   type ComponentPropsWithoutRef,   forwardRef,   type MouseEvent,   type MouseEventHandler,...
#   - import_statement: import_import (11 tokens)
#     Preview: import type { RenderPropsType } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { makePrefixer } from "../utils";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { ExpansionIcon } from "./ExpansionIcon";...
#   - import_statement: import_import (10 tokens)
#     Preview: import navigationItemCss from "./NavigationItem.css";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { NavigationItemAction } from "./NavigationItemAction";...
#   - export_statement: interface_NavigationItemProps (213 tokens)
#     Preview: export interface NavigationItemProps extends ComponentPropsWithoutRef<"div"> {   /**    * Whether th...
#   - export_statement: const_NavigationItem (396 tokens)
#     Preview: export const NavigationItem = forwardRef<HTMLDivElement, NavigationItemProps>(   function Navigation...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for NavigationItem.tsx ---
# 1. complete_module_11_parts
#    Type: complete_module
#    Size: 725 tokens, 130 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (127 more lines)
#
#   ✅ Saved: NavigationItem.tsx_chunk_001_9uejwr.md
#
# === Processing: NavigationItemAction.tsx ===
# File size: 283 characters
# File type: .tsx
# Found 4 semantic units
#   - import_statement: import_import (12 tokens)
#     Preview: import type { ComponentPropsWithoutRef } from "react";...
#   - import_statement: import_import (9 tokens)
#     Preview: import { renderProps } from "../utils";...
#   - interface_declaration: NavigationItemActionProps (13 tokens)
#     Preview: interface NavigationItemActionProps extends ComponentPropsWithoutRef<any> {}...
#   - export_statement: function_NavigationItemAction (23 tokens)
#     Preview: export function NavigationItemAction(props: NavigationItemActionProps) {   return renderProps("a", p...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for NavigationItemAction.tsx ---
# 1. complete_module_4_parts
#    Type: complete_module
#    Size: 57 tokens, 9 lines
#    Content preview:
#      import type { ComponentPropsWithoutRef } from "react";
#
#      import { renderProps } from "../utils";
#      ... (6 more lines)
#
#   ✅ Saved: NavigationItemAction.tsx_chunk_001_ikv3i2.md
#
# === Processing: Card.tsx ===
# File size: 2154 characters
# File type: .tsx
# Found 8 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (15 tokens)
#     Preview: import { type ComponentPropsWithoutRef, forwardRef } from "react";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { capitalize, makePrefixer } from "../utils";...
#   - import_statement: import_import (8 tokens)
#     Preview: import cardCss from "./Card.css";...
#   - export_statement: interface_CardProps (197 tokens)
#     Preview: export interface CardProps extends ComponentPropsWithoutRef<"div"> {   /**    * If provided an accen...
#   - export_statement: const_Card (234 tokens)
#     Preview: export const Card = forwardRef<HTMLDivElement, CardProps>(   function Card(props, ref) {     const {...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for Card.tsx ---
# 1. complete_module_8_parts
#    Type: complete_module
#    Size: 502 tokens, 83 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#
#      import { useWindow } from "@salt-ds/window";
#      ... (80 more lines)
#
#   ✅ Saved: Card.tsx_chunk_001_9ds4qp.md
#
# === Processing: FlexLayout.tsx ===
# File size: 4944 characters
# File type: .tsx
# Found 17 semantic units
#   - import_statement: import_import (14 tokens)
#     Preview: import { useComponentCssInjection } from "@salt-ds/styles";...
#   - import_statement: import_import (12 tokens)
#     Preview: import { useWindow } from "@salt-ds/window";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { clsx } from "clsx";...
#   - import_statement: import_import (26 tokens)
#     Preview: import {   type ElementType,   type ForwardedRef,   type FunctionComponent,   forwardRef, } from "re...
#   - import_statement: import_import (11 tokens)
#     Preview: import { useBreakpoint } from "../breakpoints";...
#   - import_statement: import_import (39 tokens)
#     Preview: import {   makePrefixer,   type PolymorphicComponentPropWithRef,   type PolymorphicRef,   type Respo...
#   - import_statement: import_import (10 tokens)
#     Preview: import flexLayoutCss from "./FlexLayout.css";...
#   - import_statement: import_import (10 tokens)
#     Preview: import { parseSpacing } from "./parseSpacing";...
#   - export_statement: export_statement (16 tokens)
#     Preview: export type LayoutSeparator = "start" | "center" | "end";...
#   - export_statement: const_FLEX_ALIGNMENT_BASE (19 tokens)
#     Preview: export const FLEX_ALIGNMENT_BASE = ["start", "end", "center"] as const;...
#   - export_statement: const_FLEX_CONTENT_ALIGNMENT_BASE (36 tokens)
#     Preview: export const FLEX_CONTENT_ALIGNMENT_BASE = [   ...FLEX_ALIGNMENT_BASE,   "space-between",   "space-a...
#   - export_statement: export_statement (14 tokens)
#     Preview: export type FlexAlignment = (typeof FLEX_ALIGNMENT_BASE)[number];...
#   - export_statement: export_statement (15 tokens)
#     Preview: export type FlexContentAlignment = (typeof FLEX_CONTENT_ALIGNMENT_BASE)[number];...
#   - export_statement: export_statement (326 tokens)
#     Preview: export type FlexLayoutProps<T extends ElementType> =   PolymorphicComponentPropWithRef<     T,     {...
#   - type_alias_declaration: FlexLayoutComponent (29 tokens)
#     Preview: type FlexLayoutComponent = <T extends ElementType = "div">(   props: FlexLayoutProps<T>, ) => Return...
#   - function_declaration: parseAlignment (33 tokens)
#     Preview: function parseAlignment(style: string | undefined) {   return style === "start" || style === "end" ?...
#   - export_statement: const_FlexLayout (479 tokens)
#     Preview: export const FlexLayout: FlexLayoutComponent = forwardRef(function FlexLayout<   T extends ElementTy...
# Created 3 semantic chunks
# Final result: 3 total chunks
#
# --- Semantic Chunk Summary for FlexLayout.tsx ---
# 1. imports_8_statements
#    Type: imports_group
#    Size: 132 tokens, 19 lines
#    Content preview:
#      import { useComponentCssInjection } from "@salt-ds/styles";
#      import { useWindow } from "@salt-ds/window";
#      import { clsx } from "clsx";
#      ... (16 more lines)
#
# 2. code_group_1_8_parts
#    Type: grouped_content
#    Size: 488 tokens, 63 lines
#    Content preview:
#      export type LayoutSeparator = "start" | "center" | "end";
#
# ...
#   - rule_set: rule_.saltStep-status-error_>_.salt (27 tokens)
#     Preview: .saltStep-status-error > .saltStepText-description {   color: var(--salt-status-error-foreground-inf...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for StepText.css ---
# 1. css_group_1_9_rules
#    Type: grouped_content
#    Size: 295 tokens, 39 lines
#    Content preview:
#      .saltStepText-label {
#      grid-area: label;
#      }
#      ... (36 more lines)
#
#   ✅ Saved: StepText.css_chunk_001_gf2k8d.md
#
# === Processing: SliderTooltip.css ===
# File size: 1241 characters
# File type: .css
# Found 4 semantic units
#   - rule_set: rule_.saltSliderTooltip (194 tokens)
#     Preview: .saltSliderTooltip {   background: var(--salt-container-primary-background);   border-color: var(--s...
#   - rule_set: rule_.saltSliderTooltip-visible, (18 tokens)
#     Preview: .saltSliderTooltip-visible, .saltSliderTooltip:hover {   visibility: visible; }...
#   - rule_set: rule_.saltSliderTooltip-arrow (89 tokens)
#     Preview: .saltSliderTooltip-arrow {   fill: var(--salt-container-primary-background);   height: var(--salt-si...
#   - rule_set: rule_.saltSliderTooltip-text (13 tokens)
#     Preview: .saltSliderTooltip-text {   white-space: nowrap; }...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for SliderTooltip.css ---
# 1. css_group_1_4_rules
#    Type: grouped_content
#    Size: 314 tokens, 39 lines
#    Content preview:
#      .saltSliderTooltip {
#      background: var(--salt-container-primary-background);
#      border-color: var(--salt-container-primary-borderColor);
#      ... (36 more lines)
#
#   ✅ Saved: SliderTooltip.css_chunk_001_wdpk6j.md
#
# === Processing: SliderThumb.css ===
# File size: 1681 characters
# File type: .css
# Found 7 semantic units
#   - rule_set: rule_.saltSliderThumb (111 tokens)
#     Preview: .saltSliderThumb {   align-items: center;   background: var(--salt-accent-borderColor);   cursor: va...
#   - rule_set: rule_.saltSliderThumb-disabled (35 tokens)
#     Preview: .saltSliderThumb-disabled {   background: var(--salt-accent-borderColor-disabled);   cursor: var(--s...
#   - rule_set: rule_.saltSliderThumb-focusVisible (52 tokens)
#     Preview: .saltSliderThumb-focusVisible {   outline-style: var(--salt-focused-outlineStyle);   outline-width:...
#   - rule_set: rule_.saltSliderThumb:active, (28 tokens)
#     Preview: .saltSliderThumb:active, .saltSliderThumb-dragging {   cursor: var(--salt-cursor-grab-active); }...
#   - rule_set: rule_.saltSliderThumb-input (109 tokens)
#     Preview: .saltSliderThumb-input {   border: 0;   appearance: none;   cursor: var(--salt-cursor-grab);   heigh...
#   - rule_set: rule_.saltSliderThumb-secondThumb (29 tokens)
#     Preview: .saltSliderThumb-secondThumb {   /* The second thumb needs to sit on top the first thumb */   z-inde...
#   - rule_set: rule_.saltSliderThumb-accessibleTex (75 tokens)
#     Preview: .saltSliderThumb-accessibleText {   position: absolute;   height: 1px;   width: 1px;   padding: 0;...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for SliderThumb.css ---
# 1. css_group_1_7_rules
#    Type: grouped_content
#    Size: 439 tokens, 65 lines
#    Content preview:
#      .saltSliderThumb {
#      align-items: center;
#      background: var(--salt-accent-borderColor);
#      ... (62 more lines)
#
#   ✅ Saved: SliderThumb.css_chunk_001_by0n5k.md
#
# === Processing: SliderTrack.css ===
# File size: 5090 characters
# File type: .css
# Found 32 semantic units
#   - rule_set: rule_.saltSliderTrack (114 tokens)
#     Preview: .saltSliderTrack {   --slider-track-background: var(--salt-sentiment-neutral-track);   --slider-trac...
#   - rule_set: rule_.saltSliderTrack.saltSliderTra (38 tokens)
#     Preview: .saltSliderTrack.saltSliderTrack-withMarks {   /* To wrap the marks within the boundary box */   mar...
#   - rule_set: rule_.saltSliderTrack-disabled (17 tokens)
#     Preview: .saltSliderTrack-disabled {   cursor: var(--salt-cursor-disabled); }...
#   - rule_set: rule_.saltSliderTrack-container (40 tokens)
#     Preview: .saltSliderTrack-container {   align-items: center;   display: flex;   flex-direction: row;   gap: v...
#   - rule_set: rule_.saltSliderTrack-wrapper (55 tokens)
#     Preview: .saltSliderTrack-wrapper {   align-items: center;   cursor: var(--salt-cursor-hover);   display: fle...
#   - rule_set: rule_.saltSliderTrack-disabled, (28 tokens)
#     Preview: .saltSliderTrack-disabled, .saltSliderTrack-disabled .saltSliderTrack-wrapper {   cursor: var(--salt...
#   - rule_set: rule_.saltSliderTrack-disabled_.sal (18 tokens)
#     Preview: .saltSliderTrack-disabled .saltSliderTrack-wrapper {   pointer-events: none; }...
#   - rule_set: rule_.saltSliderTrack-rail (40 tokens)
#     Preview: .saltSliderTrack-rail {   display: flex;   flex: 100%;   height: var(--salt-size-bar);   justify-con...
#   - rule_set: rule_.saltSliderTrack-rail::before, (34 tokens)
#     Preview: .saltSliderTrack-rail::before, .saltSliderTrack-rail::after {   content: "";   display: block;   hei...
#   - rule_set: rule_.saltSliderTrack-rail::before (68 tokens)
#     Preview: .saltSliderTrack-rail::before {   background: var(--slider-track-fill);   border-top-left-radius: va...
#   - rule_set: rule_.saltSliderTrack-hasMinTick.sa (25 tokens)
#     Preview: .saltSliderTrack-hasMinTick.saltSliderTrack-rail::before {   border-bottom-left-radius: unset; }...
#   - rule_set: rule_.saltSliderTrack-rail::after (72 tokens)
#     Preview: .saltSliderTrack-rail::after {   background: var(--slider-track-background);   border-top-right-radi...
#   - rule_set: rule_.saltSliderTrack-hasMaxTick.sa (25 tokens)
#     Preview: .saltSliderTrack-hasMaxTick.saltSliderTrack-rail::after {   border-bottom-right-radius: unset; }...
#   - rule_set: rule_.saltSliderTrack-range_.saltSl (44 tokens)
#     Preview: .saltSliderTrack-range .saltSliderTrack-rail::before {   background: var(--slider-track-background);...
#   - rule_set: rule_.saltSliderTrack-range_.saltSl (48 tokens)
#     Preview: .saltSliderTrack-range .saltSliderTrack-rail::after {   background: var(--slider-track-background);...
#   - rule_set: rule_.saltSliderTrack-range_.saltSl (86 tokens)
#     Preview: .saltSliderTrack-range .saltSliderTrack-rail .saltSliderTrack-fill {   background: var(--slider-trac...
#   - rule_set: rule_.saltSliderTrack-minLabel, (21 tokens)
#     Preview: .saltSliderTrack-minLabel, .saltSliderTrack-maxLabel {   user-select: none; }...
#   - rule_set: rule_.saltSliderTrack-dragging, (34 tokens)
#     Preview: .saltSliderTrack-dragging, .saltSliderTrack-dragging .saltSliderTrack-wrapper {   cursor: var(--salt...
#   - rule_set: rule_.saltSliderTrack-disabled (38 tokens)
#     Preview: .saltSliderTrack-disabled {   --slider-track-fill: var(--salt-accent-borderColor-disabled);   --slid...
#   - rule_set: rule_.saltSliderTrack-ticks (37 tokens)
#     Preview: .saltSliderTrack-ticks {   top: calc(var(--salt-size-bar) + var(--slider-tick-height));   position:...
#   - rule_set: rule_.saltSliderTrack-tick (50 tokens)
#     Preview: .saltSliderTrack-tick {   background: var(--slider-track-background);   height: var(--slider-tick-he...
#   - rule_set: rule_.saltSliderTrack-withTicks_.sa (20 tokens)
#     Preview: .saltSliderTrack-withTicks .saltSliderTrack-tickHidden {   visibility: hidden; }...
#   - rule_set: rule_.saltSliderTrack-tickSelected (18 tokens)
#     Preview: .saltSliderTrack-tickSelected {   background: var(--slider-track-fill); }...
#   - rule_set: rule_.saltSliderTrack-tick:first-of (16 tokens)
#     Preview: .saltSliderTrack-tick:first-of-type {   transform: unset; }...
#   - rule_set: rule_.saltSliderTrack-tick:last-of- (19 tokens)
#     Preview: .saltSliderTrack-tick:last-of-type {   transform: translateX(-100%); }...
#   - rule_set: rule_.saltSliderTrack-marks (25 tokens)
#     Preview: .saltSliderTrack-marks {   position: absolute;   user-select: none;   width: 100%; }...
#   - rule_set: rule_.saltSliderTrack-markLabel (118 tokens)
#     Preview: .saltSliderTrack-markLabel {   color: var(--salt-content-secondary-foreground);   font-family: var(-...
#   - rule_set: rule_.saltSliderTrack-constrainLabe (27 tokens)
#     Preview: .saltSliderTrack-constrainLabelPosition .saltSliderTrack-markLabel:first-of-type {   transform: tran...
#   - rule_set: rule_.saltSliderTrack-constrainLabe (27 tokens)
#     Preview: .saltSliderTrack-constrainLabelPosition .saltSliderTrack-markLabel:last-of-type {   transform: trans...
#   - rule_set: rule_.saltFormField_.saltSliderTrac (22 tokens)
#     Preview: .saltFormField .saltSliderTrack.saltSliderTrack-withMark {   margin-bottom: 0; }...
#   - rule_set: rule_.saltFormField_.saltSliderTrac (30 tokens)
#     Preview: .saltFormField .saltSliderTrack-container {   --saltFormField-label-width: 10%;    height: var(--sal...
#   - rule_set: rule_.saltFormField_.saltSliderTrac (33 tokens)
#     Preview: .saltFormField .saltSliderTrack-markLabel {   top: calc((var(--salt-size-base) - var(--salt-size-bar...
# Created 3 semantic chunks
# Final result: 3 total chunks
#
# --- Semantic Chunk Summary for SliderTrack.css ---
# 1. css_group_1_13_rules
#    Type: grouped_content
#    Size: 574 tokens, 86 lines
#    Content preview:
#      .saltSliderTrack {
#      --slider-track-background: var(--salt-sentiment-neutral-track);
#      --slider-track-fill: var(--salt-accent-borderColor);
#      ... (83 more lines)
#
# 2. css_group_2_14_rules
#    Type: grouped_content
#    Size: 574 tokens, 82 lines
#    Content preview:
#      .saltSliderTrack-range .saltSliderTrack-rail::before {
#      background: var(--slider-track-background);
#      width: calc(var(--slider-progressPercentageStart) - var(--salt-size-fixed-300));
#      ... (79 more lines)
#
# 3. css_group_3_5_rules
#    Type: grouped_content
#    Size: 139 tokens, 21 lines
#    Content preview:
#      .saltSliderTrack-constrainLabelPosition .saltSliderTrack-markLabel:first-of-type {
#      transform: translateX(0%);
#      }
#      ... (18 more lines)
#
#   ✅ Saved: SliderTrack.css_chunk_001_p17d1s.md
#   ✅ Saved: SliderTrack.css_chunk_002_p17d1s.md
#   ✅ Saved: SliderTrack.css_chunk_003_p17d1s.md
#
# === Processing: LinearProgress.css ===
# File size: 1884 characters
# File type: .css
# Found 9 semantic units
#   - rule_set: rule_.saltLinearProgress (54 tokens)
#     Preview: .saltLinearProgress {   align-items: center;   color: var(--salt-content-primary-foreground);   disp...
#   - rule_set: rule_.saltLinearProgress-barContain (39 tokens)
#     Preview: .saltLinearProgress-barContainer {   background: none;   position: relative;   width: 100%;   overfl...
#   - rule_set: rule_.saltLinearProgress-bar, (53 tokens)
#     Preview: .saltLinearProgress-bar, .saltLinearProgress-buffer {   position: absolute;   left: 0;   bottom: 0;...
#   - rule_set: rule_.saltLinearProgress-buffer (70 tokens)
#     Preview: .saltLinearProgress-buffer {   width: 0;   background: var(--salt-container-primary-background);   o...
#   - rule_set: rule_.saltLinearProgress-bar (39 tokens)
#     Preview: .saltLinearProgress-bar {   width: 100%;   background: var(--salt-accent-background);   z-index: cal...
#   - rule_set: rule_.saltLinearProgress-track (85 tokens)
#     Preview: .saltLinearProgress-track {   background: var(--salt-sentiment-neutral-track);   width: 100%;   heig...
#   - rule_set: rule_.saltLinearProgress-progressLa (36 tokens)
#     Preview: .saltLinearProgress-progressLabel {   color: inherit;   margin: 0;   white-space: nowrap;   padding-...
#   - rule_set: rule_.saltLinearProgress-indetermin (70 tokens)
#     Preview: .saltLinearProgress-indeterminate.saltLinearProgress-bar {   position: absolute;   left: 0px;   bott...
#   - keyframes_statement: keyframes_salt (77 tokens)
#     Preview: @keyframes salt-indeterminate-progress-bar {   0% {     transform: translateX(-100%);   }   60% {...
# Created 1 semantic chunks
# Final result: 1 total chunks
#
# --- Semantic Chunk Summary for LinearProgress.css ---
# 1. css_group_1_9_rules
#    Type: grouped_content
#    Size: 523 tokens, 81 lines
#    Content preview:
#      .saltLinearProgress {
#      align-items: center;
#      color: var(--salt-content-primary-foreground);
#      ... (78 more lines)
#
#   ✅ Saved: LinearProgress.css_chunk_001_1710iv.md
#
# === Processing: CircularProgress.css ===
# File size: 3147 characters
# File type: .css
# Found 14 semantic units
#   - rule_set: rule_.saltCircularProgress (28 tokens)
#     Preview: .saltCircularProgress {   color: var(--salt-content-primary-foreground);   display: inline-flex;   p...
#   - rule_set: rule_.saltCircularProgress-progress (59 tokens)
#     Preview: .saltCircularProgress-progressLabel {   align-items: center;   color: var(--salt-content-primary-for...
#   - rule_set: rule_.saltCircularProgress-track (110 tokens)
#     Preview: .saltCircularProgress-track {   inline-size: calc(var(--salt-size-base) * 3);   block-size: calc(var...
#   - rule_set: rule_.saltCircularProgress-bar, (73 tokens)
#     Preview: .saltCircularProgress-bar, .saltCircularProgress-bufferBorder, .saltCircularProgress-bufferBackgroun...
#   - rule_set: rule_.saltCircularProgress-bar (40 tokens)
#     Preview: .saltCircularProgress-bar {   border-color: var(--salt-accent-background);   border-style: var(--sal...
#   - rule_set: rule_.saltCircularProgress-bufferBo (62 tokens)
#     Preview: .saltCircularProgress-bufferBorder {   border: solid var(--salt-size-fixed-100) var(--salt-accent-ba...
#   - rule_set: rule_.saltCircularProgress-bufferBa (53 tokens)
#     Preview: .saltCircularProgress-bufferBackground {   border: solid var(--salt-size-bar-strong) var(--salt-cont...
#   - rule_set: rule_.saltCircularProgress-bars (42 tokens)
#     Preview: .saltCircularProgress-bars {   position: absolute;   inset-block-start: 0;   inset-inline-start: 0;...
#   - rule_set: rule_.saltCircularProgress-bufferOv (90 tokens)
#     Preview: .saltCircularProgress-bufferOverlayRight, .saltCircularProgress-bufferOverlayLeft, .saltCircularProg...
#   - rule_set: rule_.saltCircularProgress-bufferOv (53 tokens)
#     Preview: .saltCircularProgress-bufferOverlayRight, .saltCircularProgress-bufferOverlayLeft, .saltCircularProg...
#   - rule_set: rule_.saltCircularProgress-bufferSu (52 tokens)
#     Preview: .saltCircularProgress-bufferSubOverlayRight, .saltCircularProgress-bufferSubOverlayLeft, .saltCircul...
#   - rule_set: rule_.saltCircularProgress-bufferOv (25 tokens)
#     Preview: .saltCircularProgress-bufferOverlayLeft, .saltCircularProgress-barOverlayLeft {   transform: rotate(...
#   - rule_set: rule_.saltCircularProgress-bufferOv (65 tokens)
#     Preview: .saltCircularProgress-bufferOverlayRight:before, .saltCircularProgress-bufferSubOverlay:before {   c...
#   - rule_set: rule_.saltCircularProgress-bufferOv (27 tokens)
#     Preview: .saltCircularProgress-bufferOverlayRight:before {   bottom: 0;   z-index: var(--salt-zIndex-default)...
# Created 2 semantic chunks
# Final result: 2 total chunks
#
# --- Semantic Chunk Summary for CircularProgress.css ---
# 1. css_group_1_9_rules
#    Type: grouped_content
#    Size: 557 tokens, 76 lines
#    Content preview:
#      .saltCircularProgress {
#      color: var(--salt-content-primary-foreground);
#      display: inline-flex;
#      ... (73 more lines)
#
# 2. css_group_2_5_rules
#    Type: grouped_content
#    Size: 222 tokens, 36 lines
#    Content preview:
#      .saltCircularProgress-bufferOverlayRight,
#      .saltCircularProgress-bufferOverlayLeft,
#      .saltCircularProgress-barOverlayRight,
#      ... (33 more lines)
#
#   ✅ Saved: CircularProgress.css_chunk_001_trsxyg.md
#   ✅ Saved: CircularProgress.css_chunk_002_trsxyg.md
#
# 🎉 OVERALL SUMMARY
# Files processed: 358
# Total chunks created: 448
# Total chunk files saved: 448
# Output directory: /Users/tiyadiashok/python-projects/code_chunker/rag_chunks/pre_processed/code_sources/typescript/saltds_latest_chunks
# Average chunk size: 341 tokens
# Largest chunk: 1008 tokens
# Smallest chunk: 10 tokens
#
# Chunk types:
#   complete_module: 175
#   export_statement: 42
#   export_statement_part: 22
#   function_declaration: 11
#   function_declaration_part: 4
#   grouped_content: 138
#   imports_group: 28
#   interface_declaration: 9
#   rule_set: 15
#   type_alias_declaration: 4
#
# Chunks by file type:
#   .css: ~116 chunks
#   .ts: ~161 chunks
#   .tsx: ~170 chunks
